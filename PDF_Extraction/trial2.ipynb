# %%
import fitz  # PyMuPDF for PDF handling
from paddleocr import PaddleOCR  # For OCR extraction of text with bounding boxes
from deep_translator import GoogleTranslator  # For translating text from Chinese to English
from reportlab.pdfgen import canvas  # For generating the translated PDF
from reportlab.lib.pagesizes import letter, A4  # Page size for new PDF
from reportlab.lib import colors  # For coloring text (debug)
from reportlab.pdfbase.ttfonts import TTFont  # For adding custom fonts
from reportlab.pdfbase import pdfmetrics  # For registering custom fonts
import os

# %%
# Register a custom font if needed (Optional: Arial Unicode for CJK characters)
pdfmetrics.registerFont(TTFont('ArialUnicode', 'ArialUnicodeMS.ttf'))

# %%
# def adjust_cmyk_image_opacity(image_path, opacity=1.0):
#     """
#     Adjusts the opacity of a CMYK image by converting it to RGBA and modifying the alpha channel.
    
#     Args:
#         image_path (str): The path to the input CMYK image.
#         opacity (float): The desired opacity value (0.0 = fully transparent, 1.0 = fully opaque).
    
#     Returns:
#         Image: A PIL Image object with the modified opacity.
#     """
#     # Open the image in CMYK mode
#     image = Image.open(image_path)
    
#     # Convert the CMYK image to RGBA (which supports alpha channel)
#     rgba_image = image.convert("RGBA")
    
#     # Extract the R, G, B, and A channels
#     r, g, b, a = rgba_image.split()
    
#     # Create a new alpha channel with the desired opacity
#     new_alpha = a.point(lambda p: int(p * opacity))
    
#     # Merge back the modified alpha channel with the R, G, and B channels
#     rgba_image_with_opacity = Image.merge("RGBA", (r, g, b, new_alpha))
    
#     return rgba_image_with_opacity

# # Example usage
# adjusted_image = adjust_cmyk_image_opacity("image_33_0.png", opacity=0.5)
# adjusted_image.show()

# %%
# def get_image_opacity(image):
#     """
#     Retrieves the average opacity value from a CMYK image with an alpha channel.
#     Args:
#         image_path (str): Path to the local CMYK image.
#     Returns:
#         float: The average opacity value (0.0 - 1.0) if alpha channel is present, else 1.0.
#     """
#     # image = Image.open(image_path)
    
#     # Convert to RGBA if the image has an alpha channel, otherwise return full opacity (1.0)
#     if image.mode == 'CMYK':
#         rgba_image = image.convert("RGBA")
#     elif image.mode == 'RGBA':
#         rgba_image = image
#     else:
#         # No alpha channel, so return maximum opacity
#         return 1.0

#     # Extract the alpha channel from the RGBA image
#     _, _, _, alpha = rgba_image.split()
    
#     # Calculate the average opacity
#     avg_opacity = sum(alpha.getdata()) / (255 * alpha.size[0] * alpha.size[1])
#     return avg_opacity

# %%
# Step 1: Extract text, images, and tables from PDF using OCR
def extract_text_from_pdf(pdf_path, language='ch'):
    # Initialize the OCR model with the Chinese language
    ocr = PaddleOCR(lang=language, use_gpu=False)
    doc = fitz.open(pdf_path)
    extracted_data = []

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        image_list = page.get_images(full=True)
        image_data = []  # Collect image coordinates and sizes

        # Extract text and bounding boxes using OCR
        page_image = page.get_pixmap()  # Get page as an image for OCR
        image_path = f"temp_page_{page_num}.png"
        page_image.save(image_path)

        ocr_result = ocr.ocr(image_path)
        page_text_data = []
        for res in ocr_result[0]:
            # Each 'res' contains [bounding box, text, confidence]
            bounding_box, text = res
            page_text_data.append((bounding_box, text))

        # Collect image data (coordinates, etc.)
        for img_index, img_info in enumerate(image_list):
            xref = img_info[0]
            img = doc.extract_image(xref)
            # opacity = get_image_opacity(img)
            image_filename = f"image_{page_num}_{img_index}.png"
            with open(image_filename, "wb") as img_file:
                img_file.write(img["image"])
            # Extract image coordinates, width, and height
            rect = page.get_image_rects(xref)[0]
            image_data.append((image_filename, rect))

        # Append data for this page
        extracted_data.append({'page_num': page_num, 'text': page_text_data, 'images': image_data})
        # Remove temporary page image
        os.remove(image_path)

    # Reverse the ovelapping images per pages
    for page_data in extracted_data:
        # Sort the images for the current page in reverse order by filename
        page_data['images'].sort(key=lambda item: item[0], reverse=True)
    return extracted_data

# %%
extracted_data = extract_text_from_pdf("data/pdf2.pdf")
# Out:
# [2024/10/04 12:13:28] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/user/.paddleocr/whl/det/ch/ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/user/.paddleocr/whl/rec/ch/ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/user/Meet_Patel/AllChatbot-Project/chatenv/lib/python3.12/site-packages/paddleocr/ppocr/utils/ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/user/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/10/04 12:13:28] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:29] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.1902177333831787
# [2024/10/04 12:13:29] ppocr DEBUG: rec_res num  : 6, elapsed : 0.6998589038848877
# [2024/10/04 12:13:29] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:30] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.15943598747253418
# [2024/10/04 12:13:31] ppocr DEBUG: rec_res num  : 25, elapsed : 1.8976480960845947
# [2024/10/04 12:13:32] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:32] ppocr DEBUG: dt_boxes num : 57, elapsed : 0.10866570472717285
# [2024/10/04 12:13:33] ppocr DEBUG: rec_res num  : 57, elapsed : 1.2800750732421875
# [2024/10/04 12:13:33] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:33] ppocr DEBUG: dt_boxes num : 46, elapsed : 0.10744476318359375
# [2024/10/04 12:13:34] ppocr DEBUG: rec_res num  : 46, elapsed : 1.182969093322754
# [2024/10/04 12:13:34] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:35] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.14490151405334473
# [2024/10/04 12:13:38] ppocr DEBUG: rec_res num  : 113, elapsed : 3.5282769203186035
# [2024/10/04 12:13:38] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:38] ppocr DEBUG: dt_boxes num : 34, elapsed : 0.10541653633117676
# [2024/10/04 12:13:39] ppocr DEBUG: rec_res num  : 34, elapsed : 1.1330788135528564
# [2024/10/04 12:13:39] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:40] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.1188809871673584
# [2024/10/04 12:13:42] ppocr DEBUG: rec_res num  : 113, elapsed : 2.2749009132385254
# [2024/10/04 12:13:42] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:42] ppocr DEBUG: dt_boxes num : 40, elapsed : 0.10837006568908691
# [2024/10/04 12:13:44] ppocr DEBUG: rec_res num  : 40, elapsed : 1.489964246749878
# [2024/10/04 12:13:44] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:44] ppocr DEBUG: dt_boxes num : 99, elapsed : 0.11839723587036133
# [2024/10/04 12:13:46] ppocr DEBUG: rec_res num  : 99, elapsed : 2.1592962741851807
# [2024/10/04 12:13:46] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:46] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.1290895938873291
# [2024/10/04 12:13:48] ppocr DEBUG: rec_res num  : 31, elapsed : 1.565751314163208
# [2024/10/04 12:13:48] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:48] ppocr DEBUG: dt_boxes num : 155, elapsed : 0.13141322135925293
# [2024/10/04 12:13:51] ppocr DEBUG: rec_res num  : 155, elapsed : 3.213085651397705
# [2024/10/04 12:13:51] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:51] ppocr DEBUG: dt_boxes num : 45, elapsed : 0.11081838607788086
# [2024/10/04 12:13:52] ppocr DEBUG: rec_res num  : 45, elapsed : 0.9308319091796875
# [2024/10/04 12:13:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:52] ppocr DEBUG: dt_boxes num : 119, elapsed : 0.12018609046936035
# [2024/10/04 12:13:55] ppocr DEBUG: rec_res num  : 119, elapsed : 2.770078659057617
# [2024/10/04 12:13:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:55] ppocr DEBUG: dt_boxes num : 79, elapsed : 0.13962173461914062
# [2024/10/04 12:13:57] ppocr DEBUG: rec_res num  : 79, elapsed : 1.7518281936645508
# [2024/10/04 12:13:57] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:57] ppocr DEBUG: dt_boxes num : 41, elapsed : 0.10965180397033691
# [2024/10/04 12:13:59] ppocr DEBUG: rec_res num  : 41, elapsed : 1.2793655395507812
# [2024/10/04 12:13:59] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:13:59] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.11859488487243652
# [2024/10/04 12:14:00] ppocr DEBUG: rec_res num  : 30, elapsed : 1.2102153301239014
# [2024/10/04 12:14:00] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:00] ppocr DEBUG: dt_boxes num : 32, elapsed : 0.10794615745544434
# [2024/10/04 12:14:02] ppocr DEBUG: rec_res num  : 32, elapsed : 1.7649905681610107
# [2024/10/04 12:14:02] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:02] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.11862564086914062
# [2024/10/04 12:14:04] ppocr DEBUG: rec_res num  : 36, elapsed : 1.3107919692993164
# [2024/10/04 12:14:04] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:04] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.10750532150268555
# [2024/10/04 12:14:06] ppocr DEBUG: rec_res num  : 27, elapsed : 2.166451930999756
# [2024/10/04 12:14:06] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:06] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.1314234733581543
# [2024/10/04 12:14:09] ppocr DEBUG: rec_res num  : 29, elapsed : 2.7744662761688232
# [2024/10/04 12:14:09] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:09] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.10998392105102539
# [2024/10/04 12:14:12] ppocr DEBUG: rec_res num  : 29, elapsed : 2.4644880294799805
# [2024/10/04 12:14:12] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:12] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.1069033145904541
# [2024/10/04 12:14:14] ppocr DEBUG: rec_res num  : 24, elapsed : 1.9382858276367188
# [2024/10/04 12:14:14] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:14] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.10710525512695312
# [2024/10/04 12:14:15] ppocr DEBUG: rec_res num  : 23, elapsed : 1.3094425201416016
# [2024/10/04 12:14:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:15] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.10794448852539062
# [2024/10/04 12:14:16] ppocr DEBUG: rec_res num  : 25, elapsed : 1.1388611793518066
# [2024/10/04 12:14:17] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:17] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.13157105445861816
# [2024/10/04 12:14:19] ppocr DEBUG: rec_res num  : 26, elapsed : 1.994391679763794
# [2024/10/04 12:14:19] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:19] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.12916827201843262
# [2024/10/04 12:14:21] ppocr DEBUG: rec_res num  : 27, elapsed : 2.0580735206604004
# [2024/10/04 12:14:21] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:21] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.12378358840942383
# [2024/10/04 12:14:23] ppocr DEBUG: rec_res num  : 28, elapsed : 2.242474317550659
# [2024/10/04 12:14:24] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:24] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.1257951259613037
# [2024/10/04 12:14:26] ppocr DEBUG: rec_res num  : 28, elapsed : 2.7782814502716064
# [2024/10/04 12:14:26] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:27] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.10524535179138184
# [2024/10/04 12:14:28] ppocr DEBUG: rec_res num  : 25, elapsed : 1.6089179515838623
# [2024/10/04 12:14:28] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:28] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.10996651649475098
# [2024/10/04 12:14:30] ppocr DEBUG: rec_res num  : 26, elapsed : 1.8273611068725586
# [2024/10/04 12:14:30] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:30] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.10643386840820312
# [2024/10/04 12:14:32] ppocr DEBUG: rec_res num  : 26, elapsed : 1.9604110717773438
# [2024/10/04 12:14:32] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:33] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.1070711612701416
# [2024/10/04 12:14:33] ppocr DEBUG: rec_res num  : 23, elapsed : 0.5716099739074707
# [2024/10/04 12:14:33] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:33] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.10593557357788086
# [2024/10/04 12:14:35] ppocr DEBUG: rec_res num  : 27, elapsed : 2.1261179447174072
# [2024/10/04 12:14:35] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/04 12:14:36] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.10735583305358887
# [2024/10/04 12:14:38] ppocr DEBUG: rec_res num  : 28, elapsed : 2.179713249206543

# %%
extracted_data
# Out:
# [{'page_num': 0,
#   'text': [([[405.0, 41.0], [508.0, 43.0], [508.0, 57.0], [405.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9451141953468323)),
#    ([[92.0, 92.0], [175.0, 92.0], [175.0, 109.0], [92.0, 109.0]],
#     ('一、适用范围', 0.9990265369415283)),
#    ([[115.0, 141.0], [506.0, 141.0], [506.0, 155.0], [115.0, 155.0]],
#     ('本指南旨在提供我国的化妆品主要出口目标国家（地区）在化妆品标签方面', 0.9992008805274963)),
#    ([[90.0, 165.0], [505.0, 165.0], [505.0, 178.0], [90.0, 178.0]],
#     ('的法规、标准、要求以及与我国的差异，提出达到目标市场要求的建议和指南。', 0.9996585249900818)),
#    ([[89.0, 187.0], [313.0, 187.0], [313.0, 201.0], [89.0, 201.0]],
#     ('适用于所有出口或准备出口的化妆品企业。', 0.9998819231987)),
#    ([[118.0, 549.0], [428.0, 241.0], [490.0, 307.0], [180.0, 615.0]],
#     ('MOFCOM', 0.9954840540885925))],
#   'images': [('image_0_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 1,
#   'text': [([[89.0, 44.0], [189.0, 44.0], [189.0, 57.0], [89.0, 57.0]],
#     ('各国化妆品标签管理指南', 0.9979879260063171)),
#    ([[90.0, 94.0], [285.0, 94.0], [285.0, 108.0], [90.0, 108.0]],
#     ('二、进出口化妆品基本情况概述', 0.999260425567627)),
#    ([[89.0, 144.0], [174.0, 144.0], [174.0, 157.0], [89.0, 157.0]],
#     ('2.1术语和定义', 0.9997022747993469)),
#    ([[90.0, 181.0], [505.0, 181.0], [505.0, 195.0], [90.0, 195.0]],
#     ('化妆品cosmetios：指以涂抹、洒、喷或其它类似方式，施于人体表面任何部位', 0.9857862591743469)),
#    ([[96.0, 205.0], [498.0, 205.0], [498.0, 219.0], [96.0, 219.0]],
#     ('（皮肤、毛发、指甲、口唇）、牙齿和口腔粘膜，以达到清洁、芳香、改变外观、', 0.9985296726226807)),
#    ([[90.0, 229.0], [347.0, 229.0], [347.0, 242.0], [90.0, 242.0]],
#     ('修正人体气味、保养、保持良好状态目的的产品。', 0.9984531402587891)),
#    ([[89.0, 259.0], [504.0, 258.0], [504.0, 272.0], [89.0, 273.0]],
#     ('标签labelling：指粘贴或连接或印在化妆品销售包装上的文字、数字、符号、', 0.9755491614341736)),
#    ([[91.0, 283.0], [287.0, 283.0], [287.0, 297.0], [91.0, 297.0]],
#     ('图案和置于销售包装内的说明性材料。', 0.999472439289093)),
#    ([[88.0, 312.0], [506.0, 313.0], [506.0, 330.0], [88.0, 329.0]],
#     ('销售包装salespaokaging：指以销售为目的，与内装物一起交付给消费者的包', 0.9816380739212036)),
#    ([[88.0, 336.0], [109.0, 336.0], [109.0, 352.0], [88.0, 352.0]],
#     ('装。', 0.9995137453079224)),
#    ([[90.0, 369.0], [331.0, 369.0], [331.0, 384.0], [90.0, 384.0]],
#     ('内装物contents：指包装容器内所装的产品。', 0.9965500831604004)),
#    ([[88.0, 399.0], [506.0, 398.0], [506.0, 415.0], [88.0, 416.0]],
#     ('展示面displaypanels：指化妆品在陈列时，在自然状态下被消费者能看见的', 0.9871761202812195)),
#    ([[88.0, 422.0], [109.0, 422.0], [109.0, 438.0], [88.0, 438.0]],
#     ('面。', 0.9992498159408569)),
#    ([[90.0, 454.0], [505.0, 454.0], [505.0, 469.0], [90.0, 469.0]],
#     ('可视面visiblepanels：指化妆品在不破坏销售包装的情况下，消费者能够看', 0.9758085012435913)),
#    ([[90.0, 480.0], [154.0, 480.0], [154.0, 491.0], [90.0, 491.0]],
#     ('到的任何面。', 0.99381422996521)),
#    ([[89.0, 509.0], [506.0, 509.0], [506.0, 523.0], [89.0, 523.0]],
#     ('净含量netcontent：指去除包装容器和其它包装材料后，内装物的实际质量或', 0.9906005859375)),
#    ([[90.0, 532.0], [155.0, 532.0], [155.0, 546.0], [90.0, 546.0]],
#     ('体积或长度。', 0.9999301433563232)),
#    ([[90.0, 565.0], [505.0, 565.0], [505.0, 579.0], [90.0, 579.0]],
#     ('保质期sheIflife：指在化妆品产品标准和标签规定的条件下，保持化妆品品', 0.9705767631530762)),
#    ([[90.0, 586.0], [505.0, 587.0], [505.0, 601.0], [90.0, 600.0]],
#     ('质的期限。在此期限内，化妆品完全适于销售，并符合产品标准和标签中所规定', 0.9996584057807922)),
#    ([[91.0, 611.0], [131.0, 611.0], [131.0, 622.0], [91.0, 622.0]],
#     ('的品质。', 0.9970190525054932)),
#    ([[90.0, 643.0], [505.0, 643.0], [505.0, 657.0], [90.0, 657.0]],
#     ('限期使用日期expirationdate：指在化妆品产品标准和标签规定的条件下，化', 0.9800108075141907)),
#    ([[90.0, 666.0], [505.0, 666.0], [505.0, 679.0], [90.0, 679.0]],
#     ('妆品最佳的使用日期。在此期限内，化妆品完全适于销售，并符合产品标准和标', 0.9988508224487305)),
#    ([[90.0, 688.0], [505.0, 688.0], [505.0, 701.0], [90.0, 701.0]],
#     ('签上所规定的品质。超过此期限，化妆品的品质可能会发生变化，此化妆品不再', 0.9995778799057007)),
#    ([[91.0, 713.0], [142.0, 713.0], [142.0, 725.0], [91.0, 725.0]],
#     ('适于销售。', 0.9933215379714966)),
#    ([[90.0, 744.0], [420.0, 744.0], [420.0, 758.0], [90.0, 758.0]],
#     ('裸装产品primarypaokagingproduct：指一次包装的化妆品。', 0.9835028648376465))],
#   'images': [('image_1_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 2,
#   'text': [([[405.0, 41.0], [507.0, 43.0], [507.0, 57.0], [405.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9418863654136658)),
#    ([[116.0, 77.0], [507.0, 77.0], [507.0, 91.0], [116.0, 91.0]],
#     ('本指南中涉及的商品为化妆品产品，该类产品对应的海关出口目录商品编码', 0.9992119669914246)),
#    ([[90.0, 100.0], [488.0, 100.0], [488.0, 114.0], [90.0, 114.0]],
#     ('如表2.1所示（数据来自中华人民共和国海关总署编《中国海关统计年鉴》）。', 0.9941040873527527)),
#    ([[192.0, 132.0], [404.0, 132.0], [404.0, 146.0], [192.0, 146.0]],
#     ('表2.1化妆品类产品对应海关编码列表', 0.9997873306274414)),
#    ([[217.0, 163.0], [262.0, 163.0], [262.0, 178.0], [217.0, 178.0]],
#     ('产品名称', 0.9967630505561829)),
#    ([[378.0, 162.0], [470.0, 162.0], [470.0, 176.0], [378.0, 176.0]],
#     ('商品编号（海关编）', 0.9835575819015503)),
#    ([[115.0, 186.0], [318.0, 186.0], [318.0, 200.0], [115.0, 200.0]],
#     ('精油包括浸膏及净油：香膏：提取的油树脂', 0.9931473135948181)),
#    ([[371.0, 186.0], [396.0, 186.0], [396.0, 201.0], [371.0, 201.0]],
#     ('3301', 0.999460756778717)),
#    ([[114.0, 208.0], [139.0, 208.0], [139.0, 224.0], [114.0, 224.0]],
#     ('橙油', 0.9983287453651428)),
#    ([[372.0, 209.0], [418.0, 209.0], [418.0, 224.0], [372.0, 224.0]],
#     ('33011200', 0.9491865634918213)),
#    ([[114.0, 232.0], [149.0, 232.0], [149.0, 247.0], [114.0, 247.0]],
#     ('柠檬油', 0.9684562683105469)),
#    ([[372.0, 233.0], [418.0, 233.0], [418.0, 247.0], [372.0, 247.0]],
#     ('33011300', 0.9998980164527893)),
#    ([[115.0, 255.0], [207.0, 255.0], [207.0, 269.0], [115.0, 269.0]],
#     ('白柠檬油（酸橙油）', 0.9651088714599609)),
#    ([[371.0, 254.0], [419.0, 256.0], [418.0, 271.0], [370.0, 269.0]],
#     ('33011910', 0.999753475189209)),
#    ([[116.0, 278.0], [211.0, 278.0], [211.0, 292.0], [116.0, 292.0]],
#     ('其他柑橘属果实精油', 0.9964010715484619)),
#    ([[371.0, 276.0], [418.0, 279.0], [417.0, 294.0], [370.0, 291.0]],
#     ('33011990', 0.9997824430465698)),
#    ([[116.0, 303.0], [170.0, 303.0], [170.0, 317.0], [116.0, 317.0]],
#     ('胡椒薄荷油', 0.9964224100112915)),
#    ([[372.0, 303.0], [419.0, 303.0], [419.0, 317.0], [372.0, 317.0]],
#     ('33012400', 0.9998972415924072)),
#    ([[115.0, 324.0], [171.0, 324.0], [171.0, 341.0], [115.0, 341.0]],
#     ('其他薄荷油', 0.9984683990478516)),
#    ([[372.0, 326.0], [419.0, 326.0], [419.0, 340.0], [372.0, 340.0]],
#     ('33012500', 0.9998336434364319)),
#    ([[114.0, 346.0], [151.0, 346.0], [151.0, 364.0], [114.0, 364.0]],
#     ('樟脑油', 0.9998679161071777)),
#    ([[372.0, 348.0], [418.0, 348.0], [418.0, 363.0], [372.0, 363.0]],
#     ('33012910', 0.9998713731765747)),
#    ([[115.0, 371.0], [149.0, 371.0], [149.0, 387.0], [115.0, 387.0]],
#     ('香茅油', 0.9986706376075745)),
#    ([[371.0, 369.0], [418.0, 372.0], [417.0, 387.0], [370.0, 384.0]],
#     ('33012920', 0.9996537566184998)),
#    ([[114.0, 395.0], [149.0, 395.0], [149.0, 410.0], [114.0, 410.0]],
#     ('茴香油', 0.9991510510444641)),
#    ([[372.0, 395.0], [418.0, 395.0], [418.0, 409.0], [372.0, 409.0]],
#     ('33012930', 0.9995846748352051)),
#    ([[114.0, 417.0], [138.0, 417.0], [138.0, 433.0], [114.0, 433.0]],
#     ('桂油', 0.9994437098503113)),
#    ([[372.0, 419.0], [418.0, 419.0], [418.0, 433.0], [372.0, 433.0]],
#     ('33012940', 0.9998928308486938)),
#    ([[115.0, 441.0], [160.0, 441.0], [160.0, 456.0], [115.0, 456.0]],
#     ('山苍子油', 0.9986871480941772)),
#    ([[372.0, 441.0], [418.0, 441.0], [418.0, 455.0], [372.0, 455.0]],
#     ('33012950', 0.9998805522918701)),
#    ([[114.0, 462.0], [150.0, 462.0], [150.0, 481.0], [114.0, 481.0]],
#     ('桉叶油', 0.905238151550293)),
#    ([[372.0, 465.0], [418.0, 465.0], [418.0, 479.0], [372.0, 479.0]],
#     ('33012960', 0.9999063014984131)),
#    ([[116.0, 488.0], [208.0, 488.0], [208.0, 502.0], [116.0, 502.0]],
#     ('老鹤草油（香叶油）', 0.9305031299591064)),
#    ([[372.0, 488.0], [417.0, 488.0], [417.0, 502.0], [372.0, 502.0]],
#     ('33012991', 0.9998875856399536)),
#    ([[114.0, 510.0], [233.0, 509.0], [233.0, 526.0], [114.0, 527.0]],
#     ('未列名非柑橘属果实精油', 0.9954932928085327)),
#    ([[372.0, 511.0], [418.0, 511.0], [418.0, 525.0], [372.0, 525.0]],
#     ('33012999', 0.9999085068702698)),
#    ([[116.0, 534.0], [160.0, 534.0], [160.0, 550.0], [116.0, 550.0]],
#     ('鸢尾凝脂', 0.9854562282562256)),
#    ([[371.0, 533.0], [418.0, 536.0], [417.0, 550.0], [370.0, 547.0]],
#     ('33013010', 0.9996578693389893)),
#    ([[115.0, 557.0], [160.0, 557.0], [160.0, 572.0], [115.0, 572.0]],
#     ('其他香膏', 0.9974592328071594)),
#    ([[372.0, 558.0], [418.0, 558.0], [418.0, 572.0], [372.0, 572.0]],
#     ('33013090', 0.9998908042907715)),
#    ([[113.0, 579.0], [182.0, 579.0], [182.0, 596.0], [113.0, 596.0]],
#     ('提取的油树脂', 0.9991545081138611)),
#    ([[372.0, 581.0], [418.0, 581.0], [418.0, 595.0], [372.0, 595.0]],
#     ('33019010', 0.9998608827590942)),
#    ([[115.0, 603.0], [285.0, 603.0], [285.0, 617.0], [115.0, 617.0]],
#     ('柑桔属果实的精油脱的烯副产品', 0.9837990403175354)),
#    ([[372.0, 603.0], [419.0, 603.0], [419.0, 618.0], [372.0, 618.0]],
#     ('33019020', 0.9983241558074951)),
#    ([[116.0, 627.0], [327.0, 627.0], [327.0, 642.0], [116.0, 642.0]],
#     ('含浓缩精油的制品：其他烯副产品及精油液', 0.9991562366485596)),
#    ([[371.0, 624.0], [418.0, 627.0], [417.0, 642.0], [370.0, 639.0]],
#     ('33019090', 0.9997878074645996)),
#    ([[115.0, 651.0], [180.0, 651.0], [180.0, 665.0], [115.0, 665.0]],
#     ('香水及花露水', 0.9993675351142883)),
#    ([[371.0, 650.0], [397.0, 650.0], [397.0, 665.0], [371.0, 665.0]],
#     ('3303', 0.9993913173675537)),
#    ([[116.0, 674.0], [180.0, 674.0], [180.0, 688.0], [116.0, 688.0]],
#     ('香水及花露水', 0.9959778189659119)),
#    ([[372.0, 674.0], [418.0, 674.0], [418.0, 688.0], [372.0, 688.0]],
#     ('33030000', 0.9998859763145447)),
#    ([[115.0, 696.0], [327.0, 696.0], [327.0, 710.0], [115.0, 710.0]],
#     ('美容品或化妆品及护肤品：指（趾）甲化妆品', 0.9964768290519714)),
#    ([[371.0, 696.0], [397.0, 696.0], [397.0, 711.0], [371.0, 711.0]],
#     ('3304', 0.9995262026786804)),
#    ([[115.0, 720.0], [170.0, 720.0], [170.0, 734.0], [115.0, 734.0]],
#     ('唇用化妆品', 0.9998654127120972)),
#    ([[371.0, 717.0], [418.0, 720.0], [417.0, 735.0], [370.0, 732.0]],
#     ('33041000', 0.9992324113845825)),
#    ([[113.0, 742.0], [171.0, 742.0], [171.0, 759.0], [113.0, 759.0]],
#     ('眼用化妆品', 0.9989674687385559)),
#    ([[372.0, 743.0], [418.0, 743.0], [418.0, 757.0], [372.0, 757.0]],
#     ('33042000', 0.99992835521698)),
#    ([[501.0, 774.0], [506.0, 774.0], [506.0, 780.0], [501.0, 780.0]],
#     ('3', 0.9547929167747498))],
#   'images': [('image_2_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 3,
#   'text': [([[88.0, 43.0], [191.0, 43.0], [191.0, 56.0], [88.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9980707764625549)),
#    ([[95.0, 77.0], [134.0, 77.0], [134.0, 91.0], [95.0, 91.0]],
#     ('（续表）', 0.9743772149085999)),
#    ([[216.0, 100.0], [262.0, 100.0], [262.0, 114.0], [216.0, 114.0]],
#     ('产品名称', 0.998157262802124)),
#    ([[378.0, 100.0], [470.0, 100.0], [470.0, 114.0], [378.0, 114.0]],
#     ('商品编号（海关编）', 0.988210916519165)),
#    ([[115.0, 123.0], [201.0, 123.0], [201.0, 138.0], [115.0, 138.0]],
#     ('指（趾）甲化妆品', 0.9971671104431152)),
#    ([[372.0, 123.0], [418.0, 123.0], [418.0, 138.0], [372.0, 138.0]],
#     ('33043000', 0.9999027252197266)),
#    ([[116.0, 147.0], [212.0, 147.0], [212.0, 161.0], [116.0, 161.0]],
#     ('香粉，不论是否压紧', 0.9993979930877686)),
#    ([[372.0, 147.0], [419.0, 147.0], [419.0, 161.0], [372.0, 161.0]],
#     ('33049100', 0.9999167323112488)),
#    ([[116.0, 171.0], [253.0, 171.0], [253.0, 184.0], [116.0, 184.0]],
#     ('其他美容品或化妆品及护肤品', 0.977044403553009)),
#    ([[372.0, 171.0], [418.0, 171.0], [418.0, 185.0], [372.0, 185.0]],
#     ('33049900', 0.9996337890625)),
#    ([[114.0, 193.0], [149.0, 193.0], [149.0, 207.0], [114.0, 207.0]],
#     ('护发品', 0.997715175151825)),
#    ([[371.0, 193.0], [396.0, 193.0], [396.0, 208.0], [371.0, 208.0]],
#     ('3305', 0.9992895126342773)),
#    ([[114.0, 217.0], [186.0, 217.0], [186.0, 231.0], [114.0, 231.0]],
#     ('洗发剂（香波）', 0.950261116027832)),
#    ([[372.0, 217.0], [418.0, 217.0], [418.0, 231.0], [372.0, 231.0]],
#     ('33051000', 0.999923586845398)),
#    ([[114.0, 239.0], [150.0, 239.0], [150.0, 254.0], [114.0, 254.0]],
#     ('烫发剂', 0.9970018267631531)),
#    ([[372.0, 240.0], [419.0, 240.0], [419.0, 254.0], [372.0, 254.0]],
#     ('33052000', 0.9999262690544128)),
#    ([[114.0, 263.0], [150.0, 263.0], [150.0, 278.0], [114.0, 278.0]],
#     ('定型剂', 0.9999197125434875)),
#    ([[372.0, 262.0], [418.0, 262.0], [418.0, 276.0], [372.0, 276.0]],
#     ('33053000', 0.9997072219848633)),
#    ([[116.0, 286.0], [170.0, 286.0], [170.0, 301.0], [116.0, 301.0]],
#     ('其他护发品', 0.9997787475585938)),
#    ([[372.0, 286.0], [418.0, 286.0], [418.0, 301.0], [372.0, 301.0]],
#     ('33059000', 0.9998867511749268)),
#    ([[116.0, 310.0], [333.0, 310.0], [333.0, 324.0], [116.0, 324.0]],
#     ('口腔及牙齿清洁剂：清洁牙缝用的纱线（牙线）', 0.9914299845695496)),
#    ([[371.0, 309.0], [397.0, 309.0], [397.0, 324.0], [371.0, 324.0]],
#     ('3306', 0.9991181492805481)),
#    ([[115.0, 332.0], [139.0, 332.0], [139.0, 348.0], [115.0, 348.0]],
#     ('牙膏', 0.8407451510429382)),
#    ([[372.0, 333.0], [419.0, 333.0], [419.0, 347.0], [372.0, 347.0]],
#     ('33061010', 0.9996289014816284)),
#    ([[115.0, 355.0], [170.0, 355.0], [170.0, 369.0], [115.0, 369.0]],
#     ('其他洁齿品', 0.9987064599990845)),
#    ([[372.0, 355.0], [418.0, 355.0], [418.0, 369.0], [372.0, 369.0]],
#     ('33061090', 0.9997744560241699)),
#    ([[114.0, 380.0], [229.0, 380.0], [229.0, 394.0], [114.0, 394.0]],
#     ('清洁牙缝用纱线（牙线）', 0.9921144843101501)),
#    ([[371.0, 378.0], [418.0, 378.0], [418.0, 393.0], [371.0, 393.0]],
#     ('33062000', 0.9998467564582825)),
#    ([[115.0, 403.0], [171.0, 403.0], [171.0, 417.0], [115.0, 417.0]],
#     ('口腔清洁剂', 0.9996261596679688)),
#    ([[372.0, 403.0], [418.0, 403.0], [418.0, 417.0], [372.0, 417.0]],
#     ('33069000', 0.9999315142631531)),
#    ([[115.0, 425.0], [237.0, 425.0], [237.0, 439.0], [115.0, 439.0]],
#     ('芳香料制品及化妆盟洗品：', 0.9957506060600281)),
#    ([[372.0, 426.0], [396.0, 426.0], [396.0, 438.0], [372.0, 438.0]],
#     ('3307', 0.999220609664917)),
#    ([[115.0, 448.0], [171.0, 448.0], [171.0, 462.0], [115.0, 462.0]],
#     ('剃须用制剂', 0.9965906143188477)),
#    ([[372.0, 448.0], [418.0, 448.0], [418.0, 462.0], [372.0, 462.0]],
#     ('33071000', 0.9998942017555237)),
#    ([[116.0, 472.0], [213.0, 472.0], [213.0, 486.0], [116.0, 486.0]],
#     ('人体除臭剂及止汗剂', 0.9939940571784973)),
#    ([[372.0, 472.0], [418.0, 472.0], [418.0, 486.0], [372.0, 486.0]],
#     ('33072000', 0.9999265074729919)),
#    ([[117.0, 496.0], [232.0, 496.0], [232.0, 510.0], [117.0, 510.0]],
#     ('香浴盐及其他沐浴用制剂', 0.997938871383667)),
#    ([[372.0, 495.0], [419.0, 495.0], [419.0, 509.0], [372.0, 509.0]],
#     ('33073000', 0.9999250769615173)),
#    ([[115.0, 519.0], [316.0, 519.0], [316.0, 532.0], [115.0, 532.0]],
#     ('脱毛剂和未列名的芳香料制品及化妆盟洗品', 0.9870427846908569)),
#    ([[371.0, 516.0], [418.0, 518.0], [417.0, 534.0], [370.0, 531.0]],
#     ('33079000', 0.9994661808013916)),
#    ([[87.0, 555.0], [210.0, 556.0], [210.0, 573.0], [87.0, 572.0]],
#     ('2.2最新海关统计口径', 0.9996294379234314)),
#    ([[89.0, 595.0], [358.0, 595.0], [358.0, 609.0], [89.0, 609.0]],
#     ('统计口径为：该类产品的年度进出口总金额及数量。', 0.9995683431625366)),
#    ([[88.0, 634.0], [245.0, 634.0], [245.0, 648.0], [88.0, 648.0]],
#     ('2.3近5年来的进出口额统计', 0.9997530579566956)),
#    ([[87.0, 673.0], [318.0, 672.0], [318.0, 686.0], [87.0, 687.0]],
#     ('2.3.12007~2011年中国化妆品进出口额统计', 0.9927759766578674)),
#    ([[114.0, 711.0], [506.0, 711.0], [506.0, 725.0], [114.0, 725.0]],
#     ('近5年来，我国化妆品进出口总体呈现增长趋势，且近两年增长迅速。据统', 0.9971477389335632)),
#    ([[90.0, 735.0], [505.0, 735.0], [505.0, 749.0], [90.0, 749.0]],
#     ('计数据显示，2011年较2007年，我国化妆品出口数量增长42.77万吨，增幅达', 0.9994794726371765))],
#   'images': [('image_3_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 4,
#   'text': [([[406.0, 41.0], [507.0, 43.0], [507.0, 57.0], [406.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9510166049003601)),
#    ([[90.0, 77.0], [506.0, 77.0], [506.0, 91.0], [90.0, 91.0]],
#     ('175.51%，出口金额增长14.93亿美元，增幅达145.17%：化妆品进口数量上增', 0.9990782737731934)),
#    ([[90.0, 100.0], [496.0, 100.0], [496.0, 114.0], [90.0, 114.0]],
#     ('长5.51万吨，增幅达103.50%，进口金额增长14.74亿美元，增幅达214.34%，', 0.9887082576751709)),
#    ([[114.0, 124.0], [505.0, 124.0], [505.0, 138.0], [114.0, 138.0]],
#     ('我国化妆品贸易主要以出口为主。随着结构的调整，近年逐步趋向进出口贸', 0.9977100491523743)),
#    ([[91.0, 147.0], [506.0, 147.0], [506.0, 161.0], [91.0, 161.0]],
#     ('易平衡。据统计数据显示，2007年到2011年，我国化妆品贸易顺差由3.41亿美', 0.9996326565742493)),
#    ([[90.0, 171.0], [498.0, 171.0], [498.0, 185.0], [90.0, 185.0]],
#     ('元下滑至0.00亿美元，继而小幅增长至3.60亿美元，走势渐趋平稳。这一期间，', 0.9974740147590637)),
#    ([[89.0, 193.0], [499.0, 194.0], [499.0, 208.0], [89.0, 207.0]],
#     ('我国化妆品进出口贸易总额由17.16亿美元增至46.84亿美元，增幅达172.88%。', 0.998345136642456)),
#    ([[114.0, 218.0], [498.0, 218.0], [498.0, 231.0], [114.0, 231.0]],
#     ('相比贸易值的快速增长，我国化妆品在质的方面还存在较大劣势。2007年，', 0.9993734359741211)),
#    ([[90.0, 241.0], [506.0, 241.0], [506.0, 255.0], [90.0, 255.0]],
#     ('化妆品进口平均单价为12.92美元/千克，出口平均单价为4.22美元/千克，为进', 0.979113757610321)),
#    ([[90.0, 264.0], [506.0, 264.0], [506.0, 278.0], [90.0, 278.0]],
#     ('口单价的32.66%：2011年，化妆品进口平均单价为19.96美元/千克，出口平均', 0.9882999658584595)),
#    ([[91.0, 288.0], [498.0, 288.0], [498.0, 302.0], [91.0, 302.0]],
#     ('单价为3.76美元/千克，为进口单价的18.84%。可以看出，差距仍在进一步扩大。', 0.9872414469718933)),
#    ([[90.0, 312.0], [506.0, 312.0], [506.0, 325.0], [90.0, 325.0]],
#     ('这种价格方面的劣势说明我国出口化妆品含金量低，维持贸易增长是建立在大量', 0.9994148015975952)),
#    ([[90.0, 334.0], [506.0, 334.0], [506.0, 348.0], [90.0, 348.0]],
#     ('出口基础上，是以价值牺牲为代价换取的。这种状况给我国的化妆品生产企业提', 0.997650682926178)),
#    ([[90.0, 358.0], [419.0, 358.0], [419.0, 372.0], [90.0, 372.0]],
#     ('出了非常严峻的课题，应尽快改善产品质量，大力提高附加值。', 0.9986592531204224)),
#    ([[151.0, 389.0], [445.0, 389.0], [445.0, 403.0], [151.0, 403.0]],
#     ('表2.22007-2011年我国化妆品出口数量、金额一览表', 0.9711916446685791)),
#    ([[103.0, 427.0], [128.0, 427.0], [128.0, 442.0], [103.0, 442.0]],
#     ('年份', 0.9995619058609009)),
#    ([[164.0, 420.0], [188.0, 420.0], [188.0, 432.0], [164.0, 432.0]],
#     ('数量', 0.9994940757751465)),
#    ([[220.0, 419.0], [256.0, 419.0], [256.0, 433.0], [220.0, 433.0]],
#     ('增长量', 0.99994295835495)),
#    ([[279.0, 419.0], [319.0, 419.0], [319.0, 433.0], [279.0, 433.0]],
#     ('增长率', 0.9998045563697815)),
#    ([[346.0, 420.0], [371.0, 420.0], [371.0, 432.0], [346.0, 432.0]],
#     ('金额', 0.9998712539672852)),
#    ([[402.0, 419.0], [438.0, 419.0], [438.0, 433.0], [402.0, 433.0]],
#     ('增长量', 0.9999608397483826)),
#    ([[462.0, 419.0], [498.0, 419.0], [498.0, 433.0], [462.0, 433.0]],
#     ('增长率', 0.999785840511322)),
#    ([[158.0, 435.0], [194.0, 435.0], [194.0, 449.0], [158.0, 449.0]],
#     ('（万吨）', 0.9839705228805542)),
#    ([[219.0, 435.0], [256.0, 435.0], [256.0, 449.0], [219.0, 449.0]],
#     ('（万吨）', 0.9856586456298828)),
#    ([[284.0, 434.0], [311.0, 434.0], [311.0, 449.0], [284.0, 449.0]],
#     ('（%）', 0.7216063141822815)),
#    ([[338.0, 435.0], [384.0, 435.0], [384.0, 449.0], [338.0, 449.0]],
#     ('（亿美元）', 0.9890484809875488)),
#    ([[398.0, 435.0], [444.0, 435.0], [444.0, 449.0], [398.0, 449.0]],
#     ('（亿美元）', 0.990399956703186)),
#    ([[469.0, 436.0], [492.0, 436.0], [492.0, 448.0], [469.0, 448.0]],
#     ('(%)', 0.8231520652770996)),
#    ([[102.0, 454.0], [128.0, 454.0], [128.0, 470.0], [102.0, 470.0]],
#     ('2007', 0.9373417496681213)),
#    ([[161.0, 454.0], [190.0, 454.0], [190.0, 470.0], [161.0, 470.0]],
#     ('24.37', 0.9996880292892456)),
#    ([[292.0, 457.0], [303.0, 457.0], [303.0, 468.0], [292.0, 468.0]],
#     ('一', 0.6546263694763184)),
#    ([[345.0, 454.0], [373.0, 454.0], [373.0, 470.0], [345.0, 470.0]],
#     ('10.29', 0.9997460246086121)),
#    ([[413.0, 456.0], [425.0, 456.0], [425.0, 470.0], [413.0, 470.0]],
#     ('一', 0.7744161486625671)),
#    ([[102.0, 479.0], [128.0, 479.0], [128.0, 494.0], [102.0, 494.0]],
#     ('2008', 0.9995317459106445)),
#    ([[162.0, 478.0], [191.0, 478.0], [191.0, 493.0], [162.0, 493.0]],
#     ('20.20', 0.9998615980148315)),
#    ([[224.0, 478.0], [250.0, 478.0], [250.0, 493.0], [224.0, 493.0]],
#     ('-4.17', 0.9464367628097534)),
#    ([[281.0, 478.0], [313.0, 478.0], [313.0, 493.0], [281.0, 493.0]],
#     ('-17.11', 0.9960128664970398)),
#    ([[346.0, 478.0], [372.0, 478.0], [372.0, 493.0], [346.0, 493.0]],
#     ('9.36', 0.9998431205749512)),
#    ([[408.0, 478.0], [433.0, 478.0], [433.0, 494.0], [408.0, 494.0]],
#     ('-0.93', 0.9675467610359192)),
#    ([[468.0, 478.0], [493.0, 478.0], [493.0, 494.0], [468.0, 494.0]],
#     ('-9.04', 0.97443026304245)),
#    ([[102.0, 501.0], [128.0, 501.0], [128.0, 516.0], [102.0, 516.0]],
#     ('2009', 0.9277326464653015)),
#    ([[162.0, 501.0], [190.0, 501.0], [190.0, 516.0], [162.0, 516.0]],
#     ('31.37', 0.9996448755264282)),
#    ([[222.0, 501.0], [252.0, 501.0], [252.0, 516.0], [222.0, 516.0]],
#     ('11.17', 0.967769980430603)),
#    ([[283.0, 501.0], [313.0, 501.0], [313.0, 516.0], [283.0, 516.0]],
#     ('55.30', 0.9995831251144409)),
#    ([[345.0, 501.0], [373.0, 501.0], [373.0, 516.0], [345.0, 516.0]],
#     ('11.66', 0.9999440908432007)),
#    ([[408.0, 501.0], [431.0, 501.0], [431.0, 516.0], [408.0, 516.0]],
#     ('2.30', 0.9995808005332947)),
#    ([[466.0, 501.0], [495.0, 501.0], [495.0, 516.0], [466.0, 516.0]],
#     ('24.57', 0.9998180270195007)),
#    ([[102.0, 524.0], [129.0, 524.0], [129.0, 539.0], [102.0, 539.0]],
#     ('2010', 0.9654078483581543)),
#    ([[162.0, 524.0], [191.0, 524.0], [191.0, 539.0], [162.0, 539.0]],
#     ('41.58', 0.9995952844619751)),
#    ([[224.0, 525.0], [251.0, 525.0], [251.0, 538.0], [224.0, 538.0]],
#     ('10.21', 0.9995177984237671)),
#    ([[285.0, 525.0], [313.0, 525.0], [313.0, 538.0], [285.0, 538.0]],
#     ('32.55', 0.9995923042297363)),
#    ([[345.0, 524.0], [373.0, 524.0], [373.0, 539.0], [345.0, 539.0]],
#     ('17.50', 0.999881386756897)),
#    ([[408.0, 524.0], [432.0, 524.0], [432.0, 539.0], [408.0, 539.0]],
#     ('5.84', 0.9997254014015198)),
#    ([[467.0, 524.0], [495.0, 524.0], [495.0, 539.0], [467.0, 539.0]],
#     ('50.09', 0.9998752474784851)),
#    ([[102.0, 546.0], [128.0, 546.0], [128.0, 562.0], [102.0, 562.0]],
#     ('2011', 0.9997475147247314)),
#    ([[161.0, 546.0], [191.0, 546.0], [191.0, 562.0], [161.0, 562.0]],
#     ('67.14', 0.9981328845024109)),
#    ([[222.0, 546.0], [252.0, 546.0], [252.0, 562.0], [222.0, 562.0]],
#     ('25.56', 0.9975827932357788)),
#    ([[283.0, 548.0], [313.0, 548.0], [313.0, 562.0], [283.0, 562.0]],
#     ('61.47', 0.9998456835746765)),
#    ([[345.0, 546.0], [373.0, 546.0], [373.0, 562.0], [345.0, 562.0]],
#     ('25.22', 0.9997485876083374)),
#    ([[408.0, 546.0], [431.0, 546.0], [431.0, 562.0], [408.0, 562.0]],
#     ('7.72', 0.9993008375167847)),
#    ([[466.0, 546.0], [494.0, 546.0], [494.0, 562.0], [466.0, 562.0]],
#     ('44.11', 0.9997170567512512)),
#    ([[163.0, 579.0], [198.0, 579.0], [198.0, 594.0], [163.0, 594.0]],
#     ('表2.3', 0.9937264919281006)),
#    ([[202.0, 578.0], [434.0, 578.0], [434.0, 595.0], [202.0, 595.0]],
#     ('2007~2011年化妆品进口数量、金额一览表', 0.9916490316390991)),
#    ([[102.0, 617.0], [127.0, 617.0], [127.0, 633.0], [102.0, 633.0]],
#     ('年份', 0.999009370803833)),
#    ([[164.0, 611.0], [188.0, 611.0], [188.0, 623.0], [164.0, 623.0]],
#     ('数量', 0.9994940757751465)),
#    ([[220.0, 610.0], [255.0, 610.0], [255.0, 624.0], [220.0, 624.0]],
#     ('增长量', 0.9999272227287292)),
#    ([[280.0, 610.0], [316.0, 610.0], [316.0, 624.0], [280.0, 624.0]],
#     ('增长率', 0.9996671676635742)),
#    ([[347.0, 611.0], [371.0, 611.0], [371.0, 623.0], [347.0, 623.0]],
#     ('金额', 0.9999212026596069)),
#    ([[402.0, 610.0], [438.0, 610.0], [438.0, 624.0], [402.0, 624.0]],
#     ('增长量', 0.9999608397483826)),
#    ([[462.0, 610.0], [498.0, 610.0], [498.0, 624.0], [462.0, 624.0]],
#     ('增长率', 0.999785840511322)),
#    ([[159.0, 626.0], [194.0, 626.0], [194.0, 641.0], [159.0, 641.0]],
#     ('（万吨）', 0.989201009273529)),
#    ([[220.0, 626.0], [255.0, 626.0], [255.0, 641.0], [220.0, 641.0]],
#     ('（万吨）', 0.9880565404891968)),
#    ([[285.0, 625.0], [311.0, 625.0], [311.0, 641.0], [285.0, 641.0]],
#     ('（%）', 0.7159080505371094)),
#    ([[337.0, 626.0], [384.0, 626.0], [384.0, 641.0], [337.0, 641.0]],
#     ('（亿美元）', 0.9822542071342468)),
#    ([[398.0, 626.0], [444.0, 626.0], [444.0, 641.0], [398.0, 641.0]],
#     ('（亿美元）', 0.9795479774475098)),
#    ([[468.0, 625.0], [493.0, 625.0], [493.0, 641.0], [468.0, 641.0]],
#     ('（%）', 0.8652446866035461)),
#    ([[103.0, 647.0], [127.0, 647.0], [127.0, 659.0], [103.0, 659.0]],
#     ('2007', 0.9997591972351074)),
#    ([[164.0, 645.0], [188.0, 645.0], [188.0, 660.0], [164.0, 660.0]],
#     ('5.32', 0.9996718168258667)),
#    ([[231.0, 648.0], [241.0, 648.0], [241.0, 659.0], [231.0, 659.0]],
#     ('一', 0.7699519395828247)),
#    ([[291.0, 646.0], [304.0, 646.0], [304.0, 660.0], [291.0, 660.0]],
#     ('一', 0.7216811180114746)),
#    ([[347.0, 646.0], [371.0, 646.0], [371.0, 661.0], [347.0, 661.0]],
#     ('6.88', 0.9995927810668945)),
#    ([[413.0, 647.0], [425.0, 647.0], [425.0, 660.0], [413.0, 660.0]],
#     ('一', 0.7758406400680542)),
#    ([[475.0, 648.0], [484.0, 648.0], [484.0, 658.0], [475.0, 658.0]],
#     ('一', 0.6341047286987305)),
#    ([[102.0, 669.0], [128.0, 669.0], [128.0, 684.0], [102.0, 684.0]],
#     ('2008', 0.9775075912475586)),
#    ([[165.0, 669.0], [187.0, 669.0], [187.0, 684.0], [165.0, 684.0]],
#     ('6.11', 0.9998089671134949)),
#    ([[224.0, 669.0], [249.0, 669.0], [249.0, 684.0], [224.0, 684.0]],
#     ('0.79', 0.9998223185539246)),
#    ([[284.0, 669.0], [313.0, 669.0], [313.0, 684.0], [284.0, 684.0]],
#     ('14.85', 0.9997223019599915)),
#    ([[347.0, 669.0], [371.0, 669.0], [371.0, 684.0], [347.0, 684.0]],
#     ('9.36', 0.9998579621315002)),
#    ([[408.0, 669.0], [432.0, 669.0], [432.0, 684.0], [408.0, 684.0]],
#     ('2.48', 0.9995203018188477)),
#    ([[467.0, 669.0], [495.0, 669.0], [495.0, 684.0], [467.0, 684.0]],
#     ('36.05', 0.999860405921936)),
#    ([[102.0, 692.0], [128.0, 692.0], [128.0, 707.0], [102.0, 707.0]],
#     ('2009', 0.9247211813926697)),
#    ([[164.0, 692.0], [188.0, 692.0], [188.0, 707.0], [164.0, 707.0]],
#     ('5.90', 0.9998552799224854)),
#    ([[224.0, 692.0], [250.0, 692.0], [250.0, 707.0], [224.0, 707.0]],
#     ('-0.21', 0.9933320879936218)),
#    ([[284.0, 692.0], [312.0, 692.0], [312.0, 707.0], [284.0, 707.0]],
#     ('-3.44', 0.9991532564163208)),
#    ([[345.0, 692.0], [373.0, 692.0], [373.0, 707.0], [345.0, 707.0]],
#     ('10.70', 0.9998572468757629)),
#    ([[409.0, 692.0], [432.0, 692.0], [432.0, 707.0], [409.0, 707.0]],
#     ('1.34', 0.9996750354766846)),
#    ([[467.0, 692.0], [495.0, 692.0], [495.0, 707.0], [467.0, 707.0]],
#     ('14.32', 0.9073437452316284)),
#    ([[103.0, 717.0], [127.0, 717.0], [127.0, 729.0], [103.0, 729.0]],
#     ('2010', 0.9990687966346741)),
#    ([[164.0, 715.0], [188.0, 715.0], [188.0, 731.0], [164.0, 731.0]],
#     ('7.55', 0.9995918273925781)),
#    ([[225.0, 715.0], [249.0, 715.0], [249.0, 731.0], [225.0, 731.0]],
#     ('1.65', 0.9998016953468323)),
#    ([[284.0, 717.0], [312.0, 717.0], [312.0, 730.0], [284.0, 730.0]],
#     ('27.97', 0.99989253282547)),
#    ([[346.0, 717.0], [373.0, 717.0], [373.0, 730.0], [346.0, 730.0]],
#     ('15.00', 0.9999273419380188)),
#    ([[409.0, 717.0], [431.0, 717.0], [431.0, 729.0], [409.0, 729.0]],
#     ('4.30', 0.9996328353881836)),
#    ([[468.0, 717.0], [495.0, 717.0], [495.0, 730.0], [468.0, 730.0]],
#     ('40.19', 0.9999235272407532)),
#    ([[102.0, 739.0], [128.0, 739.0], [128.0, 754.0], [102.0, 754.0]],
#     ('2011', 0.9785217642784119)),
#    ([[164.0, 740.0], [189.0, 740.0], [189.0, 752.0], [164.0, 752.0]],
#     ('10.83', 0.9998153448104858)),
#    ([[225.0, 739.0], [249.0, 739.0], [249.0, 754.0], [225.0, 754.0]],
#     ('3.28', 0.9997938275337219)),
#    ([[284.0, 739.0], [313.0, 739.0], [313.0, 754.0], [284.0, 754.0]],
#     ('43.44', 0.9998449087142944)),
#    ([[345.0, 739.0], [372.0, 739.0], [372.0, 754.0], [345.0, 754.0]],
#     ('21.62', 0.9997766613960266)),
#    ([[408.0, 739.0], [431.0, 739.0], [431.0, 754.0], [408.0, 754.0]],
#     ('6.62', 0.9997555613517761)),
#    ([[468.0, 740.0], [495.0, 740.0], [495.0, 753.0], [468.0, 753.0]],
#     ('44.13', 0.999862790107727)),
#    ([[501.0, 774.0], [506.0, 774.0], [506.0, 781.0], [501.0, 781.0]],
#     ('5', 0.9952648878097534))],
#   'images': [('image_4_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 5,
#   'text': [([[88.0, 43.0], [191.0, 43.0], [191.0, 56.0], [88.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9985672235488892)),
#    ([[197.0, 102.0], [219.0, 102.0], [219.0, 114.0], [197.0, 114.0]],
#     ('出口', 0.9994686841964722)),
#    ([[323.0, 101.0], [346.0, 101.0], [346.0, 113.0], [323.0, 113.0]],
#     ('进口', 0.9997382164001465)),
#    ([[385.0, 109.0], [447.0, 109.0], [447.0, 127.0], [385.0, 127.0]],
#     ('单位：万吨', 0.9998327493667603)),
#    ([[121.0, 124.0], [130.0, 124.0], [130.0, 133.0], [121.0, 133.0]],
#     ('80', 0.9810962080955505)),
#    ([[120.0, 162.0], [130.0, 162.0], [130.0, 172.0], [120.0, 172.0]],
#     ('60', 0.9846401214599609)),
#    ([[121.0, 200.0], [130.0, 200.0], [130.0, 209.0], [121.0, 209.0]],
#     ('40', 0.9969171285629272)),
#    ([[120.0, 239.0], [132.0, 239.0], [132.0, 247.0], [120.0, 247.0]],
#     ('20', 0.9986414909362793)),
#    ([[155.0, 287.0], [190.0, 287.0], [190.0, 302.0], [155.0, 302.0]],
#     ('2007年', 0.999534010887146)),
#    ([[220.0, 287.0], [255.0, 287.0], [255.0, 302.0], [220.0, 302.0]],
#     ('2008年', 0.9997478723526001)),
#    ([[283.0, 287.0], [320.0, 287.0], [320.0, 302.0], [283.0, 302.0]],
#     ('2009年', 0.9997056722640991)),
#    ([[349.0, 287.0], [383.0, 287.0], [383.0, 302.0], [349.0, 302.0]],
#     ('2010年', 0.9994446039199829)),
#    ([[413.0, 287.0], [449.0, 287.0], [449.0, 302.0], [413.0, 302.0]],
#     ('2011年', 0.9997886419296265)),
#    ([[164.0, 334.0], [432.0, 334.0], [432.0, 348.0], [164.0, 348.0]],
#     ('图2.12007~2011年我国化妆品进出口数量分析图', 0.9871957302093506)),
#    ([[195.0, 375.0], [221.0, 375.0], [221.0, 388.0], [195.0, 388.0]],
#     ('出口', 0.9983100891113281)),
#    ([[323.0, 374.0], [350.0, 374.0], [350.0, 388.0], [323.0, 388.0]],
#     ('进口', 0.9999498724937439)),
#    ([[389.0, 380.0], [459.0, 383.0], [458.0, 398.0], [388.0, 396.0]],
#     ('单位：亿美元', 0.9984628558158875)),
#    ([[122.0, 398.0], [132.0, 398.0], [132.0, 407.0], [122.0, 407.0]],
#     ('30', 0.982109785079956)),
#    ([[122.0, 448.0], [133.0, 448.0], [133.0, 457.0], [122.0, 457.0]],
#     ('20', 0.9983835220336914)),
#    ([[122.0, 474.0], [132.0, 474.0], [132.0, 483.0], [122.0, 483.0]],
#     ('15', 0.9985637664794922)),
#    ([[121.0, 498.0], [134.0, 498.0], [134.0, 510.0], [121.0, 510.0]],
#     ('10', 0.9990451335906982)),
#    ([[127.0, 526.0], [132.0, 526.0], [132.0, 531.0], [127.0, 531.0]],
#     ('5', 0.9694938063621521)),
#    ([[125.0, 551.0], [134.0, 551.0], [134.0, 559.0], [125.0, 559.0]],
#     ('0', 0.8846127986907959)),
#    ([[155.0, 561.0], [190.0, 558.0], [191.0, 574.0], [156.0, 576.0]],
#     ('2007年', 0.999531626701355)),
#    ([[221.0, 561.0], [256.0, 561.0], [256.0, 575.0], [221.0, 575.0]],
#     ('2008年', 0.9993936419487)),
#    ([[285.0, 561.0], [321.0, 561.0], [321.0, 575.0], [285.0, 575.0]],
#     ('2009年', 0.9988248944282532)),
#    ([[350.0, 561.0], [384.0, 561.0], [384.0, 575.0], [350.0, 575.0]],
#     ('2010年', 0.9996558427810669)),
#    ([[413.0, 561.0], [449.0, 558.0], [450.0, 572.0], [414.0, 575.0]],
#     ('2011年', 0.9989562034606934)),
#    ([[163.0, 607.0], [432.0, 607.0], [432.0, 621.0], [163.0, 621.0]],
#     ('图2.22007-2011年我国化妆品进出口金额分析图', 0.9841305613517761)),
#    ([[89.0, 647.0], [295.0, 647.0], [295.0, 660.0], [89.0, 660.0]],
#     ('2.3.22007~2011年中国化妆品出口构成', 0.989794909954071)),
#    ([[114.0, 684.0], [506.0, 684.0], [506.0, 698.0], [114.0, 698.0]],
#     ('近5年来，我国化妆品出口主要以肤用化妆品、发用化妆品、口腔类化妆品', 0.9996466040611267)),
#    ([[91.0, 707.0], [505.0, 707.0], [505.0, 721.0], [91.0, 721.0]],
#     ('及美容化妆品为主，占总出口额的80%以上。其中，增幅列居首位的是肤用化妆', 0.9997274875640869)),
#    ([[90.0, 732.0], [498.0, 732.0], [498.0, 745.0], [90.0, 745.0]],
#     ('品，其平均年增长达1.42亿美元，所占比重上升了14%：其次是口腔类化妆品，', 0.9956234097480774))],
#   'images': [('image_5_2.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312)),
#    ('image_5_1.png',
#     Rect(110.89999389648438, 365.469970703125, 485.8999938964844, 589.719970703125)),
#    ('image_5_0.png',
#     Rect(108.64999389648438, 77.54998779296875, 487.3999938964844, 316.04998779296875))]},
#  {'page_num': 6,
#   'text': [([[407.0, 43.0], [507.0, 43.0], [507.0, 56.0], [407.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9773830771446228)),
#    ([[90.0, 77.0], [506.0, 77.0], [506.0, 90.0], [90.0, 90.0]],
#     ('平均年增长达0.61亿美元，所占比重上升8%：再者是美容化妆品，平均年增长', 0.9983927011489868)),
#    ([[90.0, 100.0], [410.0, 100.0], [410.0, 113.0], [90.0, 113.0]],
#     ('达0.36亿美元，所占比重下降23%：其余种类增幅相对较低。', 0.9973745942115784)),
#    ([[139.0, 132.0], [456.0, 132.0], [456.0, 146.0], [139.0, 146.0]],
#     ('表2.42007-2011年我国各类化妆品出口数量、金额一览表', 0.9866729378700256)),
#    ([[417.0, 161.0], [508.0, 162.0], [508.0, 176.0], [417.0, 175.0]],
#     ('单位：万吨/亿美元', 0.9788021445274353)),
#    ([[185.0, 186.0], [224.0, 186.0], [224.0, 201.0], [185.0, 201.0]],
#     ('2007年', 0.9999117851257324)),
#    ([[251.0, 186.0], [289.0, 186.0], [289.0, 201.0], [251.0, 201.0]],
#     ('2008年', 0.9998208284378052)),
#    ([[318.0, 186.0], [356.0, 186.0], [356.0, 201.0], [318.0, 201.0]],
#     ('2009年', 0.9998515248298645)),
#    ([[387.0, 187.0], [425.0, 184.0], [426.0, 199.0], [388.0, 202.0]],
#     ('2010年', 0.9995778799057007)),
#    ([[457.0, 186.0], [495.0, 186.0], [495.0, 200.0], [457.0, 200.0]],
#     ('2011年', 0.9998037219047546)),
#    ([[99.0, 197.0], [157.0, 197.0], [157.0, 215.0], [99.0, 215.0]],
#     ('化妆品类别', 0.9996927380561829)),
#    ([[175.0, 210.0], [199.0, 210.0], [199.0, 223.0], [175.0, 223.0]],
#     ('数量', 0.9998500347137451)),
#    ([[210.0, 209.0], [234.0, 209.0], [234.0, 225.0], [210.0, 225.0]],
#     ('金额', 0.9999785423278809)),
#    ([[245.0, 209.0], [270.0, 209.0], [270.0, 225.0], [245.0, 225.0]],
#     ('数量', 0.9999125003814697)),
#    ([[279.0, 210.0], [300.0, 210.0], [300.0, 223.0], [279.0, 223.0]],
#     ('金额', 0.9999444484710693)),
#    ([[309.0, 210.0], [331.0, 210.0], [331.0, 223.0], [309.0, 223.0]],
#     ('数量', 0.9998013973236084)),
#    ([[342.0, 209.0], [367.0, 209.0], [367.0, 225.0], [342.0, 225.0]],
#     ('金额', 0.9999904036521912)),
#    ([[378.0, 210.0], [401.0, 210.0], [401.0, 223.0], [378.0, 223.0]],
#     ('数量', 0.9998784065246582)),
#    ([[412.0, 209.0], [436.0, 209.0], [436.0, 225.0], [412.0, 225.0]],
#     ('金额', 0.9999870657920837)),
#    ([[449.0, 210.0], [471.0, 210.0], [471.0, 223.0], [449.0, 223.0]],
#     ('数量', 0.9996308088302612)),
#    ([[483.0, 210.0], [505.0, 210.0], [505.0, 223.0], [483.0, 223.0]],
#     ('金额', 0.9999369382858276)),
#    ([[100.0, 234.0], [155.0, 234.0], [155.0, 248.0], [100.0, 248.0]],
#     ('肤用化妆品', 0.9995190501213074)),
#    ([[176.0, 235.0], [198.0, 235.0], [198.0, 247.0], [176.0, 247.0]],
#     ('4.18', 0.9996837377548218)),
#    ([[212.0, 235.0], [232.0, 235.0], [232.0, 247.0], [212.0, 247.0]],
#     ('2.32', 0.9992360472679138)),
#    ([[247.0, 236.0], [267.0, 236.0], [267.0, 247.0], [247.0, 247.0]],
#     ('4.86', 0.9996682405471802)),
#    ([[280.0, 237.0], [296.0, 237.0], [296.0, 245.0], [280.0, 245.0]],
#     ('2.25', 0.9737333655357361)),
#    ([[308.0, 236.0], [331.0, 236.0], [331.0, 247.0], [308.0, 247.0]],
#     ('11.38', 0.999488353729248)),
#    ([[345.0, 235.0], [365.0, 235.0], [365.0, 247.0], [345.0, 247.0]],
#     ('3.46', 0.9994348287582397)),
#    ([[377.0, 236.0], [402.0, 236.0], [402.0, 247.0], [377.0, 247.0]],
#     ('14.49', 0.9997279047966003)),
#    ([[415.0, 235.0], [433.0, 235.0], [433.0, 247.0], [415.0, 247.0]],
#     ('6.12', 0.9997026920318604)),
#    ([[448.0, 237.0], [471.0, 237.0], [471.0, 245.0], [448.0, 245.0]],
#     ('21.76', 0.9943212270736694)),
#    ([[483.0, 236.0], [505.0, 236.0], [505.0, 247.0], [483.0, 247.0]],
#     ('9.43', 0.9997925162315369)),
#    ([[100.0, 257.0], [155.0, 257.0], [155.0, 271.0], [100.0, 271.0]],
#     ('发用化妆品', 0.9997461438179016)),
#    ([[176.0, 258.0], [198.0, 258.0], [198.0, 270.0], [176.0, 270.0]],
#     ('6.09', 0.9997832775115967)),
#    ([[212.0, 258.0], [232.0, 258.0], [232.0, 270.0], [212.0, 270.0]],
#     ('1.23', 0.9994672536849976)),
#    ([[246.0, 258.0], [267.0, 258.0], [267.0, 269.0], [246.0, 269.0]],
#     ('5.53', 0.9995863437652588)),
#    ([[279.0, 259.0], [299.0, 259.0], [299.0, 270.0], [279.0, 270.0]],
#     ('1.19', 0.9997131824493408)),
#    ([[310.0, 259.0], [329.0, 259.0], [329.0, 270.0], [310.0, 270.0]],
#     ('6.97', 0.9998680949211121)),
#    ([[345.0, 259.0], [364.0, 259.0], [364.0, 270.0], [345.0, 270.0]],
#     ('1.41', 0.999386191368103)),
#    ([[377.0, 259.0], [402.0, 259.0], [402.0, 270.0], [377.0, 270.0]],
#     ('10.06', 0.9998574256896973)),
#    ([[416.0, 258.0], [434.0, 258.0], [434.0, 270.0], [416.0, 270.0]],
#     ('1.90', 0.9990336894989014)),
#    ([[447.0, 260.0], [470.0, 260.0], [470.0, 268.0], [447.0, 268.0]],
#     ('10.21', 0.9959760904312134)),
#    ([[483.0, 259.0], [505.0, 259.0], [505.0, 270.0], [483.0, 270.0]],
#     ('2.26', 0.9996992349624634)),
#    ([[95.0, 281.0], [160.0, 281.0], [160.0, 296.0], [95.0, 296.0]],
#     ('口腔类化妆品', 0.9994086623191833)),
#    ([[176.0, 282.0], [198.0, 282.0], [198.0, 293.0], [176.0, 293.0]],
#     ('3.50', 0.999297022819519)),
#    ([[211.0, 282.0], [231.0, 282.0], [231.0, 294.0], [211.0, 294.0]],
#     ('0.71', 0.9996079206466675)),
#    ([[246.0, 282.0], [267.0, 282.0], [267.0, 293.0], [246.0, 293.0]],
#     ('2.14', 0.9994843006134033)),
#    ([[279.0, 284.0], [297.0, 284.0], [297.0, 292.0], [279.0, 292.0]],
#     ('0.43', 0.9936761856079102)),
#    ([[310.0, 282.0], [329.0, 282.0], [329.0, 293.0], [310.0, 293.0]],
#     ('5.61', 0.9989290237426758)),
#    ([[344.0, 282.0], [364.0, 282.0], [364.0, 293.0], [344.0, 293.0]],
#     ('0.97', 0.981416642665863)),
#    ([[381.0, 284.0], [398.0, 284.0], [398.0, 292.0], [381.0, 292.0]],
#     ('7.65', 0.9847378730773926)),
#    ([[416.0, 282.0], [433.0, 282.0], [433.0, 293.0], [416.0, 293.0]],
#     ('1.36', 0.9966118931770325)),
#    ([[447.0, 284.0], [470.0, 284.0], [470.0, 292.0], [447.0, 292.0]],
#     ('20.60', 0.9922537803649902)),
#    ([[484.0, 282.0], [505.0, 282.0], [505.0, 293.0], [484.0, 293.0]],
#     ('3.74', 0.9992004036903381)),
#    ([[100.0, 304.0], [155.0, 304.0], [155.0, 318.0], [100.0, 318.0]],
#     ('美容化妆品', 0.9971563220024109)),
#    ([[176.0, 306.0], [198.0, 306.0], [198.0, 317.0], [176.0, 317.0]],
#     ('8.91', 0.9996191263198853)),
#    ([[212.0, 306.0], [232.0, 306.0], [232.0, 317.0], [212.0, 317.0]],
#     ('5.38', 0.9994052648544312)),
#    ([[247.0, 308.0], [266.0, 308.0], [266.0, 316.0], [247.0, 316.0]],
#     ('6.40', 0.9988009929656982)),
#    ([[280.0, 308.0], [298.0, 308.0], [298.0, 316.0], [280.0, 316.0]],
#     ('5.00', 0.998462975025177)),
#    ([[310.0, 306.0], [330.0, 306.0], [330.0, 317.0], [310.0, 317.0]],
#     ('5.28', 0.999581515789032)),
#    ([[345.0, 306.0], [365.0, 306.0], [365.0, 317.0], [345.0, 317.0]],
#     ('4.82', 0.9993669986724854)),
#    ([[379.0, 306.0], [400.0, 306.0], [400.0, 317.0], [379.0, 317.0]],
#     ('6.60', 0.9995605945587158)),
#    ([[414.0, 306.0], [433.0, 306.0], [433.0, 317.0], [414.0, 317.0]],
#     ('6.63', 0.9992987513542175)),
#    ([[449.0, 306.0], [469.0, 306.0], [469.0, 317.0], [449.0, 317.0]],
#     ('7.07', 0.998964250087738)),
#    ([[483.0, 306.0], [506.0, 306.0], [506.0, 317.0], [483.0, 317.0]],
#     ('7.18', 0.9995568990707397)),
#    ([[95.0, 327.0], [160.0, 327.0], [160.0, 341.0], [95.0, 341.0]],
#     ('香水类化妆品', 0.9988088011741638)),
#    ([[177.0, 329.0], [197.0, 329.0], [197.0, 340.0], [177.0, 340.0]],
#     ('0.85', 0.9994786381721497)),
#    ([[212.0, 329.0], [231.0, 329.0], [231.0, 340.0], [212.0, 340.0]],
#     ('0.53', 0.9993991851806641)),
#    ([[246.0, 329.0], [266.0, 329.0], [266.0, 340.0], [246.0, 340.0]],
#     ('0.73', 0.9995167851448059)),
#    ([[278.0, 329.0], [298.0, 329.0], [298.0, 340.0], [278.0, 340.0]],
#     ('0.42', 0.99957275390625)),
#    ([[311.0, 329.0], [329.0, 329.0], [329.0, 340.0], [311.0, 340.0]],
#     ('1.36', 0.9995919466018677)),
#    ([[345.0, 329.0], [364.0, 329.0], [364.0, 340.0], [345.0, 340.0]],
#     ('0.73', 0.999158501625061)),
#    ([[380.0, 329.0], [398.0, 329.0], [398.0, 340.0], [380.0, 340.0]],
#     ('1.81', 0.9974244236946106)),
#    ([[416.0, 329.0], [433.0, 329.0], [433.0, 340.0], [416.0, 340.0]],
#     ('1.07', 0.9585973620414734)),
#    ([[450.0, 329.0], [469.0, 329.0], [469.0, 340.0], [450.0, 340.0]],
#     ('2.56', 0.9992824792861938)),
#    ([[484.0, 329.0], [504.0, 329.0], [504.0, 340.0], [484.0, 340.0]],
#     ('1.21', 0.9995995759963989)),
#    ([[89.0, 350.0], [166.0, 350.0], [166.0, 364.0], [89.0, 364.0]],
#     ('特殊功能化妆品', 0.9992368817329407)),
#    ([[176.0, 352.0], [197.0, 352.0], [197.0, 363.0], [176.0, 363.0]],
#     ('0.78', 0.9994711875915527)),
#    ([[213.0, 353.0], [230.0, 353.0], [230.0, 361.0], [213.0, 361.0]],
#     ('0.11', 0.9855654835700989)),
#    ([[247.0, 353.0], [265.0, 353.0], [265.0, 361.0], [247.0, 361.0]],
#     ('0.44', 0.9787169694900513)),
#    ([[279.0, 353.0], [298.0, 353.0], [298.0, 361.0], [279.0, 361.0]],
#     ('0.07', 0.996968686580658)),
#    ([[309.0, 352.0], [330.0, 352.0], [330.0, 363.0], [309.0, 363.0]],
#     ('0.68', 0.9994663596153259)),
#    ([[345.0, 353.0], [363.0, 353.0], [363.0, 361.0], [345.0, 361.0]],
#     ('0.26', 0.9949672818183899)),
#    ([[378.0, 352.0], [399.0, 352.0], [399.0, 363.0], [378.0, 363.0]],
#     ('0.77', 0.9998676776885986)),
#    ([[414.0, 352.0], [433.0, 352.0], [433.0, 363.0], [414.0, 363.0]],
#     ('0.26', 0.9348881840705872)),
#    ([[449.0, 353.0], [468.0, 353.0], [468.0, 361.0], [449.0, 361.0]],
#     ('0.82', 0.9912519454956055)),
#    ([[483.0, 352.0], [505.0, 352.0], [505.0, 363.0], [483.0, 363.0]],
#     ('0.33', 0.9996017217636108)),
#    ([[101.0, 374.0], [155.0, 374.0], [155.0, 389.0], [101.0, 389.0]],
#     ('其他化妆品', 0.9996911287307739)),
#    ([[176.0, 374.0], [198.0, 374.0], [198.0, 387.0], [176.0, 387.0]],
#     ('0.05', 0.9997695684432983)),
#    ([[211.0, 375.0], [231.0, 375.0], [231.0, 387.0], [211.0, 387.0]],
#     ('0.01', 0.9995846748352051)),
#    ([[246.0, 375.0], [268.0, 375.0], [268.0, 387.0], [246.0, 387.0]],
#     ('0.10', 0.9997135996818542)),
#    ([[278.0, 376.0], [297.0, 376.0], [297.0, 385.0], [278.0, 385.0]],
#     ('0.01', 0.9983270764350891)),
#    ([[310.0, 376.0], [329.0, 376.0], [329.0, 385.0], [310.0, 385.0]],
#     ('0.08', 0.9965192675590515)),
#    ([[345.0, 375.0], [364.0, 375.0], [364.0, 387.0], [345.0, 387.0]],
#     ('0.01', 0.999613881111145)),
#    ([[378.0, 374.0], [398.0, 374.0], [398.0, 386.0], [378.0, 386.0]],
#     ('0.21', 0.9981112480163574)),
#    ([[414.0, 374.0], [433.0, 374.0], [433.0, 387.0], [414.0, 387.0]],
#     ('0.17', 0.999749481678009)),
#    ([[449.0, 374.0], [469.0, 374.0], [469.0, 387.0], [449.0, 387.0]],
#     ('4.11', 0.9993182420730591)),
#    ([[484.0, 375.0], [505.0, 375.0], [505.0, 387.0], [484.0, 387.0]],
#     ('1.06', 0.9998660087585449)),
#    ([[115.0, 397.0], [139.0, 397.0], [139.0, 412.0], [115.0, 412.0]],
#     ('总计', 0.9999936819076538)),
#    ([[174.0, 399.0], [200.0, 399.0], [200.0, 410.0], [174.0, 410.0]],
#     ('24.37', 0.999860405921936)),
#    ([[209.0, 399.0], [234.0, 399.0], [234.0, 410.0], [209.0, 410.0]],
#     ('10.29', 0.999896228313446)),
#    ([[244.0, 399.0], [270.0, 399.0], [270.0, 410.0], [244.0, 410.0]],
#     ('20.20', 0.9999051094055176)),
#    ([[279.0, 401.0], [297.0, 401.0], [297.0, 409.0], [279.0, 409.0]],
#     ('9.36', 0.9991695284843445)),
#    ([[308.0, 401.0], [330.0, 401.0], [330.0, 408.0], [308.0, 408.0]],
#     ('31.37', 0.99665367603302)),
#    ([[345.0, 401.0], [366.0, 401.0], [366.0, 408.0], [345.0, 408.0]],
#     ('1.66', 0.9537361264228821)),
#    ([[378.0, 400.0], [401.0, 400.0], [401.0, 408.0], [378.0, 408.0]],
#     ('41.58', 0.9971021413803101)),
#    ([[414.0, 400.0], [438.0, 400.0], [438.0, 409.0], [414.0, 409.0]],
#     ('17.50', 0.9988082647323608)),
#    ([[446.0, 399.0], [472.0, 399.0], [472.0, 410.0], [446.0, 410.0]],
#     ('67.14', 0.9995874166488647)),
#    ([[481.0, 399.0], [506.0, 399.0], [506.0, 410.0], [481.0, 410.0]],
#     ('25.22', 0.9997304677963257)),
#    ([[402.0, 457.0], [467.0, 457.0], [467.0, 472.0], [402.0, 472.0]],
#     ('单位：亿美元', 0.9995584487915039)),
#    ([[123.0, 470.0], [133.0, 470.0], [133.0, 479.0], [123.0, 479.0]],
#     ('10', 0.9964340329170227)),
#    ([[180.0, 661.0], [416.0, 661.0], [416.0, 674.0], [180.0, 674.0]],
#     ('■2007年2008年2009年2010年2011年', 0.9801317453384399)),
#    ([[158.0, 710.0], [438.0, 710.0], [438.0, 724.0], [158.0, 724.0]],
#     ('图2.32007~2011年我国各类化妆品出口金额分析图', 0.9843816757202148))],
#   'images': [('image_6_1.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312)),
#    ('image_6_0.png',
#     Rect(110.89999389648438, 438.14996337890625, 485.8999938964844, 691.6499633789062))]},
#  {'page_num': 7,
#   'text': [([[88.0, 43.0], [190.0, 43.0], [190.0, 56.0], [88.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9987098574638367)),
#    ([[246.0, 81.0], [308.0, 81.0], [308.0, 92.0], [246.0, 92.0]],
#     ('香水类化妆品', 0.9907912611961365)),
#    ([[170.0, 91.0], [235.0, 91.0], [235.0, 105.0], [170.0, 105.0]],
#     ('口腔类化妆品', 0.9984360337257385)),
#    ([[319.0, 84.0], [386.0, 84.0], [386.0, 98.0], [319.0, 98.0]],
#     ('特殊功能化妆', 0.9996464252471924)),
#    ([[269.0, 95.0], [287.0, 95.0], [287.0, 107.0], [269.0, 107.0]],
#     ('5%', 0.8798196315765381)),
#    ([[121.0, 106.0], [176.0, 106.0], [176.0, 117.0], [121.0, 117.0]],
#     ('发用化妆品', 0.9989961385726929)),
#    ([[194.0, 105.0], [209.0, 105.0], [209.0, 117.0], [194.0, 117.0]],
#     ('7%', 0.9950799942016602)),
#    ([[338.0, 97.0], [370.0, 97.0], [370.0, 112.0], [338.0, 112.0]],
#     ('品1%', 0.9081454873085022)),
#    ([[354.0, 110.0], [411.0, 110.0], [411.0, 124.0], [354.0, 124.0]],
#     ('其他化妆品', 0.99907386302948)),
#    ([[138.0, 120.0], [156.0, 120.0], [156.0, 132.0], [138.0, 132.0]],
#     ('12%', 0.9933981895446777)),
#    ([[375.0, 125.0], [390.0, 125.0], [390.0, 138.0], [375.0, 138.0]],
#     ('0%', 0.9405678510665894)),
#    ([[141.0, 153.0], [197.0, 153.0], [197.0, 167.0], [141.0, 167.0]],
#     ('肤用化妆品', 0.9990173578262329)),
#    ([[308.0, 158.0], [360.0, 158.0], [360.0, 169.0], [308.0, 169.0]],
#     ('美容化妆品', 0.996650218963623)),
#    ([[159.0, 168.0], [179.0, 168.0], [179.0, 179.0], [159.0, 179.0]],
#     ('23%', 0.9978032112121582)),
#    ([[324.0, 171.0], [345.0, 171.0], [345.0, 183.0], [324.0, 183.0]],
#     ('52%', 0.991143524646759)),
#    ([[161.0, 241.0], [435.0, 241.0], [435.0, 255.0], [161.0, 255.0]],
#     ('图2.42007年我国各类化妆品出口金额占比分析图', 0.9994047284126282)),
#    ([[227.0, 280.0], [293.0, 280.0], [293.0, 291.0], [227.0, 291.0]],
#     ('香水类化妆品', 0.9988114237785339)),
#    ([[309.0, 280.0], [379.0, 278.0], [380.0, 292.0], [309.0, 295.0]],
#     ('其他化妆品4%', 0.9938835501670837)),
#    ([[158.0, 294.0], [226.0, 294.0], [226.0, 306.0], [158.0, 306.0]],
#     ('发用化妆品9%', 0.9983327984809875)),
#    ([[250.0, 294.0], [267.0, 294.0], [267.0, 307.0], [250.0, 307.0]],
#     ('5%', 0.9968210458755493)),
#    ([[371.0, 292.0], [438.0, 295.0], [438.0, 309.0], [370.0, 307.0]],
#     ('特殊功能化妆', 0.999338686466217)),
#    ([[391.0, 308.0], [422.0, 308.0], [422.0, 322.0], [391.0, 322.0]],
#     ('品1%', 0.9850563406944275)),
#    ([[126.0, 321.0], [190.0, 321.0], [190.0, 332.0], [126.0, 332.0]],
#     ('口腔类化妆品', 0.9993343353271484)),
#    ([[148.0, 334.0], [169.0, 334.0], [169.0, 348.0], [148.0, 348.0]],
#     ('15%', 0.9992446303367615)),
#    ([[374.0, 334.0], [427.0, 334.0], [427.0, 345.0], [374.0, 345.0]],
#     ('肤用化妆品', 0.998319149017334)),
#    ([[250.0, 355.0], [303.0, 355.0], [303.0, 366.0], [250.0, 366.0]],
#     ('美容化妆品', 0.9966225624084473)),
#    ([[391.0, 348.0], [411.0, 348.0], [411.0, 360.0], [391.0, 360.0]],
#     ('37%', 0.9571860432624817)),
#    ([[265.0, 368.0], [285.0, 368.0], [285.0, 383.0], [265.0, 383.0]],
#     ('29%', 0.9966203570365906)),
#    ([[161.0, 436.0], [207.0, 436.0], [207.0, 450.0], [161.0, 450.0]],
#     ('图2.52', 0.9937388300895691)),
#    ([[201.0, 436.0], [434.0, 436.0], [434.0, 450.0], [201.0, 450.0]],
#     ('2011年我国各类化妆品出口金额占比分析图', 0.9988555908203125)),
#    ([[89.0, 475.0], [246.0, 475.0], [246.0, 488.0], [89.0, 488.0]],
#     ('2.4近年的主要出口目标市场', 0.9992066025733948)),
#    ([[88.0, 514.0], [390.0, 514.0], [390.0, 528.0], [88.0, 528.0]],
#     ('2.4.12007~2011年中国化妆品出口五大洲数量及金额分析', 0.9913939237594604)),
#    ([[114.0, 553.0], [506.0, 553.0], [506.0, 566.0], [114.0, 566.0]],
#     ('据统计数据显示，亚洲、美洲和欧洲为我国化妆品主要出口地区。相比2007', 0.998945415019989)),
#    ([[90.0, 576.0], [506.0, 576.0], [506.0, 590.0], [90.0, 590.0]],
#     ('年，2011年我国化妆品出口亚洲的数量和金额分别增长了13.03万吨和6.14亿', 0.9994961023330688)),
# ...
#    ([[121.0, 219.0], [504.0, 219.0], [504.0, 232.0], [121.0, 232.0]],
#     ('《危险品制备指令1999/45/EC》提到了使用有害原材料和特定的免除标签化', 0.9978574514389038)),
#    ([[90.0, 243.0], [505.0, 243.0], [505.0, 256.0], [90.0, 256.0]],
#     ('妆品的标签要求，指令的第10条要求在使用此危险品的场所建立安全数据表', 0.9995681643486023)),
#    ([[97.0, 265.0], [506.0, 265.0], [506.0, 279.0], [97.0, 279.0]],
#     ('（SDSs），这些准则在《指令91/155/EEC》上有规定，此契约也免除化妆品，但', 0.9885815978050232)),
#    ([[91.0, 288.0], [361.0, 288.0], [361.0, 302.0], [91.0, 302.0]],
#     ('是使用者可以要求以其他方式给出同等的产品信息。', 0.9994643926620483)),
#    ([[88.0, 327.0], [137.0, 327.0], [137.0, 341.0], [88.0, 341.0]],
#     ('3.2美国', 0.9999392628669739)),
#    ([[89.0, 367.0], [169.0, 367.0], [169.0, 381.0], [89.0, 381.0]],
#     ('3.2.1法律文件', 0.99989253282547)),
#    ([[111.0, 404.0], [503.0, 403.0], [503.0, 420.0], [111.0, 421.0]],
#     ('·The Food,Drugs and Cosmetics Act（FD&CAct）（《食品、药品和化妆品',
#      0.9561446309089661)),
#    ([[90.0, 428.0], [229.0, 428.0], [229.0, 442.0], [90.0, 442.0]],
#     ('法案》）：化妆品主要法规', 0.9996015429496765)),
#    ([[112.0, 460.0], [507.0, 458.0], [507.0, 475.0], [112.0, 477.0]],
#     ('·The FairPackaging and Labelling Act（FPLA）（《合理包装及标签法》）：规',
#      0.9626584053039551)),
#    ([[90.0, 483.0], [259.0, 483.0], [259.0, 497.0], [90.0, 497.0]],
#     ('定了化妆品的标签、包装和广告', 0.9998651146888733)),
#    ([[112.0, 513.0], [395.0, 512.0], [395.0, 529.0], [112.0, 530.0]],
#     ('·CosmeticLabelling（《化妆品标签》）：21 CFR701', 0.9812681078910828)),
#    ([[114.0, 545.0], [383.0, 545.0], [383.0, 560.0], [114.0, 560.0]],
#     ('·CosmeticLabellingManual（《化妆品标签指南》）', 0.9687114357948303)),
#    ([[114.0, 578.0], [505.0, 578.0], [505.0, 592.0], [114.0, 592.0]],
#     ('·LabelingRequirementsforOver-the-CounterDrugs（《非处方药品（OTC）标签',
#      0.9723595380783081)),
#    ([[90.0, 600.0], [213.0, 600.0], [213.0, 614.0], [90.0, 614.0]],
#     ('要求》）：21CFR201.66', 0.9826574325561523)),
#    ([[89.0, 639.0], [169.0, 639.0], [169.0, 652.0], [89.0, 652.0]],
#     ('3.2.2主管机关', 0.9998936057090759)),
#    ([[115.0, 676.0], [502.0, 676.0], [502.0, 693.0], [115.0, 693.0]],
#     ('美国食品药品管理局（The Food and DrugAdministration，FDA）主管化妆',
#      0.9737571477890015)),
#    ([[89.0, 697.0], [482.0, 699.0], [482.0, 717.0], [89.0, 714.0]],
#     ('品和药品。化妆品由食品安全和营养学中心（TheCenterforFood Safety and', 0.9851632714271545)),
#    ([[89.0, 724.0], [502.0, 723.0], [502.0, 737.0], [89.0, 738.0]],
#     ('Applied Nutrition，CFSAN）下属色素和化妆品办公室负责，负责从生产到上市', 0.9789620041847229)),
#    ([[91.0, 748.0], [505.0, 748.0], [505.0, 761.0], [91.0, 761.0]],
#     ('后的监督管理工作，可以不经通知进入到生产厂地进行检查，从上市产品中抽查', 0.9920855760574341)),
#    ([[90.0, 783.0], [100.0, 783.0], [100.0, 793.0], [90.0, 793.0]],
#     ('30', 0.9996609687805176))],
#   'images': [('image_29_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 30,
#   'text': [([[408.0, 45.0], [507.0, 45.0], [507.0, 58.0], [408.0, 58.0]],
#     ('各国化妆品标签管理指南', 0.978227436542511)),
#    ([[89.0, 79.0], [505.0, 79.0], [505.0, 92.0], [89.0, 92.0]],
#     ('产品。进口产品要遵循《进口化妆品规程》。OTC药品由药品评估和研究中心（The', 0.9891186356544495)),
#    ([[89.0, 101.0], [505.0, 100.0], [505.0, 114.0], [89.0, 115.0]],
#     ('Center forDrugEvaluation and Research，CDER）负责管理。既是化妆品又是OTC',
#      0.9724129438400269)),
#    ([[90.0, 125.0], [505.0, 125.0], [505.0, 139.0], [90.0, 139.0]],
#     ('药品的产品由CFSAN和CDER共同管理。对于进口美国的海外产品，FDA可以到', 0.9993395805358887)),
#    ([[90.0, 148.0], [167.0, 148.0], [167.0, 162.0], [90.0, 162.0]],
#     ('海外施行检查。', 0.9997683763504028)),
#    ([[88.0, 186.0], [180.0, 185.0], [180.0, 199.0], [88.0, 200.0]],
#     ('3.2.3化妆品定义', 0.9993133544921875)),
#    ([[121.0, 226.0], [307.0, 226.0], [307.0, 239.0], [121.0, 239.0]],
#     ('《FD&C法案》将化妆品定义为两类：', 0.9957010746002197)),
#    ([[113.0, 256.0], [164.0, 256.0], [164.0, 270.0], [113.0, 270.0]],
#     ('·化妆品', 0.9996305704116821)),
#    ([[115.0, 288.0], [185.0, 288.0], [185.0, 300.0], [115.0, 300.0]],
#     ('·非处方药品', 0.9943916201591492)),
#    ([[114.0, 318.0], [505.0, 318.0], [505.0, 332.0], [114.0, 332.0]],
#     ('产品属于化妆品或药品取决于它们的用途，而用途则根据产品功效声明和消', 0.9989509582519531)),
#    ([[91.0, 342.0], [498.0, 342.0], [498.0, 356.0], [91.0, 356.0]],
#     ('费者的认知（通过产品的口碑或成分的治疗功能）来确定。根据《FD&C法案》，', 0.9939702153205872)),
#    ([[90.0, 365.0], [498.0, 365.0], [498.0, 380.0], [90.0, 380.0]],
#     ('产品可以是药品，也可以是化妆品，或既是药品也是化妆品（与欧盟刚好相反）。', 0.9916945695877075)),
#    ([[91.0, 388.0], [505.0, 388.0], [505.0, 402.0], [91.0, 402.0]],
#     ('第三种情况只有在产品有两种用途，符合两种定义的时候才会发生，例如：防头', 0.9995548725128174)),
#    ([[91.0, 412.0], [504.0, 412.0], [504.0, 426.0], [91.0, 426.0]],
#     ('皮屑香波是化妆品，因为它的声明表明产品的用途是用来清洁头发：但是它同样', 0.9953514933586121)),
#    ([[91.0, 435.0], [505.0, 435.0], [505.0, 449.0], [91.0, 449.0]],
#     ('也可视作药品，因为它含有公认的防头皮屑成分且它的声明表明它是用来治疗头', 0.9976266026496887)),
#    ([[91.0, 459.0], [504.0, 459.0], [504.0, 473.0], [91.0, 473.0]],
#     ('皮屑的。确定为既是化妆品又是药品的产品必须符合两种类别产品的法规要求。', 0.9976205825805664)),
#    ([[115.0, 491.0], [506.0, 491.0], [506.0, 504.0], [115.0, 504.0]],
#     ('化妆品的定义：指除了脂肪酸碱性盐肥皂之外的施用于人体（擦、注、撒或', 0.9806081652641296)),
#    ([[89.0, 512.0], [505.0, 513.0], [505.0, 527.0], [89.0, 526.0]],
#     ('喷）或其任何部位用于清洁、美化、增强吸引力或改善外貌而对人体结构或功能', 0.9984846115112305)),
#    ([[90.0, 536.0], [182.0, 537.0], [182.0, 552.0], [90.0, 550.0]],
#     ('没有影响的产品。', 0.9993440508842468)),
#    ([[112.0, 568.0], [504.0, 568.0], [504.0, 581.0], [112.0, 581.0]],
#     ('药品的定义：用于治疗、缓解、医治或预防人类和其他动物疾病的物品以及', 0.9996553063392639)),
#    ([[91.0, 591.0], [395.0, 591.0], [395.0, 605.0], [91.0, 605.0]],
#     ('食品之外的用于影响人体或其他动物体结构和功能的物品。', 0.9998706579208374)),
#    ([[115.0, 623.0], [383.0, 623.0], [383.0, 638.0], [115.0, 638.0]],
#     ('非处方药品是指可以无需医生处方即可买到的药品。', 0.9999305009841919)),
#    ([[115.0, 654.0], [504.0, 654.0], [504.0, 667.0], [115.0, 667.0]],
#     ('某些在欧盟被分为化妆品的产品在美国被分为新药品而非OTC药品。新药', 0.9953710436820984)),
#    ([[90.0, 677.0], [505.0, 677.0], [505.0, 690.0], [90.0, 690.0]],
#     ('品是指尚未被专家们广泛认可在预期使用目的下安全有效的药品，或是尚未在确', 0.9997344017028809)),
#    ([[91.0, 701.0], [252.0, 701.0], [252.0, 714.0], [91.0, 714.0]],
#     ('切的范围或时间内使用的药品。', 0.999703586101532))],
#   'images': [('image_30_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 31,
#   'text': [([[88.0, 43.0], [191.0, 43.0], [191.0, 56.0], [88.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9986264705657959)),
#    ([[88.0, 79.0], [181.0, 79.0], [181.0, 93.0], [88.0, 93.0]],
#     ('3.2.4化妆品分类', 0.9996052980422974)),
#    ([[117.0, 117.0], [207.0, 117.0], [207.0, 132.0], [117.0, 132.0]],
#     ('（1）化妆品分类：', 0.9944838285446167)),
#    ([[115.0, 147.0], [176.0, 147.0], [176.0, 164.0], [115.0, 164.0]],
#     ('·皮肤护理', 0.9997888803482056)),
#    ([[115.0, 177.0], [153.0, 177.0], [153.0, 195.0], [115.0, 195.0]],
#     ('·香水', 0.9985237717628479)),
#    ([[116.0, 209.0], [188.0, 209.0], [188.0, 227.0], [116.0, 227.0]],
#     ('·眼部化妆品', 0.9980111122131348)),
#    ([[117.0, 242.0], [211.0, 242.0], [211.0, 256.0], [117.0, 256.0]],
#     ('·眼部外的化妆品', 0.994114875793457)),
#    ([[116.0, 273.0], [174.0, 273.0], [174.0, 287.0], [116.0, 287.0]],
#     ('·指甲产品', 0.9987121820449829)),
#    ([[116.0, 304.0], [223.0, 304.0], [223.0, 317.0], [116.0, 317.0]],
#     ('·沐浴油和泡沫浴液', 0.9947478175163269)),
#    ([[116.0, 335.0], [164.0, 335.0], [164.0, 349.0], [116.0, 349.0]],
#     ('·漱口水', 0.9897320866584778)),
#    ([[115.0, 365.0], [188.0, 365.0], [188.0, 383.0], [115.0, 383.0]],
#     ('·染发预处理', 0.9997009634971619)),
#    ([[117.0, 398.0], [297.0, 398.0], [297.0, 412.0], [117.0, 412.0]],
#     ('·洗发水、烫发剂或其他护发产品', 0.9983885884284973)),
#    ([[117.0, 429.0], [164.0, 429.0], [164.0, 444.0], [117.0, 444.0]],
#     ('·除臭剂', 0.9970558881759644)),
#    ([[115.0, 458.0], [176.0, 458.0], [176.0, 476.0], [115.0, 476.0]],
#     ('·剃须产品', 0.9972807168960571)),
#    ([[117.0, 492.0], [175.0, 492.0], [175.0, 506.0], [117.0, 506.0]],
#     ('·儿童产品', 0.9978044629096985)),
#    ([[115.0, 521.0], [176.0, 521.0], [176.0, 538.0], [115.0, 538.0]],
#     ('·晒黑产品', 0.988763153553009)),
#    ([[119.0, 553.0], [286.0, 553.0], [286.0, 570.0], [119.0, 570.0]],
#     ('（2）OTC药品（化妆品）分类：', 0.9873287081718445)),
#    ([[117.0, 585.0], [271.0, 585.0], [271.0, 599.0], [117.0, 599.0]],
#     ('·防齿（含氟化物）的牙膏', 0.9929483532905579)),
#    ([[115.0, 615.0], [174.0, 615.0], [174.0, 629.0], [115.0, 629.0]],
#     ('·保湿产品', 0.9969415664672852)),
#    ([[115.0, 647.0], [188.0, 647.0], [188.0, 664.0], [115.0, 664.0]],
#     ('·防晒化妆品', 0.9962582588195801)),
#    ([[117.0, 679.0], [164.0, 679.0], [164.0, 694.0], [117.0, 694.0]],
#     ('·抑汗剂', 0.9839004278182983)),
#    ([[117.0, 710.0], [199.0, 710.0], [199.0, 725.0], [117.0, 725.0]],
#     ('·防头屑洗发水', 0.9944842457771301)),
#    ([[91.0, 783.0], [99.0, 783.0], [99.0, 792.0], [91.0, 792.0]],
#     ('32', 0.977055013179779))],
#   'images': [('image_31_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 32,
#   'text': [([[407.0, 45.0], [507.0, 45.0], [507.0, 58.0], [407.0, 58.0]],
#     ('各国化妆品标签管理指南', 0.9900049567222595)),
#    ([[89.0, 80.0], [204.0, 80.0], [204.0, 94.0], [89.0, 94.0]],
#     ('3.2.5化妆品标签要求', 0.999926745891571)),
#    ([[90.0, 120.0], [234.0, 120.0], [234.0, 134.0], [90.0, 134.0]],
#     ('3.2.5.1化妆品标签一般要求', 0.9996322393417358)),
#    ([[115.0, 159.0], [286.0, 159.0], [286.0, 172.0], [115.0, 172.0]],
#     ('规定化妆品标签必须标注的内容：', 0.9987807869911194)),
#    ([[120.0, 189.0], [401.0, 189.0], [401.0, 202.0], [120.0, 202.0]],
#     ('（1）产品名称和呈述：必须标注在外包装主展示面上。', 0.9973723888397217)),
#    ([[115.0, 221.0], [505.0, 221.0], [505.0, 234.0], [115.0, 234.0]],
#     ('使用化妆品的常用名或者恰当的描述性名称。如果该化妆品的性质是显而易', 0.9988158345222473)),
#    ([[91.0, 245.0], [505.0, 245.0], [505.0, 258.0], [91.0, 258.0]],
#     ('见的，则在不会造成公众对该化妆品误解和无法辨别的前提下，可以使用更为奇', 0.9988271594047546)),
#    ([[90.0, 267.0], [168.0, 267.0], [168.0, 281.0], [90.0, 281.0]],
#     ('特有趣的名称。', 0.9984959363937378)),
#    ([[120.0, 298.0], [472.0, 298.0], [472.0, 312.0], [120.0, 312.0]],
#     ('（2）生产商、包装商或发行商的名称和地址：在内、外包装上标注。', 0.9945071935653687)),
#    ([[115.0, 331.0], [505.0, 331.0], [505.0, 345.0], [115.0, 345.0]],
#     ('具体规定见《美国联邦法规》（CodeofFederalRegulations，CFR）第21卷', 0.9901977181434631)),
#    ([[90.0, 353.0], [505.0, 353.0], [505.0, 367.0], [90.0, 367.0]],
#     ('第701.12部分。进口化妆品必须在容器外面用英语标明原产国及制造商或代理', 0.9996358752250671)),
#    ([[90.0, 375.0], [498.0, 375.0], [498.0, 390.0], [90.0, 390.0]],
#     ('商（包括进口商）。原产国由以下语句标注：“由…（英文标写国家名）国制造”；', 0.9582576155662537)),
#    ([[90.0, 400.0], [498.0, 400.0], [498.0, 414.0], [90.0, 414.0]],
#     ('或“…（英文标写的国家名）国产品”：或其他能清楚表明原产国意思的语句。', 0.9747369885444641)),
#    ([[90.0, 423.0], [498.0, 423.0], [498.0, 437.0], [90.0, 437.0]],
#     ('如果原产国是北美自由贸易区（NAFTA）国家，可以用英语、法语或西班牙语。', 0.998415470123291)),
#    ([[120.0, 454.0], [366.0, 454.0], [366.0, 468.0], [120.0, 468.0]],
#     ('（3）净含量：标注在内、外包装的主展示面上。', 0.9945207834243774)),
#    ([[115.0, 487.0], [506.0, 487.0], [506.0, 500.0], [115.0, 500.0]],
#     ('强制以传统的美国惯例单位标注，另外，还可以用公制单位同时标注。如果', 0.9983416199684143)),
#    ([[91.0, 509.0], [505.0, 509.0], [505.0, 522.0], [91.0, 522.0]],
#     ('化妆品为液体，声明必须用体积单位：如果化妆品为固体、半固体、粘性物或固', 0.9973628520965576)),
#    ([[91.0, 532.0], [504.0, 532.0], [504.0, 546.0], [91.0, 546.0]],
#     ('体混合物，声明必须用重量单位。重量用磅和盘司表示。液体体积用美制加仑、', 0.9925277829170227)),
#    ([[91.0, 557.0], [505.0, 557.0], [505.0, 570.0], [91.0, 570.0]],
#     ('夸脱、品脱和液量益司表示。美国的体积计算和英国以及其他国家的体积有微小', 0.971297562122345)),
#    ([[88.0, 577.0], [352.0, 579.0], [352.0, 595.0], [88.0, 593.0]],
#     ('的差别。净含量标签的具体规定见21CFR701.13。', 0.9995600581169128)),
#    ([[117.0, 610.0], [310.0, 610.0], [310.0, 624.0], [117.0, 624.0]],
#     ('（4）化妆品成分表：在外包装上标注。', 0.9965876340866089)),
#    ([[115.0, 643.0], [505.0, 643.0], [505.0, 656.0], [115.0, 656.0]],
#     ('具体规定见21CFR701.3。供个人使用的零售产品在化妆品标签上必须列出', 0.999078094959259)),
#    ([[90.0, 666.0], [505.0, 666.0], [505.0, 679.0], [90.0, 679.0]],
#     ('化妆品的全部成分。一般情况下不零售的化妆品，例如，专业人士在专业机构中', 0.9941197037696838)),
#    ([[90.0, 687.0], [503.0, 688.0], [503.0, 702.0], [90.0, 701.0]],
#     ('为顾客使用的发用品或彩妆品，以及在工作场所供人们使用的洁肤霜和润肤霜，', 0.9967648983001709)),
#    ([[91.0, 712.0], [505.0, 712.0], [505.0, 726.0], [91.0, 726.0]],
#     ('而且这些产品也不会销售给消费者供他们在家使用，可以不注明成分。香水和香', 0.9985043406486511)),
#    ([[91.0, 736.0], [505.0, 736.0], [505.0, 749.0], [91.0, 749.0]],
#     ('料例外，可以只列出非商标性名称。此外，出于商业保密的需要，经FDA批准', 0.9900206327438354)),
#    ([[496.0, 774.0], [506.0, 774.0], [506.0, 784.0], [496.0, 784.0]],
#     ('33', 0.9997084140777588))],
#   'images': [('image_32_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]},
#  {'page_num': 33,
#   'text': [([[90.0, 46.0], [188.0, 46.0], [188.0, 56.0], [90.0, 56.0]],
#     ('各国化妆品标签管理指南', 0.9715783596038818)),
#    ([[89.0, 78.0], [505.0, 77.0], [505.0, 91.0], [89.0, 92.0]],
#     ('豁免公之于众的成分可以不列于标签上，但必须于标签组分的最后部分声明：“以', 0.9974098205566406)),
#    ([[91.0, 101.0], [505.0, 101.0], [505.0, 114.0], [91.0, 114.0]],
#     ('及其他成分”。如果包装上没有足够的标签空间或者是装饰性的容器，可使用附', 0.9991649985313416)),
#    ([[90.0, 124.0], [505.0, 126.0], [505.0, 140.0], [90.0, 139.0]],
#     ('页标签（附带的标签、带子或卡片）（具体细节见CTFA标签手册（TheCosmetic，', 0.9834113121032715)),
#    ([[89.0, 149.0], [505.0, 148.0], [505.0, 162.0], [89.0, 163.0]],
#     ('Toiletry andFragranceAssociation，美国化妆品、盟洗用品和香料协会，现已更名',
#      0.9820773005485535)),
#    ([[91.0, 173.0], [422.0, 173.0], [422.0, 186.0], [91.0, 186.0]],
#     ('为PersonCareProductsCouncil，美国个人用品护理用品协会））。', 0.9773821234703064)),
#    ([[115.0, 203.0], [179.0, 203.0], [179.0, 218.0], [115.0, 218.0]],
#     ('标注顺序为：', 0.9989671111106873)),
#    ([[115.0, 235.0], [505.0, 235.0], [505.0, 248.0], [115.0, 248.0]],
#     ('含量高于1%的成分以降序排列：含量小于1%的成分，其顺序可以是任意', 0.9920347929000854)),
#    ([[90.0, 257.0], [506.0, 257.0], [506.0, 271.0], [90.0, 271.0]],
#     ('排列的：色素添加剂按任意顺序排列，以“含有…”语句引出，不能使用“+/-”', 0.9534696340560913)),
#    ([[90.0, 281.0], [216.0, 281.0], [216.0, 294.0], [90.0, 294.0]],
#     ('符号：“以及其他成分”。', 0.9499173164367676)),
#    ([[115.0, 313.0], [504.0, 313.0], [504.0, 326.0], [115.0, 326.0]],
#     ('标注的成份名称必须依次使用下列名称：21CFR701.30中列出的指定名称、', 0.9984896779060364)),
#    ([[90.0, 335.0], [506.0, 335.0], [506.0, 349.0], [90.0, 349.0]],
#     ('CTFA《化妆品成分词典》（此规定名称见INCI名称）、《美国药典》的名称、《国', 0.9891666173934937)),
#    ([[91.0, 359.0], [505.0, 359.0], [505.0, 373.0], [91.0, 373.0]],
#     ('家处方集》的名称、《食品化学法典》的名称、《美国药品正名和药典药名词典》', 0.9989129304885864)),
#    ([[90.0, 382.0], [419.0, 382.0], [419.0, 396.0], [90.0, 396.0]],
#     ('的名称、消费者公认的名称、化学或其他技术专用名称或描述。', 0.9997926354408264)),
#    ([[120.0, 413.0], [181.0, 413.0], [181.0, 427.0], [120.0, 427.0]],
#     ('（5）保质期', 0.976116418838501)),
#    ([[115.0, 445.0], [299.0, 445.0], [299.0, 458.0], [115.0, 458.0]],
#     ('要说明在什么时间内使用是安全的。', 0.9995044469833374)),
#    ([[121.0, 478.0], [190.0, 478.0], [190.0, 489.0], [121.0, 489.0]],
#     ('（6）生产批号', 0.9586329460144043)),
#    ([[115.0, 503.0], [455.0, 503.0], [455.0, 517.0], [115.0, 517.0]],
#     ('化妆品不要求批量鉴定，但是应当建立在健康的商业活动基础上。', 0.999502420425415)),
#    ([[120.0, 528.0], [315.0, 528.0], [315.0, 542.0], [120.0, 542.0]],
#     ('（7）警告声明：在内、外包装上标注。', 0.9961077570915222)),
#    ([[121.0, 563.0], [505.0, 563.0], [505.0, 576.0], [121.0, 576.0]],
#     ('《化妆品类产品警告声明》（21CFR740）对警告声明作了详细规定。某些产', 0.9855842590332031)),
#    ([[89.0, 584.0], [497.0, 585.0], [497.0, 599.0], [89.0, 598.0]],
#     ('品标签必须带有警示用语。例如以自加压容器包装的化妆品（如喷雾剂产品）', 0.9986067414283752)),
#    ([[91.0, 608.0], [505.0, 608.0], [505.0, 621.0], [91.0, 621.0]],
#     ('女用除臭喷雾和儿童泡沫浴液等。当一个具体的警示用语得到法律认可后，就不', 0.9974765181541443)),
#    ([[90.0, 633.0], [505.0, 633.0], [505.0, 646.0], [90.0, 646.0]],
#     ('能改变语句，并且在使用时必须按照相关法规确切使用。如果化妆品的安全性未', 0.9988062381744385)),
#    ([[90.0, 656.0], [501.0, 656.0], [501.0, 669.0], [90.0, 669.0]],
#     ('能得到充分的证实，且没有在标签的主展示面上出现以下明确的声明：“警告一一', 0.9929438829421997)),
#    ([[91.0, 680.0], [504.0, 680.0], [504.0, 693.0], [91.0, 693.0]],
#     ('该产品的安全性未经测定”，则该化妆品将会被视为错误标签产品。另外，还需', 0.9986661672592163)),
#    ([[91.0, 702.0], [336.0, 702.0], [336.0, 715.0], [91.0, 715.0]],
#     ('要注意某些州制定的对警告有特殊要求的法令。', 0.9997324347496033)),
#    ([[121.0, 734.0], [270.0, 734.0], [270.0, 747.0], [121.0, 747.0]],
#     ('（8）必要时，标注储存条件。', 0.9966636896133423)),
#    ([[90.0, 783.0], [99.0, 783.0], [99.0, 793.0], [90.0, 793.0]],
#     ('34', 0.999496579170227))],
#   'images': [('image_33_0.png',
#     Rect(123.77999877929688, 242.75997924804688, 543.5399780273438, 671.1599731445312))]}]

# %%
def translate_text(text, source_lang='zh-CN', target_lang='en'):
    if not isinstance(text, str):
        print(f"Invalid input type for translation: {type(text)}")  # Debugging line
        return ""  # Return empty string for invalid input

    max_chunk_size = 5000
    translated_chunks = []

    # Split the text into smaller chunks
    for i in range(0, len(text), max_chunk_size):
        chunk = text[i:i + max_chunk_size]
        print(f"Translating chunk: {chunk}")  # Debugging line

        try:
            translated_chunk = GoogleTranslator(source=source_lang, target=target_lang).translate(chunk)
            if translated_chunk:  # Ensure we only append valid strings
                translated_chunks.append(translated_chunk)
            else:
                print(f"Translation returned None for chunk: {chunk}")  # Debugging line

        except Exception as e:
            print(f"Error translating chunk '{chunk}': {e}")  # Print the error for debugging

    # Join all the translated chunks into a single string
    translated_text = ''.join(translated_chunks)
    return translated_text

# %%
# Step 3: Reconstruct PDF with translated text and preserved layout
def create_translated_pdf(extracted_data, output_path, page_size=A4):
    c = canvas.Canvas(output_path, pagesize=page_size)
    width, height = page_size

    for page in extracted_data:
        page_num = page['page_num']
        text_data = page['text']
        image_data = page['images']

        # Set the font and size for the text
        c.setFont("ArialUnicode", 10)

        # Draw images at original positions
        for img_filename, rect in image_data:
            x1, y1, x2, y2 = rect  # Image coordinates
            img_width = x2 - x1
            img_height = y2 - y1
            # img_opa = adjust_cmyk_image_opacity(img_filename, opacity=0.5)
            # Save the adjusted image temporarily
            # temp_filename = f"temp_{os.path.basename(img_filename)}"
            # img_opa.save(temp_filename)
            c.drawImage(img_filename, x1, height - y2, width=img_width, height=img_height)

        # Draw translated text at original bounding box positions with adjusted font size
        for bounding_box, text_tuple in text_data:
            if not isinstance(text_tuple, tuple):
                print(f"Invalid text input: {text_tuple}")  # Debugging line
                continue  # Skip invalid text

            # Extract the actual text and ignore the confidence score
            text = text_tuple[0]  # Get the text from the tuple
            
            # Ensure the text is a string
            if not isinstance(text, str):
                print(f"Invalid text extracted: {text}")  # Debugging line
                continue  # Skip if the extracted text is not a string
            
            x_min, y_min = bounding_box[0]
            # x_min = x_min-60
            # print("----------------",x_min,"---------------",y_min,"-------------------------------")
            x_max, y_max = bounding_box[2]
            # x_max = x_max+80
            # print("----------------",x_max,"---------------",y_max,"-------------------------------")

            # # Draw a bounding box around the text
            # c.setStrokeColorRGB(0, 0, 1)  # Set color to blue for bounding box
            # c.rect(x_min, height - y_max, x_max - x_min, y_max - y_min, stroke=1, fill=0)

            # Translate the text
            translated_text = translate_text(text)

            # Calculate the appropriate font size to fit text within bounding box
            box_width = x_max - x_min
            c.setFont("ArialUnicode", 10)  # Default font size
            font_size = adjust_font_size(translated_text, box_width)
            c.setFont("ArialUnicode", font_size)

            # Check if the text is within a table or a paragraph
            if is_within_table(bounding_box, text_data):
                # Adjust alignment and placement if it's part of a table
                c.drawRightString(x_max, height - y_max, translated_text)
            else:
                # Place the translated text normally
                c.drawString(x_min, height - y_max, translated_text)  # Adjust Y-coordinate for PDF format

        # Add a new page for each original PDF page
        c.showPage()
    # delete_all_images(extracted_data)
    c.save()


# Helper function: Adjust font size to fit text within a bounding box
def adjust_font_size(text, box_width, initial_font_size=10):
    """Adjust the font size based on the box width and text length."""
    font_size = initial_font_size
    text_width = len(text) * (font_size * 0.5)  # Approximate text width calculation
    if text_width > box_width:
        font_size = (box_width / len(text)) * 2 # Adjust font size proportionally
        # font_size = ((box_width / len(text)) * 2 ) + 1 # Adjust font size proportionally
    return font_size


# Helper function: Check if the bounding box is part of a table
def is_within_table(bounding_box, text_data):
    """Identify if a text bounding box belongs to a table by checking proximity with other boxes."""
    x_min, y_min, x_max, y_max = bounding_box[0][0], bounding_box[0][1], bounding_box[2][0], bounding_box[2][1]
    for other_box, _ in text_data:
        if other_box != bounding_box:
            other_x_min, other_y_min, other_x_max, other_y_max = other_box[0][0], other_box[0][1], other_box[2][0], other_box[2][1]
            # Check if the bounding boxes are aligned horizontally and vertically
            if abs(other_y_min - y_min) < 5 and abs(other_y_max - y_max) < 5:
                return True
    return False

def delete_all_images(extracted_data):
    # Loop through each page's data in extracted_data
    for page in extracted_data:
        image_data = page.get('images', [])
        
        # Loop through each image tuple in image_data
        for img_tuple in image_data:
            img_filename = img_tuple[0]  # Extract the image filename
            # Delete the image file if it exists
            if os.path.exists(img_filename):
                os.remove(img_filename)

# %%
create_translated_pdf(extracted_data, "translated_english_document2.pdf")
# Out:
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 一、适用范围
# Translating chunk: 本指南旨在提供我国的化妆品主要出口目标国家（地区）在化妆品标签方面
# Translating chunk: 的法规、标准、要求以及与我国的差异，提出达到目标市场要求的建议和指南。
# Translating chunk: 适用于所有出口或准备出口的化妆品企业。
# Translating chunk: MOFCOM
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 二、进出口化妆品基本情况概述
# Translating chunk: 2.1术语和定义
# Translating chunk: 化妆品cosmetios：指以涂抹、洒、喷或其它类似方式，施于人体表面任何部位
# Translating chunk: （皮肤、毛发、指甲、口唇）、牙齿和口腔粘膜，以达到清洁、芳香、改变外观、
# Translating chunk: 修正人体气味、保养、保持良好状态目的的产品。
# Translating chunk: 标签labelling：指粘贴或连接或印在化妆品销售包装上的文字、数字、符号、
# Translating chunk: 图案和置于销售包装内的说明性材料。
# Translating chunk: 销售包装salespaokaging：指以销售为目的，与内装物一起交付给消费者的包
# Translating chunk: 装。
# Translating chunk: 内装物contents：指包装容器内所装的产品。
# Translating chunk: 展示面displaypanels：指化妆品在陈列时，在自然状态下被消费者能看见的
# Translating chunk: 面。
# Translating chunk: 可视面visiblepanels：指化妆品在不破坏销售包装的情况下，消费者能够看
# Translating chunk: 到的任何面。
# Translating chunk: 净含量netcontent：指去除包装容器和其它包装材料后，内装物的实际质量或
# Translating chunk: 体积或长度。
# Translating chunk: 保质期sheIflife：指在化妆品产品标准和标签规定的条件下，保持化妆品品
# Translating chunk: 质的期限。在此期限内，化妆品完全适于销售，并符合产品标准和标签中所规定
# Translating chunk: 的品质。
# Translating chunk: 限期使用日期expirationdate：指在化妆品产品标准和标签规定的条件下，化
# Translating chunk: 妆品最佳的使用日期。在此期限内，化妆品完全适于销售，并符合产品标准和标
# Translating chunk: 签上所规定的品质。超过此期限，化妆品的品质可能会发生变化，此化妆品不再
# Translating chunk: 适于销售。
# Translating chunk: 裸装产品primarypaokagingproduct：指一次包装的化妆品。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 本指南中涉及的商品为化妆品产品，该类产品对应的海关出口目录商品编码
# Translating chunk: 如表2.1所示（数据来自中华人民共和国海关总署编《中国海关统计年鉴》）。
# Translating chunk: 表2.1化妆品类产品对应海关编码列表
# Translating chunk: 产品名称
# Translating chunk: 商品编号（海关编）
# Translating chunk: 精油包括浸膏及净油：香膏：提取的油树脂
# Translating chunk: 3301
# Translating chunk: 橙油
# Translating chunk: 33011200
# Translating chunk: 柠檬油
# Translating chunk: 33011300
# Translating chunk: 白柠檬油（酸橙油）
# Translating chunk: 33011910
# Translating chunk: 其他柑橘属果实精油
# Translating chunk: 33011990
# Translating chunk: 胡椒薄荷油
# Translating chunk: 33012400
# Translating chunk: 其他薄荷油
# Translating chunk: 33012500
# Translating chunk: 樟脑油
# Translating chunk: 33012910
# Translating chunk: 香茅油
# Translating chunk: 33012920
# Translating chunk: 茴香油
# Translating chunk: 33012930
# Translating chunk: 桂油
# Translating chunk: 33012940
# Translating chunk: 山苍子油
# Translating chunk: 33012950
# Translating chunk: 桉叶油
# Translating chunk: 33012960
# Translating chunk: 老鹤草油（香叶油）
# Translating chunk: 33012991
# Translating chunk: 未列名非柑橘属果实精油
# Translating chunk: 33012999
# Translating chunk: 鸢尾凝脂
# Translating chunk: 33013010
# Translating chunk: 其他香膏
# Translating chunk: 33013090
# Translating chunk: 提取的油树脂
# Translating chunk: 33019010
# Translating chunk: 柑桔属果实的精油脱的烯副产品
# Translating chunk: 33019020
# Translating chunk: 含浓缩精油的制品：其他烯副产品及精油液
# Translating chunk: 33019090
# Translating chunk: 香水及花露水
# Translating chunk: 3303
# Translating chunk: 香水及花露水
# Translating chunk: 33030000
# Translating chunk: 美容品或化妆品及护肤品：指（趾）甲化妆品
# Translating chunk: 3304
# Translating chunk: 唇用化妆品
# Translating chunk: 33041000
# Translating chunk: 眼用化妆品
# Translating chunk: 33042000
# Translating chunk: 3
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: （续表）
# Translating chunk: 产品名称
# Translating chunk: 商品编号（海关编）
# Translating chunk: 指（趾）甲化妆品
# Translating chunk: 33043000
# Translating chunk: 香粉，不论是否压紧
# Translating chunk: 33049100
# Translating chunk: 其他美容品或化妆品及护肤品
# Translating chunk: 33049900
# Translating chunk: 护发品
# Translating chunk: 3305
# Translating chunk: 洗发剂（香波）
# Translating chunk: 33051000
# Translating chunk: 烫发剂
# Translating chunk: 33052000
# Translating chunk: 定型剂
# Translating chunk: 33053000
# Translating chunk: 其他护发品
# Translating chunk: 33059000
# Translating chunk: 口腔及牙齿清洁剂：清洁牙缝用的纱线（牙线）
# Translating chunk: 3306
# Translating chunk: 牙膏
# Translating chunk: 33061010
# Translating chunk: 其他洁齿品
# Translating chunk: 33061090
# Translating chunk: 清洁牙缝用纱线（牙线）
# Translating chunk: 33062000
# Translating chunk: 口腔清洁剂
# Translating chunk: 33069000
# Translating chunk: 芳香料制品及化妆盟洗品：
# Translating chunk: 3307
# Translating chunk: 剃须用制剂
# Translating chunk: 33071000
# Translating chunk: 人体除臭剂及止汗剂
# Translating chunk: 33072000
# Translating chunk: 香浴盐及其他沐浴用制剂
# Translating chunk: 33073000
# Translating chunk: 脱毛剂和未列名的芳香料制品及化妆盟洗品
# Translating chunk: 33079000
# Translating chunk: 2.2最新海关统计口径
# Translating chunk: 统计口径为：该类产品的年度进出口总金额及数量。
# Translating chunk: 2.3近5年来的进出口额统计
# Translating chunk: 2.3.12007~2011年中国化妆品进出口额统计
# Translating chunk: 近5年来，我国化妆品进出口总体呈现增长趋势，且近两年增长迅速。据统
# Translating chunk: 计数据显示，2011年较2007年，我国化妆品出口数量增长42.77万吨，增幅达
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 175.51%，出口金额增长14.93亿美元，增幅达145.17%：化妆品进口数量上增
# Translating chunk: 长5.51万吨，增幅达103.50%，进口金额增长14.74亿美元，增幅达214.34%，
# Translating chunk: 我国化妆品贸易主要以出口为主。随着结构的调整，近年逐步趋向进出口贸
# Translating chunk: 易平衡。据统计数据显示，2007年到2011年，我国化妆品贸易顺差由3.41亿美
# Translating chunk: 元下滑至0.00亿美元，继而小幅增长至3.60亿美元，走势渐趋平稳。这一期间，
# Translating chunk: 我国化妆品进出口贸易总额由17.16亿美元增至46.84亿美元，增幅达172.88%。
# Translating chunk: 相比贸易值的快速增长，我国化妆品在质的方面还存在较大劣势。2007年，
# Translating chunk: 化妆品进口平均单价为12.92美元/千克，出口平均单价为4.22美元/千克，为进
# Translating chunk: 口单价的32.66%：2011年，化妆品进口平均单价为19.96美元/千克，出口平均
# Translating chunk: 单价为3.76美元/千克，为进口单价的18.84%。可以看出，差距仍在进一步扩大。
# Translating chunk: 这种价格方面的劣势说明我国出口化妆品含金量低，维持贸易增长是建立在大量
# Translating chunk: 出口基础上，是以价值牺牲为代价换取的。这种状况给我国的化妆品生产企业提
# Translating chunk: 出了非常严峻的课题，应尽快改善产品质量，大力提高附加值。
# Translating chunk: 表2.22007-2011年我国化妆品出口数量、金额一览表
# Translating chunk: 年份
# Translating chunk: 数量
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: 金额
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: （万吨）
# Translating chunk: （万吨）
# Translating chunk: （%）
# Translation returned None for chunk: （%）
# Translating chunk: （亿美元）
# Translating chunk: （亿美元）
# Translating chunk: (%)
# Translation returned None for chunk: (%)
# Translating chunk: 2007
# Translating chunk: 24.37
# Translating chunk: 一
# Translating chunk: 10.29
# Translating chunk: 一
# Translating chunk: 2008
# Translating chunk: 20.20
# Translating chunk: -4.17
# Translating chunk: -17.11
# Translating chunk: 9.36
# Translating chunk: -0.93
# Translating chunk: -9.04
# Translating chunk: 2009
# Translating chunk: 31.37
# Translating chunk: 11.17
# Translating chunk: 55.30
# Translating chunk: 11.66
# Translating chunk: 2.30
# Translating chunk: 24.57
# Translating chunk: 2010
# Translating chunk: 41.58
# Translating chunk: 10.21
# Translating chunk: 32.55
# Translating chunk: 17.50
# Translating chunk: 5.84
# Translating chunk: 50.09
# Translating chunk: 2011
# Translating chunk: 67.14
# Translating chunk: 25.56
# Translating chunk: 61.47
# Translating chunk: 25.22
# Translating chunk: 7.72
# Translating chunk: 44.11
# Translating chunk: 表2.3
# Translating chunk: 2007~2011年化妆品进口数量、金额一览表
# Translating chunk: 年份
# Translating chunk: 数量
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: 金额
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: （万吨）
# Translating chunk: （万吨）
# Translating chunk: （%）
# Translation returned None for chunk: （%）
# Translating chunk: （亿美元）
# Translating chunk: （亿美元）
# Translating chunk: （%）
# Translation returned None for chunk: （%）
# Translating chunk: 2007
# Translating chunk: 5.32
# Translating chunk: 一
# Translating chunk: 一
# Translating chunk: 6.88
# Translating chunk: 一
# Translating chunk: 一
# Translating chunk: 2008
# Translating chunk: 6.11
# Translating chunk: 0.79
# Translating chunk: 14.85
# Translating chunk: 9.36
# Translating chunk: 2.48
# Translating chunk: 36.05
# Translating chunk: 2009
# Translating chunk: 5.90
# Translating chunk: -0.21
# Translating chunk: -3.44
# Translating chunk: 10.70
# Translating chunk: 1.34
# Translating chunk: 14.32
# Translating chunk: 2010
# Translating chunk: 7.55
# Translating chunk: 1.65
# Translating chunk: 27.97
# Translating chunk: 15.00
# Translating chunk: 4.30
# Translating chunk: 40.19
# Translating chunk: 2011
# Translating chunk: 10.83
# Translating chunk: 3.28
# Translating chunk: 43.44
# Translating chunk: 21.62
# Translating chunk: 6.62
# Translating chunk: 44.13
# Translating chunk: 5
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 出口
# Translating chunk: 进口
# Translating chunk: 单位：万吨
# Translating chunk: 80
# Translating chunk: 60
# Translating chunk: 40
# Translating chunk: 20
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 图2.12007~2011年我国化妆品进出口数量分析图
# Translating chunk: 出口
# Translating chunk: 进口
# Translating chunk: 单位：亿美元
# Translating chunk: 30
# Translating chunk: 20
# Translating chunk: 15
# Translating chunk: 10
# Translating chunk: 5
# Translating chunk: 0
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 图2.22007-2011年我国化妆品进出口金额分析图
# Translating chunk: 2.3.22007~2011年中国化妆品出口构成
# Translating chunk: 近5年来，我国化妆品出口主要以肤用化妆品、发用化妆品、口腔类化妆品
# Translating chunk: 及美容化妆品为主，占总出口额的80%以上。其中，增幅列居首位的是肤用化妆
# Translating chunk: 品，其平均年增长达1.42亿美元，所占比重上升了14%：其次是口腔类化妆品，
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 平均年增长达0.61亿美元，所占比重上升8%：再者是美容化妆品，平均年增长
# Translating chunk: 达0.36亿美元，所占比重下降23%：其余种类增幅相对较低。
# Translating chunk: 表2.42007-2011年我国各类化妆品出口数量、金额一览表
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 化妆品类别
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 肤用化妆品
# Translating chunk: 4.18
# Translating chunk: 2.32
# Translating chunk: 4.86
# Translating chunk: 2.25
# Translating chunk: 11.38
# Translating chunk: 3.46
# Translating chunk: 14.49
# Translating chunk: 6.12
# Translating chunk: 21.76
# Translating chunk: 9.43
# Translating chunk: 发用化妆品
# Translating chunk: 6.09
# Translating chunk: 1.23
# Translating chunk: 5.53
# Translating chunk: 1.19
# Translating chunk: 6.97
# Translating chunk: 1.41
# Translating chunk: 10.06
# Translating chunk: 1.90
# Translating chunk: 10.21
# Translating chunk: 2.26
# Translating chunk: 口腔类化妆品
# Translating chunk: 3.50
# Translating chunk: 0.71
# Translating chunk: 2.14
# Translating chunk: 0.43
# Translating chunk: 5.61
# Translating chunk: 0.97
# Translating chunk: 7.65
# Translating chunk: 1.36
# Translating chunk: 20.60
# Translating chunk: 3.74
# Translating chunk: 美容化妆品
# Translating chunk: 8.91
# Translating chunk: 5.38
# Translating chunk: 6.40
# Translating chunk: 5.00
# Translating chunk: 5.28
# Translating chunk: 4.82
# Translating chunk: 6.60
# Translating chunk: 6.63
# Translating chunk: 7.07
# Translating chunk: 7.18
# Translating chunk: 香水类化妆品
# Translating chunk: 0.85
# Translating chunk: 0.53
# Translating chunk: 0.73
# Translating chunk: 0.42
# Translating chunk: 1.36
# Translating chunk: 0.73
# Translating chunk: 1.81
# Translating chunk: 1.07
# Translating chunk: 2.56
# Translating chunk: 1.21
# Translating chunk: 特殊功能化妆品
# Translating chunk: 0.78
# Translating chunk: 0.11
# Translating chunk: 0.44
# Translating chunk: 0.07
# Translating chunk: 0.68
# Translating chunk: 0.26
# Translating chunk: 0.77
# Translating chunk: 0.26
# Translating chunk: 0.82
# Translating chunk: 0.33
# Translating chunk: 其他化妆品
# Translating chunk: 0.05
# Translating chunk: 0.01
# Translating chunk: 0.10
# Translating chunk: 0.01
# Translating chunk: 0.08
# Translating chunk: 0.01
# Translating chunk: 0.21
# Translating chunk: 0.17
# Translating chunk: 4.11
# Translating chunk: 1.06
# Translating chunk: 总计
# Translating chunk: 24.37
# Translating chunk: 10.29
# Translating chunk: 20.20
# Translating chunk: 9.36
# Translating chunk: 31.37
# Translating chunk: 1.66
# Translating chunk: 41.58
# Translating chunk: 17.50
# Translating chunk: 67.14
# Translating chunk: 25.22
# Translating chunk: 单位：亿美元
# Translating chunk: 10
# Translating chunk: ■2007年2008年2009年2010年2011年
# Translating chunk: 图2.32007~2011年我国各类化妆品出口金额分析图
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 香水类化妆品
# Translating chunk: 口腔类化妆品
# Translating chunk: 特殊功能化妆
# Translating chunk: 5%
# Translating chunk: 发用化妆品
# Translating chunk: 7%
# Translating chunk: 品1%
# Translating chunk: 其他化妆品
# Translating chunk: 12%
# Translating chunk: 0%
# Translating chunk: 肤用化妆品
# Translating chunk: 美容化妆品
# Translating chunk: 23%
# Translating chunk: 52%
# Translating chunk: 图2.42007年我国各类化妆品出口金额占比分析图
# Translating chunk: 香水类化妆品
# Translating chunk: 其他化妆品4%
# Translating chunk: 发用化妆品9%
# Translating chunk: 5%
# Translating chunk: 特殊功能化妆
# Translating chunk: 品1%
# Translating chunk: 口腔类化妆品
# Translating chunk: 15%
# Translating chunk: 肤用化妆品
# Translating chunk: 美容化妆品
# Translating chunk: 37%
# Translating chunk: 29%
# Translating chunk: 图2.52
# Translating chunk: 2011年我国各类化妆品出口金额占比分析图
# Translating chunk: 2.4近年的主要出口目标市场
# Translating chunk: 2.4.12007~2011年中国化妆品出口五大洲数量及金额分析
# Translating chunk: 据统计数据显示，亚洲、美洲和欧洲为我国化妆品主要出口地区。相比2007
# Translating chunk: 年，2011年我国化妆品出口亚洲的数量和金额分别增长了13.03万吨和6.14亿
# Translating chunk: 美元，所占比重前者下降3%，后者上升19%：出口美洲的数量和金额分别增长
# Translating chunk: 了8.25万吨和2.76亿美元，所占比重依次下降5%和10%：出口欧洲的数量和
# Translating chunk: 金额分别增长了9.87万吨和3.88亿美元，所占比重前者上升6%，后者下降7%；
# Translating chunk: 出口非洲的数量和金额分别增加了2.63万吨和0.53亿美元，所占比重依次上升
# Translating chunk: 3%和1%：出口大洋洲的数量和金额分别增加了0.61万吨和0.01亿美元，所占
# Translating chunk: 比重依次下降1%和3%。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 表2.52007~2011年化妆品出口五大洲数量及金额
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 洲别
# Translating chunk: 亚洲
# Translating chunk: 美洲
# Translating chunk: 欧洲
# Translating chunk: 非洲
# Translating chunk: 大洋洲
# Translating chunk: 年份
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 2007
# Translating chunk: 9.60
# Translating chunk: 2.93
# Translating chunk: 7.40
# Translating chunk: 3.35
# Translating chunk: 4.36
# Translating chunk: 1.97
# Translating chunk: 0.78
# Translating chunk: 0.20
# Translating chunk: 0.91
# Translating chunk: 0.44
# Translating chunk: 2008
# Translating chunk: 9.53
# Translating chunk: 3.56
# Translating chunk: 4.73
# Translating chunk: 2.47
# Translating chunk: 3.31
# Translating chunk: 1.96
# Translating chunk: 1.40
# Translating chunk: 0.31
# Translating chunk: 0.46
# Translating chunk: 0.14
# Translating chunk: 2009
# Translating chunk: 14.38
# Translating chunk: 4.83
# Translating chunk: 6.96
# Translating chunk: 2.71
# Translating chunk: 6.52
# Translating chunk: 2.61
# Translating chunk: 1.67
# Translating chunk: 0.35
# Translating chunk: 0.70
# Translating chunk: 0.19
# Translating chunk: 2010
# Translating chunk: 17.82
# Translating chunk: 6.06
# Translating chunk: 9.67
# Translating chunk: 3.92
# Translating chunk: 8.24
# Translating chunk: 4.21
# Translating chunk: 1.99
# Translating chunk: 0.44
# Translating chunk: 0.78
# Translating chunk: 0.25
# Translating chunk: 2011
# Translating chunk: 22.63
# Translating chunk: 9.07
# Translating chunk: 15.64
# Translating chunk: 6.11
# Translating chunk: 14.23
# Translating chunk: 5.85
# Translating chunk: 3.41
# Translating chunk: 0.73
# Translating chunk: 1.53
# Translating chunk: 0.45
# Translating chunk: 非洲
# Translating chunk: 大洋洲
# Translating chunk: 3%
# Translating chunk: 4%
# Translating chunk: 欧洲
# Translating chunk: 19%
# Translating chunk: 亚洲
# Translating chunk: 42%
# Translating chunk: 美洲
# Translating chunk: 32%
# Translating chunk: 图2.6
# Translating chunk: 2007年我国出口各大洲化妆品数量占比分析图
# Translating chunk: 大洋洲
# Translating chunk: 非洲
# Translating chunk: 6%
# Translating chunk: 3%
# Translating chunk: 欧洲
# Translating chunk: 亚洲
# Translating chunk: 25%
# Translating chunk: 39%
# Translating chunk: 美洲
# Translating chunk: 27%
# Translating chunk: 图2.72011年我国出口各大洲化妆品金额占比分析图
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 大洋洲
# Translating chunk: 非洲
# Translating chunk: 5%
# Translating chunk: 2%
# Translating chunk: 亚洲
# Translating chunk: 22%
# Translating chunk: 欧洲
# Translating chunk: 33%
# Translating chunk: 美洲
# Translating chunk: 38%
# Translating chunk: 图2.82007年我国出口各大洲化妆品金额占比分析图
# Translating chunk: 非洲
# Translating chunk: 大洋洲
# Translating chunk: 3%
# Translating chunk: 2%
# Translating chunk: 欧洲
# Translating chunk: 26%
# Translating chunk: 亚洲
# Translating chunk: 41%
# Translating chunk: 美洲
# Translating chunk: 28%
# Translating chunk: 图2.92011年我国出口各大洲化妆品金额占比分析图
# Translating chunk: 2.4.22007~2011年中国化妆品主要出口地区数量及金额分析
# Translating chunk: 近5年来，北美、欧盟和香港地区一直是我国化妆品出口较多的地区。2011
# Translating chunk: 年较2007年，出口至北美地区的数量和金额分别增长了6.68万吨和2.04亿美元，
# Translating chunk: 所占比重依次下降2%和9%：出口至欧盟地区的数量和金额分别增长了4.52万
# Translating chunk: 吨和3.00亿美元，所占比重依次上升2%和3%：出口至香港地区的数量和金额
# Translating chunk: 分别增长了5.82万吨和2.75亿美元，数量所占比重下降3%，金额所占比重上升
# Translating chunk: 4%。2011年出口到这3个地区的数量和金额均占化妆品出口总量和总额的60%
# Translating chunk: 10
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 以上。
# Translating chunk: 表2.6
# Translating chunk: 2007-2011年我国化妆品主要出口地区数量及金额
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 地区
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 北美
# Translating chunk: 6.56
# Translating chunk: 3.04
# Translating chunk: 3.90
# Translating chunk: 2.14
# Translating chunk: 6.07
# Translating chunk: 2.36
# Translating chunk: 7.93
# Translating chunk: 3.26
# Translating chunk: 13.24
# Translating chunk: 5.08
# Translating chunk: 欧盟
# Translating chunk: 2.89
# Translating chunk: 1.60
# Translating chunk: 2.85
# Translating chunk: 1.81
# Translating chunk: 3.56
# Translating chunk: 2.09
# Translating chunk: 4.79
# Translating chunk: 3.58
# Translating chunk: 7.41
# Translating chunk: 4.60
# Translating chunk: 香港
# Translating chunk: 6.10
# Translating chunk: 1.37
# Translating chunk: 5.48
# Translating chunk: 1.93
# Translating chunk: 8.92
# Translating chunk: 2.66
# Translating chunk: 10.63
# Translating chunk: 3.34
# Translating chunk: 11.92
# Translating chunk: 4.12
# Translating chunk: 东亚
# Translating chunk: 0.96
# Translating chunk: 0.66
# Translating chunk: 0.82
# Translating chunk: 0.74
# Translating chunk: 1.06
# Translating chunk: 0.82
# Translating chunk: 1.79
# Translating chunk: 1.01
# Translating chunk: 2.93
# Translating chunk: 1.51
# Translating chunk: 东盟
# Translating chunk: 0.96
# Translating chunk: 0.80
# Translating chunk: 0.65
# Translating chunk: 0.86
# Translating chunk: 0.99
# Translating chunk: 0.90
# Translating chunk: 1.37
# Translating chunk: 1.29
# Translating chunk: 2.33
# Translating chunk: 1.70
# Translating chunk: 台湾
# Translating chunk: 0.82
# Translating chunk: 0.31
# Translating chunk: 0.81
# Translating chunk: 0.36
# Translating chunk: 1.23
# Translating chunk: 0.47
# Translating chunk: 1.41
# Translating chunk: 0.56
# Translating chunk: 1.57
# Translating chunk: 0.62
# Translating chunk: 中东
# Translating chunk: 1.26
# Translating chunk: 0.47
# Translating chunk: 1.42
# Translating chunk: 0.41
# Translating chunk: 1.46
# Translating chunk: 0.52
# Translating chunk: 1.71
# Translating chunk: 0.60
# Translating chunk: 2.42
# Translating chunk: 0.80
# Translating chunk: 拉美
# Translating chunk: 0.83
# Translating chunk: 0.31
# Translating chunk: 0.82
# Translating chunk: 0.33
# Translating chunk: 0.86
# Translating chunk: 0.33
# Translating chunk: 1.71
# Translating chunk: 0.65
# Translating chunk: 2.37
# Translating chunk: 1.02
# Translating chunk: 东欧
# Translating chunk: 1.43
# Translating chunk: 0.36
# Translating chunk: 0.44
# Translating chunk: 0.14
# Translating chunk: 2.93
# Translating chunk: 0.50
# Translating chunk: 1.37
# Translating chunk: 1.29
# Translating chunk: 2.33
# Translating chunk: 1.70
# Translating chunk: 大洋洲
# Translating chunk: 0.91
# Translating chunk: 0.44
# Translating chunk: 0.45
# Translating chunk: 0.14
# Translating chunk: 0.70
# Translating chunk: 0.19
# Translating chunk: 0.78
# Translating chunk: 0.25
# Translating chunk: 1.52
# Translating chunk: 0.45
# Translating chunk: 非洲
# Translating chunk: 0.78
# Translating chunk: 0.20
# Translating chunk: 1.40
# Translating chunk: 0.31
# Translating chunk: 1.67
# Translating chunk: 0.35
# Translating chunk: 1.99
# Translating chunk: 0.44
# Translating chunk: 3.41
# Translating chunk: 0.73
# Translating chunk: [注]北美：美国、加拿大，共2国：
# Translating chunk: 欧盟：法国、意大利、荷兰、比利时、卢森堡、德国、爱尔兰、丹麦、英国、希腊、
# Translating chunk: 葡萄牙、西班牙、奥地利、芬兰、瑞典、波兰、拉脱维亚、立陶宛、爱沙尼亚、
# Translating chunk: 匈牙利、捷克、斯洛伐克、斯洛文尼亚、马耳他、塞浦路斯、保加利亚、罗马
# Translating chunk: 尼亚，共27国：
# Translating chunk: 东亚：日本、韩国、朝鲜、蒙古，共4国：
# Translating chunk: 东盟：印度尼西亚、新加坡、泰国、菲律宾、马来西亚、文莱、缅甸、越南、老挝、
# Translating chunk: 柬埔赛，共10国：
# Translating chunk: 中东：巴林、埃及、伊朗、伊拉克、以色列、约旦、科威特、黎巴嫩、阿曼、卡塔尔、
# Translating chunk: 沙特阿拉伯、叙利亚、阿拉伯联合首长国、也门、巴勒斯坦、阿尔及利亚、利
# Translating chunk: 比亚、摩洛哥、突尼斯、苏丹、毛里塔尼亚、索马里，共22国：
# Translating chunk: 东欧：俄罗斯联邦、白俄罗斯、乌克兰、摩尔多瓦，共4国。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 东欧6%中东5%
# Translating chunk: 东盟4%
# Translating chunk: 欧盟12%
# Translating chunk: 东亚4%
# Translating chunk: 大洋洲4%
# Translating chunk: 拉美4%
# Translating chunk: 香港26%
# Translating chunk: 其他15%
# Translating chunk: 台湾4%
# Translating chunk: 非洲3%
# Translating chunk: 北美28%
# Translating chunk: 图2.10
# Translating chunk: 2007年我国化妆品主要出口地区数量分布占比分析图
# Translating chunk: 东亚6%
# Translating chunk: 非洲
# Translating chunk: 中东5%
# Translating chunk: 7%
# Translating chunk: 拉美5%
# Translating chunk: 欧盟14%
# Translating chunk: 东盟4%
# Translating chunk: 其他14%
# Translating chunk: 东欧4%
# Translating chunk: 香港23%
# Translating chunk: 台湾3%
# Translating chunk: 大洋洲3%
# Translating chunk: 北美26%
# Translating chunk: 图2.11
# Translating chunk: 2011年我国化妆品主要出口地区数量分布占比分析图
# Translating chunk: 东盟
# Translating chunk: 东亚
# Translating chunk: 中东5%
# Translating chunk: 8%
# Translating chunk: 7%
# Translating chunk: 大洋洲5
# Translating chunk: 香港14%
# Translating chunk: 东欧4%
# Translating chunk: 其他12%
# Translating chunk: 台湾3%
# Translating chunk: 欧盟17%
# Translating chunk: 拉美3%
# Translating chunk: 北美32%
# Translating chunk: 非洲2%
# Translating chunk: 图2.122007年我国化妆品主要出口地区金额分布占比分析图
# Translating chunk: 12
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 东盟
# Translating chunk: 东欧
# Translating chunk: 东亚7%
# Translating chunk: 8%
# Translating chunk: 8%
# Translating chunk: 拉美4
# Translating chunk: 中东3%
# Translating chunk: 香港18%
# Translating chunk: 其他11%
# Translating chunk: 非3%
# Translating chunk: 欧盟21%
# Translating chunk: 台湾3%
# Translating chunk: 北美23%
# Translating chunk: 大洋洲2%
# Translating chunk: 图2.132011年我国化妆品主要出口地区金额分布占比分析图
# Translating chunk: 2.4.32007~20011年中国化妆品主要出口国家或地区数量及金额分析
# Translating chunk: 2011年，我国化妆品出口贸易共涉及180多个国家或地区。以金额计，列
# Translating chunk: 居前十的国家或地区依次为：美国、香港、英国、保税区、日本、俄罗斯、法国、
# Translating chunk: 波兰、新加坡和台湾。其2011年共计从我国进口化妆品40.82万吨，价值17.58
# Translating chunk: 亿美元，分别占比60.79%和69.70%.其中美国和香港远超其他国家或地区，出
# Translating chunk: 口数量和金额占比均大于50%。然而从出口平均单价来看，新加坡、波兰和法国
# Translating chunk: 优势明显，价格较高，俄罗斯最低，仅为1.78美元/千克，约为新加坡的1/10。
# Translating chunk: 表2.72007~2011年我国化妆品主要出口国家（地区）数量及金额分布
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 国家
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 美国
# Translating chunk: 6.36
# Translating chunk: 2.98
# Translating chunk: 3.70
# Translating chunk: 2.06
# Translating chunk: 5.81
# Translating chunk: 2.29
# Translating chunk: 7.58
# Translating chunk: 3.14
# Translating chunk: 12.46
# Translating chunk: 4.85
# Translating chunk: 香港
# Translating chunk: 6.10
# Translating chunk: 1.37
# Translating chunk: 5.48
# Translating chunk: 1.93
# Translating chunk: 8.92
# Translating chunk: 2.66
# Translating chunk: 10.63
# Translating chunk: 3.34
# Translating chunk: 11.92
# Translating chunk: 4.12
# Translating chunk: 英国
# Translating chunk: 1.10
# Translating chunk: 0.40
# Translating chunk: 1.26
# Translating chunk: 0.56
# Translating chunk: 1.66
# Translating chunk: 0.77
# Translating chunk: 2.21
# Translating chunk: 1.13
# Translating chunk: 3.77
# Translating chunk: 1.65
# Translating chunk: 保税区
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.10
# Translating chunk: 0.10
# Translating chunk: 1.23
# Translating chunk: 1.37
# Translating chunk: 日本
# Translating chunk: 0.73
# Translating chunk: 0.59
# Translating chunk: 0.58
# Translating chunk: 0.65
# Translating chunk: 0.77
# Translating chunk: 0.71
# Translating chunk: 1.44
# Translating chunk: 0.87
# Translating chunk: 2.23
# Translating chunk: 1.27
# Translating chunk: 俄罗斯
# Translating chunk: 1.15
# Translating chunk: 0.26
# Translating chunk: 0.39
# Translating chunk: 0.11
# Translating chunk: 2.45
# Translating chunk: 0.40
# Translating chunk: 2.68
# Translating chunk: 0.47
# Translating chunk: 6.12
# Translating chunk: 1.09
# Translating chunk: 法国
# Translating chunk: 0.32
# Translating chunk: 0.45
# Translating chunk: 0.23
# Translating chunk: 0.52
# Translating chunk: 0.27
# Translating chunk: 0.50
# Translating chunk: 0.43
# Translating chunk: 0.86
# Translating chunk: 0.54
# Translating chunk: 0.93
# Translating chunk: 13
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: （续表）
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 国家
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 波兰
# Translating chunk: 0.03
# Translating chunk: 0.02
# Translating chunk: 0.14
# Translating chunk: 0.13
# Translating chunk: 0.11
# Translating chunk: 0.13
# Translating chunk: 0.40
# Translating chunk: 0.69
# Translating chunk: 0.49
# Translating chunk: 0.85
# Translating chunk: 新加坡
# Translating chunk: 0.31
# Translating chunk: 0.42
# Translating chunk: 0.22
# Translating chunk: 0.48
# Translating chunk: 0.35
# Translating chunk: 0.46
# Translating chunk: 0.41
# Translating chunk: 0.72
# Translating chunk: 0.48
# Translating chunk: 0.84
# Translating chunk: 台湾
# Translating chunk: 0.82
# Translating chunk: 0.31
# Translating chunk: 0.81
# Translating chunk: 0.36
# Translating chunk: 1.23
# Translating chunk: 0.47
# Translating chunk: 1.41
# Translating chunk: 0.56
# Translating chunk: 1.57
# Translating chunk: 0.62
# Translating chunk: 俄罗斯15%
# Translating chunk: 英国9%
# Translating chunk: 日本6
# Translating chunk: 台湾4%
# Translating chunk: 香港29%
# Translating chunk: 其他10%
# Translating chunk: 保税区3%
# Translating chunk: 法国
# Translating chunk: 1%
# Translating chunk: 波兰1%
# Translating chunk: 美国31%
# Translating chunk: 新加坡1%
# Translating chunk: 图2.142011年我国化妆品主要出口国家或地区数量分布占比分析图
# Translating chunk: 保税区
# Translating chunk: 英国9%
# Translating chunk: 8%
# Translating chunk: 日本
# Translating chunk: 7%
# Translating chunk: 俄罗斯6%
# Translating chunk: 法国5%
# Translating chunk: 香港23%
# Translating chunk: 其他25%
# Translating chunk: 波兰5%
# Translating chunk: 新加坡5%
# Translating chunk: 台湾4%
# Translating chunk: 美国28%
# Translating chunk: 图2.152011年我国化妆品主要出口国家或地区金额分布占比分析图
# Translating chunk: 14
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 单位：美元/千克
# Translating chunk: 20
# Translating chunk: 17.30
# Translating chunk: 17.38
# Translating chunk: 15
# Translating chunk: 17.50
# Translating chunk: 11.10
# Translating chunk: 10
# Translating chunk: 4.37
# Translating chunk: 5.66
# Translating chunk: 3.90
# Translating chunk: 3.45
# Translating chunk: 1.78
# Translating chunk: 3.91
# Translating chunk: 美国
# Translating chunk: 香港
# Translating chunk: 英国
# Translating chunk: 保税区
# Translating chunk: 日本
# Translating chunk: 俄罗斯
# Translating chunk: 法国
# Translating chunk: 波兰
# Translating chunk: 新加坡台湾
# Translating chunk: 图2.16
# Translating chunk: 2011年我国化妆品主要出口国家出口化妆品平均单价
# Translating chunk: 此外，较2007年，以上10个国家或地区的出口贸易均呈现出不同程度的增
# Translating chunk: 长，按金额统计，增幅列居前三的国家依次为：波兰、俄罗斯和英国。
# Translating chunk: 单位：万吨
# Translating chunk: 14
# Translating chunk: 2007年
# Translating chunk: 12
# Translating chunk: 2011年
# Translating chunk: 10
# Translating chunk: 美国
# Translating chunk: 香港英国保税区日本俄罗斯法国波兰新加坡台湾
# Translating chunk: 图2.172007、2011年我国化妆品主要出口国家或地区数量分析图
# Translating chunk: 15
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 单位：亿美元
# Translating chunk: 2007年
# Translating chunk: 2011年
# Translating chunk: 美国
# Translating chunk: 香港
# Translating chunk: 英国保税区日本俄罗斯法国
# Translating chunk: 波兰新加坡台湾
# Translating chunk: 图2.182007、2011年我国化妆品主要出口国家或地区金额分析图
# Translating chunk: 2.4.4主要出口目标市场分析
# Translating chunk: 2.4.4.1美国
# Translating chunk: 美国是化妆品业的全球巨头。2011年我国对美出口化妆品共计4.85亿美元，
# Translating chunk: 其中肤用化妆品出口2.16亿美元，占比44%：美容化妆品出口1.79亿美元，占
# Translating chunk: 比37%：其他化妆品出口0.29亿美元，占比6%：香水类化妆品出口0.28亿美
# Translating chunk: 元，占比6%：发用化妆品出口0.27亿美元，占比6%：特殊功能化妆品出口0.04
# Translating chunk: 亿美元，占比1%：口腔类化妆品出口0.02亿美元，占比不足0.5%
# Translating chunk: 其他化妆品6%
# Translating chunk: 美容化妆品
# Translating chunk: 香水类化妆品
# Translating chunk: 37%
# Translating chunk: 6%
# Translating chunk: 发用化妆品6%
# Translating chunk: 特殊功能化妆
# Translating chunk: 品1%
# Translating chunk: 口腔类化妆品
# Translating chunk: 肤用化妆品
# Translating chunk: 0%
# Translating chunk: 44%
# Translating chunk: 图2.192011年我国各类化妆品出口至美国金额占比分析图
# Translating chunk: 16
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 2.4.4.2日本
# Translating chunk: 日本在化妆品生产和消费方面均为比较发达的国家，市场规模仅次于美国。
# Translating chunk: 其拥有亚洲最大的化妆品市场和研究开发中心，在经历高速发展之后，目前已进
# Translating chunk: 入成熟期。2011年我国对日出口化妆品共计1.27亿美元，其中肤用化妆品出口
# Translating chunk: 0.47亿美元，占比37%：美容化妆品出口0.40亿美元，占比32%：发用化妆品
# Translating chunk: 出口0.31亿美元，占比25%：特殊功能化妆品出口0.05亿美元，占比4%：其
# Translating chunk: 他化妆品出口0.02亿美元，占比1%：口腔类化妆品出口0.01亿美元，占比1%：
# Translating chunk: 香水类化妆品出口较小，不足0.01亿美元。
# Translating chunk: 发用化妆品
# Translating chunk: 特殊功能化妆
# Translating chunk: 25%
# Translating chunk: 品4%
# Translating chunk: 其他化妆品1%
# Translating chunk: 美容化妆品
# Translating chunk: 口腔类化妆品
# Translating chunk: 32%
# Translating chunk: 1%
# Translating chunk: 香水类化妆品
# Translating chunk: 肤用化妆品
# Translating chunk: 0%
# Translating chunk: 37%
# Translating chunk: 图2.202011年我国各类化妆品出口至日本金额占比分析图
# Translating chunk: 2.4.4.3欧盟
# Translating chunk: 欧盟是我国最大的贸易伙伴，其化妆品制造业尤为发达，英国、法国、德国、
# Translating chunk: 意大利等都是传统的化妆品制造强国，拥有众多大型化妆品企业和久负胜名的化
# Translating chunk: 妆品领军品牌。2011年我国向欧盟出口化妆品共计4.60亿美元，其中肤用化妆
# Translating chunk: 品出口2.12亿美元，占比46%：美容化妆品出口1.69亿美元，占比37%：香水
# Translating chunk: 类化妆品出口0.53亿美元，占比12%：发用化妆品出口0.09亿美元，占比2%；
# Translating chunk: 口腔类化妆品出口0.08亿美元，占比2%：其他化妆品出口0.06亿美元，占比
# Translating chunk: 1%：特殊功能化妆品出口0.01亿美元，占比不足0.3%。
# Translating chunk: 17
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 美容化妆品
# Translating chunk: 香水类化妆品
# Translating chunk: 37%
# Translating chunk: 12%
# Translating chunk: 发用化妆品2%
# Translating chunk: 口腔类化妆品
# Translating chunk: 其他化妆品1%
# Translating chunk: 2%
# Translating chunk: 特殊功能化妆
# Translating chunk: 肤用化妆品
# Translating chunk: 品0%
# Translating chunk: 46%
# Translating chunk: 图2.212011年我国各类化妆品出口至欧盟金额占比分析图
# Translating chunk: 2.4.4.4香港
# Translating chunk: 香港化妆品的本销及转口贸易均相当发达，是我国主要出口地区之一。2011
# Translating chunk: 年，我国对港出口化妆品共计4.12亿美元，其中肤用化妆品出口1.48亿美元，
# Translating chunk: 占比36%：美容化妆品出口0.84亿美元，占比20%：发用化妆品出口0.72亿美
# Translating chunk: 元，占比18%：口腔类化妆品出口0.56亿美元，占比14%：其他化妆品出口0.37
# Translating chunk: 亿美元，占比9%：香水类化妆品出口0.09亿美元，占比2%：特殊功能化妆品
# Translating chunk: 出口0.05亿美元，占比1%。
# Translating chunk: 发用化妆品
# Translating chunk: 口腔类化妆
# Translating chunk: 品14%
# Translating chunk: 其他化妆品9%
# Translating chunk: 18%
# Translating chunk: 香水类化妆品
# Translating chunk: 美容化妆品
# Translating chunk: 2%
# Translating chunk: 20%
# Translating chunk: 特殊功能化妆
# Translating chunk: 品1%
# Translating chunk: 肤用化妆品
# Translating chunk: 36%
# Translating chunk: 图2.222011年我国各类化妆品出口至香港金额占比分析图
# Translating chunk: 18
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 2.4.4.5其他市场
# Translating chunk: 随着中国与东盟的自由贸易区的建立，东盟成为我国化妆品出口的重要市场
# Translating chunk: 之一。2011年对东盟化妆品出口占我国化妆品出口总额的8%，仅次于北美、欧
# Translating chunk: 盟和香港。我国向东盟出口的化妆品涵盖了较大的范围，既有化妆品、护肤品、
# Translating chunk: 须后水等较高级阶段的制成品，也有香精、精油等原料型产品，这在一定程度上
# Translating chunk: 说明我国的化妆品工业的生产技术和经验比东盟更为丰富，处于一定的竞争优势
# Translating chunk: 地位，值得国内企业关注，并积极开拓东南亚化妆品市场。此外，中国和东盟国
# Translating chunk: 家化妆品关税的削减也将在一定程度上推动双方相关产品进出口贸易增长。
# Translating chunk: 2.5我国产品在国际市场的主要优势
# Translating chunk: 2.5.1价格优势
# Translating chunk: 我国化妆品主要集中在中低档产品，品质优良，但包装简易、产品线简单，
# Translating chunk: 因而造就了低成本、低售价。我国有丰富的劳动力资源，劳动力成本较低。我国
# Translating chunk: 具有丰富的自然资源，为化妆品的生产提供了原料保障。我国入世后，化工原料
# Translating chunk: 进口关税下调，降低了产品的成本。
# Translating chunk: 2.5.2技术优势
# Translating chunk: 我国化妆品的生产和使用有着悠久的历史，有着深厚底蕴的文化内涵。我国
# Translating chunk: 上海家化、天津郁美净等化妆品企业有较长的生产历史，拥有先进的工艺设备和
# Translating chunk: 雄厚的技术力量。他们实施规范的生产程序，导入科学管理方法，创建护肤研究
# Translating chunk: 中心，严格监控产品质量，研制出大量优质的护肤产品：注重新产品的开发，应
# Translating chunk: 用现代高科技手段，从根本上改变产品结构，增加产品的附加值和技术含量。
# Translating chunk: 化妆品是多种学科相互交叉的结品，近年来我国与化妆品相关的产业，如机
# Translating chunk: 械工业、包装工业、化学工业、医药工业、中医药工业和微电子工业的快速发展，
# Translating chunk: 为化妆品提供更多的优质原料、包装材料、装备技术和拓展化妆品需用的中医中
# Translating chunk: 药，使化妆品业不断向深度和广度进展，呈现出前所未有的兴旺景象。
# Translating chunk: 我国具有得天独厚的中草药资源条件，中药化妆品历史悠久、品种齐全、剂
# Translating chunk: 19
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 型多样，与中医药融为一体，具有明显的功能性。以化学合成物质为原料的化妆
# Translating chunk: 品易产生毒副作用和皮肤过墩反应，而天然植物为原料的化妆品具有安全可靠、
# Translating chunk: 标本兼治的特点，是生物功能性化妆品的最好原料，我国传统的中草药在几千年
# Translating chunk: 外敷内服的应用实践中已积累了许多药效记录和经验，对它们的用量、安全性和
# Translating chunk: 副作用也有许多验证，这就为化妆品的原料探寻开辟了广阔的资源，并对新型化
# Translating chunk: 妆品的开发提供了有利的条件，因此，我国在开发天然营养型和疗效性化妆品方
# Translating chunk: 面具备了很强的优势。
# Translating chunk: 另外，众多跨国化妆品公司来华投资，他们具备技术优势、产品优势、经营
# Translating chunk: 管理优势、世界性的协作优势和资讯优势，在中国生产国际一流的品牌，促进了
# Translating chunk: 高档次化妆品市场的发展：在中国投资数百万甚至上千万美元建立规模相当大的
# Translating chunk: 研究机构和研究发展中心，促进了我国化妆品业的蓬勃发展。另外，他们还是国
# Translating chunk: 际化妆品行业相关法规、产品标准的研究和制定的参与者，有关政府部门提出有
# Translating chunk: 关化妆品的监督管理的措施和方法，提供相关资讯，更有利于我国化妆品更快的
# Translating chunk: 与国际接轨。
# Translating chunk: 2.5.3规模优势
# Translating chunk: 目前，全国约有化妆品生产企业3300余家，逾2500种产品品种、14个中
# Translating chunk: 国名牌产地、25个中国驰名商标及150多个国家和地区的海外销售地，我国的
# Translating chunk: 化妆品工业已经初步形成了以化妆品产品为核心的庞大的化妆品经济链。2011
# Translating chunk: 年我国化妆品工业制造累计工业（现价）总产值为790.33亿元，同比增长21.6%，
# Translating chunk: 产销率为99%，2010年完成总产值为695.07亿元，同比增长18.7%，产销率为
# Translating chunk: 100.8%,(1)
# Translating chunk: 2.6潜在目标市场
# Translating chunk: 2.6.1东欧
# Translating chunk: 由于上世纪末多国化妆品公司的人驻，东欧地区的化妆品市场现已接近于成
# Translating chunk: 熟的西欧市场。诸多大销量的领先品牌诸如欧瑞莲、多芬和妮维雅等统领着整个
# Translating chunk: 市场，主要以护肤品和护发品为主。但各个地区细分市场却不尽相同。在克罗地
# Translating chunk: 亚，皮肤护理品是最大的市场，2007年的市场价值为5600万欧元，其次是护发
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 用品市场，为3900万欧元：在捷克共和国，护发品的市场价值超过了护肤品1.5
# Translating chunk: 亿欧元，达到1.95亿欧元：而在爱沙尼亚，护肤品市场价值为3000万欧元，护
# Translating chunk: 发品市场价值仅为1900万欧元：在斯洛文尼亚，护肤品市场占最大份额，价值
# Translating chunk: 3900万欧元，护发品次之，价值为3600万欧元，分别占据化妆品市场第一和第
# Translating chunk: 二的位置3。
# Translating chunk: 2.6.2拉美
# Translating chunk: 近年来，随着全球经济的复苏，化妆品产业出现了一些新的动态。2009年，
# Translating chunk: 在全球遭遇金融危机的背景下，拉美地区逆势走高，化妆品销售额增长15%：
# Translating chunk: 2010年，增长20%，BPC规模达6400万美元，几乎和北美市场媲美。业界人
# Translating chunk: 士对未来拉丁美洲的化妆品工业市场持以乐观的态度。2009年拉美排名前十的
# Translating chunk: 化妆品品牌依次为雅芳、娜图、高露洁、吉列、博蒂卡、Sunsilk、欧莱雅、妮维
# Translating chunk: 雅、棕榄和德芙。巴西作为拉美地区美容和个人护理品工业的销售区域中心，
# Translating chunk: 2009年化妆品市场销售额达290亿美元，占巴西GDP的1.3%。欧睿国际分析报
# Translating chunk: 告指出，未来，在更大的消费量的推动下，如购买频率的增加、低收入群体消费
# Translating chunk: 观念的转变，防晒护理品、婴儿护理品、脱毛剂和彩色化妆品都将保持动态增长
# Translating chunk: [5]。与此同时，拉美本土企业，诸如 Natura Cosmestics,Botica Comercial
# Translating chunk: FarmaceuticaLtda,L'Bel和Unique-Yanbal Group的发展也日益壮大起来"。拉丁
# Translating chunk: 美洲地区的化妆品工业正在努力发展和改进自然有机产品、环境主题、社会责任
# Translating chunk: 和所在地区不同国家之间的贸易。
# Translating chunk: 2.6.3中东
# Translating chunk: 近年来，随着人口的增加和当地旅游业的发展，中东地区逐渐成为全球范围
# Translating chunk: 内化妆品和个人护理用品产品发展较快地区之一。产品种类主要以美容类化妆品
# Translating chunk: 和香水为主，销售额年增长率保持在10%~15%。据海湾合作委员会统计显示，
# Translating chunk: 2006年，中东地区奢侈品/高端化妆品市场达8~10亿美元，阿联首占据28%的
# Translating chunk: 市场份额，拥有中东地区化妆品消费者最多的国家之一的沙特阿拉伯则占据了
# Translating chunk: 45%的市场份额。2007年，沙特阿拉伯的化妆品和香水销售额分别为13.2亿美
# Translating chunk: 元和2.38亿美元：2008年，迪拜的化妆品和香水的销售额分别增长了39%和34%。
# Translating chunk: 21
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 阿联酋的化妆品消费群体中，25%~30%为当地阿拉伯女性，25%~30%为外国人，
# Translating chunk: 15%~20%为游客。阿联酋和迪拜相对于沙特阿拉伯，市场管理较为宽松，发展
# Translating chunk: 较快，而消费者也表现得更加成熟和专业。
# Translating chunk: 2.6.4非洲
# Translating chunk: 近年来非洲化妆品市场需求量正在迅速增长，市场潜力巨大。在南非，化妆
# Translating chunk: 品市场每年的需求量就超过11.5亿美元，科特迪瓦在润肤霜和洗发剂类需求量
# Translating chunk: 每年能达到4000万美元。据统计整个非洲化妆品市场需求量年增长率达30%。
# Translating chunk: 来自诸多国家的化妆品企业已经相继进军非洲化妆品市场。任何一个地区的人们
# Translating chunk: 都不愿意亏待自已的皮肤，非洲人也不例外，即使是一些贫困国家大街小巷也不
# Translating chunk: 乏装扮时尚的女郎，化妆品专卖店、超市化妆品专柜和各种美容院也数不胜数。
# Translating chunk: 非洲人最喜欢在他们富有特点的头发上狠下功夫，在非洲化妆品专营店里面，用
# Translating chunk: 于洗发、护发、染发、美发的各种化妆品应有尽有。由于非洲大陆普遍炎热干燥，
# Translating chunk: 皮肤容易丧失水分，保湿霜、润肤油、爽肤水普遍受到消费者青睐。此外，非洲
# Translating chunk: 人还比较喜欢涂口红、擦指甲油、酒香气较浓的香水，而且在这方面，非洲男性
# Translating chunk: 比女性有过之而无不及。
# Translating chunk: 非洲化妆品主要来自进口。由于税收高，利润多，化妆品走私现象比较严重。
# Translating chunk: 法国产品在非洲市场的占有率最高，其次为美国。中国化妆品在非洲市场还比较
# Translating chunk: 少，作为中国化妆品企业可以通过参加非洲商品交易会、网络营销、参加化妆品
# Translating chunk: 展览会，做大做强我们的化妆品品牌，让非洲人了解中国的化妆品，尽早健康地
# Translating chunk: 进入非洲化妆品市场。中国企业生产的化妆品一般都不适合非洲人的皮肤和头发
# Translating chunk: 特征，所以中国化妆品想进入非洲市场的话，应该专门为这个市场开发一些产品，
# Translating chunk: 新产品的研究开发这一步不能省。
# Translating chunk: 22
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 三、主要市场化妆品标签要求及与我国的差异
# Translating chunk: 3.1欧盟
# Translating chunk: 3.1.1法律文件
# Translating chunk: ·Directive76/768/EEC（《指令76/768/EEC》）：《欧盟化妆品指令》（2013
# Translating chunk: 年7月11日废止）
# Translating chunk: ·Directive95/17/EC（《指令95/17/EC》）：有关化妆品一到多种成分在标
# Translating chunk: 签成分表中可不标注的详细规定
# Translating chunk: （EC）1223/2009（《欧洲议会和欧盟理事会化妆品法规》）：2013年7月11
# Translating chunk: 日开始生效，将取代旧的化妆品指令76/768/EEC及其到目前为止的67项修订文件
# Translating chunk: （注：其中部分要求将先于上述日期开始执行）
# Translating chunk: 3.1.2主管机关
# Translating chunk: 化妆品由欧盟委员会企业理事会化妆品和医学部门负责，各成员国有各自的
# Translating chunk: 官方机构负责本国的监督和管理，主要着重于上市后管理。
# Translating chunk: 各国政府主管部门的主要工作有三个方面：在销售、生产和分销地进行稽查：
# Translating chunk: 审查标签：审查所提供的文件。
# Translating chunk: 监督主要有三种方式：
# Translating chunk: ①健康危害或跟踪调查：
# Translating chunk: ②按照产品类别进行专项调查：
# Translating chunk: ③现场检查。
# Translating chunk: 3.1.3化妆品定义
# Translating chunk: 化妆品指用于人体外部任何部位（皮肤、毛发、指甲、口唇和外阴部）或牙
# Translating chunk: 23
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 齿及口腔粘膜的物质或制品，主要起到清洁、香化或保护作用，以达到良好状态、
# Translating chunk: 美容或消除体臭为目的。
# Translating chunk: 3.1.4化妆品分类
# Translating chunk: （1）膏霜、乳液、液、凝胶和油（手、脸、脚等）：
# Translating chunk: （2）面膜（化学性脱皮产品除外）；
# Translating chunk: （3）色彩固定剂：
# Translating chunk: （4）化妆粉、浴后用粉、卫生用粉等：
# Translating chunk: （5）盟洗用皂、除臭皂等：
# Translating chunk: （6）香水、卫生间水、古龙水：
# Translating chunk: （7）沐浴、冲洗用品（浴盐、浴泡、浴油、凝胶等）：
# Translating chunk: （8）脱毛剂：
# Translating chunk: （9）除臭剂和抑汗剂：
# Translating chunk: （10）发用产品（染发剂和漂白剂、卷发、直发和定型剂、定型产品、清洁
# Translating chunk: 产品（液、粉、香波）、护发产品（液、膏霜、油）、美发产品（液、光亮剂、
# Translating chunk: 油）：
# Translating chunk: （11）剃须产品（膏霜、泡沫、液等）：
# Translating chunk: （12）脸和眼部化妆和卸妆产品：
# Translating chunk: （13）唇部用产品：
# Translating chunk: （14）牙齿和口腔保护产品：
# Translating chunk: （15）指甲保护和化妆产品：
# Translating chunk: （16）外用个人卫生用品：
# Translating chunk: （17）日光浴产品：
# Translating chunk: （18）非日光黑肤产品：
# Translating chunk: 24
# Translating chunk: 各国化救品标签管理指南
# Translating chunk: （19）皮肤增白产品：
# Translating chunk: （20）抗皱产品。
# Translating chunk: 3.1.5化妆品标签要求
# Translating chunk: 3.1.5.1化妆品标签一般要求
# Translating chunk: 《欧盟化妆品指令》条款6规定了化妆品标签要求，规定必须注明以下内容：
# Translating chunk: （1）产品名称或类型
# Translating chunk: （2）生产商或欧盟内经销商的地址或注册的办事处
# Translating chunk: 提供多个地址时，必须注明保存产品资料的地址，可以在该地址下划线标明。
# Translating chunk: 欧盟指令不要求注明进口化妆品的原产国，但有的成员国可能要求注明：
# Translating chunk: （3）净含量
# Translating chunk: 以重量或体积标明。强制以SI公制单位标注，同时可以标注美国惯例单位。
# Translating chunk: 当两种单位都使用时，SI公制单位必须占支配地位。双标签只能使用到2009年。
# Translating chunk: 《指令76/211/EC》对净含量的标注要求做了规定，其修补法介绍了一系列
# Translating chunk: 平均体积或重量的管理。标签上净含量旁边的标志“e”表示净含量的标注符合
# Translating chunk: 该指令。《喷雾剂指令75/324/EEC》要求喷雾剂产品同时标注重量及体积。
# Translating chunk: （4）化妆品成分表
# Translating chunk: 要求在外包装上标注化妆品全部成分的名称。如果实际原因无法做到时，可
# Translating chunk: 印在附带的小册子、标签、带子或卡片上，但同时应该在外包装上印制简语或附
# Translating chunk: 录I中的符号指示消费者参看。应在句头以“成分（INGERDIENTS）”作为引
# Translating chunk: 导语引出成分表。
# Translating chunk: 标注顺序为：
# Translating chunk: ①含量高于1%的各成分名称按加入量的降序列出，含量低于1%的成分可
# Translating chunk: 按任意顺序列于其后。
# Translating chunk: ②着色剂可以以任意顺序标注在其他成分之后。对于有多种色号的美容化
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 妆品，使用范围内所有的着色剂都应列出，并标注字样“可能含有（maycontain）”
# Translating chunk: 或符号“+/-”。
# Translating chunk: 标注的成分名称：
# Translating chunk: ①成份必须使用下列法规规定或采用的名称：INCI名称（International
# Translating chunk: NomencaltureCosmeticIngredienr，化妆品成分国际名称）、欧洲药典名称、世界
# Translating chunk: 卫生组织推荐的非专利名称、欧洲现有流通商业化学物品目录（EINECS)索引号、
# Translating chunk: 国际纯化学与应用化学联盟（IUPAC）索引号、美国化学文摘（CAS）索引号、色
# Translating chunk: 素索引号以及条款7（2）中推荐的普通名称。
# Translating chunk: 下列情况不属于成分物质：
# Translating chunk: 一原料中的杂质；
# Translating chunk: 一生产中用到但成品中不含有的辅料：
# Translating chunk: 一作为香料或芳香物质的溶剂或载体且使用量受到严格控制的物质。
# Translating chunk: ②香料和芳香成分及其原料应以单词“香味”或“香型”（“perfume”或
# Translating chunk: “aroma”）给予提示：
# Translating chunk: ③着色剂必须采用染料颜色索引号（CI号），没有相应的CI号时，使用INCI
# Translating chunk: 名称：
# Translating chunk: 当含有附录Ⅲ中“其他限制和要求”表列出的要求提到的物质时，无论其功
# Translating chunk: 能如何，都应标注在成分表中。
# Translating chunk: 有时生产商出于商业秘密的原因，会提出不在成分表中公布一种或几种成分
# Translating chunk: 的申请，必须符合《指令95/17/EC》的规定。
# Translating chunk: （5）保质期
# Translating chunk: 保质期应标注为：“最好在·…（日期）前使用（bestused before the endof...）”，
# Translating chunk: 日期按下列标注方式之一进行标注：
# Translating chunk: 一日期（按“月，年”或是“日，月，年”顺序）
# Translating chunk: 一指示标注日期的地方
# Translating chunk: 26
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 对于保质期超过30个月的化妆品，不强制要求标注保质期，但需要标明开
# Translating chunk: 启后产品可以安全使用的时间。按附录Ⅲ（a）中给出的符号“开启后期限（Period
# Translating chunk: AfterOpening，PAO)”标注，在符号后注明使用期限：“数字十M”表示可使用
# Translating chunk: 多少个月，不需要翻译成各成员国的母语：也可用“数字十years”表示可使用
# Translating chunk: 多少年，但“years”必须翻译成销售国的母语。
# Translating chunk: （6）生产批号或产品识别号
# Translating chunk: 如果因产品本身体积太小无法做到时，允许只标注在外包装上（其次也可以
# Translating chunk: 标注在外容器上）。
# Translating chunk: （7）必要的警告声明（注意事项）
# Translating chunk: 包含特定组分的产品必须依照《欧盟化妆品指令》附录标注警告声明。所有
# Translating chunk: 成员国要求用自己各自国家的语言标注警示用语，在内外包装上都必须标注。如
# Translating chunk: 果因实际原因无法做到，可以标注在说明书、标签或卡片上，但同时必须在包装
# Translating chunk: 容器或外包装上印制简语或附录Ⅲ中的符号指示给消费者看。
# Translating chunk: 对喷雾剂产品和易燃产品有特殊警告规定，见《喷雾剂指令75/324/EEC》
# Translating chunk: 和修订版94/1/EC。此外，欧洲化妆品盟洗用品及香水协会（TheEuropean
# Translating chunk: Cosmetic，Tioletry，and PerfumeryAssociation，Colipa）联络委员会发布了关于易
# Translating chunk: 燃性产品标签政策，界定了某些化妆品在哪种情况下要求或者不要求标注此警告
# Translating chunk: 声明。
# Translating chunk: （8）必要的使用说明
# Translating chunk: 必须以官方语言或销售国的母语注明。该信息可以标注在附带的小册子、带
# Translating chunk: 子或标签条上，并印制简语或附录Ⅲ中的符号指示消费者参看。
# Translating chunk: （9）必要的储存条件
# Translating chunk: （10）产品功效
# Translating chunk: 如果产品的外观可以清楚的显示其功效，则可以不标注。
# Translating chunk: 功效宣称用语不得具有误导性。当主管机关认为一个产品的描述、标签、生
# Translating chunk: 产商或负责机构提供的其他信息可能使得该产品对人体健康有危害时，将禁止其
# Translating chunk: 27
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 投放市场。另外，有的成员国有本国的详细规定。
# Translating chunk: 《误导性广告84/450/EEC》及修订版97/55/EEC是专门关于对比性广告的指
# Translating chunk: 令。其中规定允许在指令指定条件下使用对比性广告。
# Translating chunk: 其中产品名称或类型、生产商或欧盟内经销商的地址或注册的办事处、净含
# Translating chunk: 量、保质期、使用说明、生产批号、必要的警告声明、产品功效和保存条件必须
# Translating chunk: 在内外包装上同时标注。
# Translating chunk: 所有标签内容至少应以各国母语或欧盟官方语言或上述两种语言进行标注。
# Translating chunk: 对字体大小没有要求（除了《指令76/211/EC》中对净含量有要求）。但建
# Translating chunk: 议使用可以确保视力正常的人在距离约30厘米处能轻松识读的字号。
# Translating chunk: （EC)1223/2009（《欧洲议会和欧盟理事会化妆品法规》）将从2013年7
# Translating chunk: 月11日起，取代旧的化妆品指令76/768/EEC及其到目前为止的67项修订文件，
# Translating chunk: 以欧盟法规的形式发布，在27个欧盟成员国（以及挪威、冰岛和列支敦士登）中
# Translating chunk: 作为国家法律实施。届时，欧洲经济区1（EEA)市场中销售的化妆品必须符合新
# Translating chunk: 颁布的欧盟化妆品法规（EC)No1223/20092的要求，其中部分要求将先于上述日
# Translating chunk: 期开始执行，如对于CMR（致癌、诱导有机体突变或对生殖有毒害的物质）和
# Translating chunk: 纳米材料的规定将分别于2010年12月1日和2013年1月11日开始执行。
# Translating chunk: 新法规简化了欧洲经济区对化妆品的要求，使其成为单一法律，消除了可能
# Translating chunk: 在成员国执法过程中产生分歧的内容。化妆品通报只需递交给由中央委员会和
# Translating chunk: COLIPA（欧洲化妆品协会）联合开发的数据库，而不是现在的各个成员国。不过，
# Translating chunk: 企业需要自行通报并保存相关文件，而不是由行业协会代管。
# Translating chunk: 《欧洲议会和欧盟理事会化妆品法规》对责任人的定义变得更加明确，规定
# Translating chunk: 责任人具体包括：①EEA内的生产商、②将产品输入EEA的进口商及③使用其
# Translating chunk: 自己的名称或商标将化妆品投放市场或者对化妆品的更改可能影响其法规符合
# Translating chunk: 性（不包括仅文字翻译）的分销商。根据新要求，责任人将承担更多的法律责任，
# Translating chunk: 涉及化妆品生产规范（GMP)、产品安全报告、产品资料档案（PIF)、产品通报、产
# Translating chunk: 品声明等。其中有关标签的规定有：
# Translating chunk: 28
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: （1）原产国：
# Translating chunk: 进口至EEA的化妆品必须标明原产国：
# Translating chunk: （2）最短有效期
# Translating chunk: 日期前的文字"有效期至"(best used before theendof")可由新的煮蛋计时
# Translating chunk: 器标志取代：如果开启后有效期无关紧要（现实实践确认）则无需注明开启后有效
# Translating chunk: 期。
# Translating chunk: 最短有效期煮蛋计时器标志
# Translating chunk: （3）在将产品投放市场前，分销商应确保符合以下标签要求：
# Translating chunk: 责任人的姓名或注册名称和地址：
# Translating chunk: 化妆品的批号或识别信息：
# Translating chunk: -成份表：（成份表中纳米材料的名称后应带有"（nano)字样）
# Translating chunk: -肥皂、沐浴球和其它小产品的减损：
# Translating chunk: 有关非预包装的、按买方要求在销售时进行包装的，或为立即销售进行预
# Translating chunk: 包装的化妆品的国家法规。
# Translating chunk: 3.1.5.2环境标签
# Translating chunk: 欧盟于1992年通过第EEC880/92号条例出台了生态标签体系，提出对声称
# Translating chunk: “环境友好（environmentalfriendly）”产品的最低要求，并于2000年通过欧盟
# Translating chunk: 1980/2000号条例进一步修改补充。该条例适用于全体成员国，提供了一个关于
# Translating chunk: 如何授予达到了各自行业既定的标准的产品生态标签的机制。它评价的是一种产
# Translating chunk: 品从生产到处理掉的整个过程产生的影响。该标签是自愿的，而且需要交纳使用
# Translating chunk: 费。每个成员国都有指定的本国范围内管理此项事务的实体。到目前为止，还没
# Translating chunk: 有一类化妆品制定完成此生态标签的授予标准。部分成员国有本国强制性的环境
# Translating chunk: 标签法。
# Translating chunk: 29
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 3.1.5.3小包装产品标签和其他豁免
# Translating chunk: 以下情况无需标注净含量：①包装容量小于5g或5ml的样品：②免费样品：
# Translating chunk: ③独立包装的样品：④通常按数量销售的样品。但仍需标注其他标签强制要求的
# Translating chunk: 内容。警告（预防措施）、使用说明、成份表可以标注在附带的说明书、标签、
# Translating chunk: 带子或卡片上，此时必须在外包装上印制符号指示消费者参看这些附带信息。
# Translating chunk: 《危险品制备指令1999/45/EC》提到了使用有害原材料和特定的免除标签化
# Translating chunk: 妆品的标签要求，指令的第10条要求在使用此危险品的场所建立安全数据表
# Translating chunk: （SDSs），这些准则在《指令91/155/EEC》上有规定，此契约也免除化妆品，但
# Translating chunk: 是使用者可以要求以其他方式给出同等的产品信息。
# Translating chunk: 3.2美国
# Translating chunk: 3.2.1法律文件
# Translating chunk: ·The Food,Drugs and Cosmetics Act（FD&CAct）（《食品、药品和化妆品
# Translating chunk: 法案》）：化妆品主要法规
# Translating chunk: ·The FairPackaging and Labelling Act（FPLA）（《合理包装及标签法》）：规
# Translating chunk: 定了化妆品的标签、包装和广告
# Translating chunk: ·CosmeticLabelling（《化妆品标签》）：21 CFR701
# Translating chunk: ·CosmeticLabellingManual（《化妆品标签指南》）
# Translating chunk: ·LabelingRequirementsforOver-the-CounterDrugs（《非处方药品（OTC）标签
# Translating chunk: 要求》）：21CFR201.66
# Translating chunk: 3.2.2主管机关
# Translating chunk: 美国食品药品管理局（The Food and DrugAdministration，FDA）主管化妆
# Translating chunk: 品和药品。化妆品由食品安全和营养学中心（TheCenterforFood Safety and
# Translating chunk: Applied Nutrition，CFSAN）下属色素和化妆品办公室负责，负责从生产到上市
# Translating chunk: 后的监督管理工作，可以不经通知进入到生产厂地进行检查，从上市产品中抽查
# Translating chunk: 30
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 产品。进口产品要遵循《进口化妆品规程》。OTC药品由药品评估和研究中心（The
# Translating chunk: Center forDrugEvaluation and Research，CDER）负责管理。既是化妆品又是OTC
# Translating chunk: 药品的产品由CFSAN和CDER共同管理。对于进口美国的海外产品，FDA可以到
# Translating chunk: 海外施行检查。
# Translating chunk: 3.2.3化妆品定义
# Translating chunk: 《FD&C法案》将化妆品定义为两类：
# Translating chunk: ·化妆品
# Translating chunk: ·非处方药品
# Translating chunk: 产品属于化妆品或药品取决于它们的用途，而用途则根据产品功效声明和消
# Translating chunk: 费者的认知（通过产品的口碑或成分的治疗功能）来确定。根据《FD&C法案》，
# Translating chunk: 产品可以是药品，也可以是化妆品，或既是药品也是化妆品（与欧盟刚好相反）。
# Translating chunk: 第三种情况只有在产品有两种用途，符合两种定义的时候才会发生，例如：防头
# Translating chunk: 皮屑香波是化妆品，因为它的声明表明产品的用途是用来清洁头发：但是它同样
# Translating chunk: 也可视作药品，因为它含有公认的防头皮屑成分且它的声明表明它是用来治疗头
# Translating chunk: 皮屑的。确定为既是化妆品又是药品的产品必须符合两种类别产品的法规要求。
# Translating chunk: 化妆品的定义：指除了脂肪酸碱性盐肥皂之外的施用于人体（擦、注、撒或
# Translating chunk: 喷）或其任何部位用于清洁、美化、增强吸引力或改善外貌而对人体结构或功能
# Translating chunk: 没有影响的产品。
# Translating chunk: 药品的定义：用于治疗、缓解、医治或预防人类和其他动物疾病的物品以及
# Translating chunk: 食品之外的用于影响人体或其他动物体结构和功能的物品。
# Translating chunk: 非处方药品是指可以无需医生处方即可买到的药品。
# Translating chunk: 某些在欧盟被分为化妆品的产品在美国被分为新药品而非OTC药品。新药
# Translating chunk: 品是指尚未被专家们广泛认可在预期使用目的下安全有效的药品，或是尚未在确
# Translating chunk: 切的范围或时间内使用的药品。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 3.2.4化妆品分类
# Translating chunk: （1）化妆品分类：
# Translating chunk: ·皮肤护理
# Translating chunk: ·香水
# Translating chunk: ·眼部化妆品
# Translating chunk: ·眼部外的化妆品
# Translating chunk: ·指甲产品
# Translating chunk: ·沐浴油和泡沫浴液
# Translating chunk: ·漱口水
# Translating chunk: ·染发预处理
# Translating chunk: ·洗发水、烫发剂或其他护发产品
# Translating chunk: ·除臭剂
# Translating chunk: ·剃须产品
# Translating chunk: ·儿童产品
# Translating chunk: ·晒黑产品
# Translating chunk: （2）OTC药品（化妆品）分类：
# Translating chunk: ·防齿（含氟化物）的牙膏
# Translating chunk: ·保湿产品
# Translating chunk: ·防晒化妆品
# Translating chunk: ·抑汗剂
# Translating chunk: ·防头屑洗发水
# Translating chunk: 32
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 3.2.5化妆品标签要求
# Translating chunk: 3.2.5.1化妆品标签一般要求
# Translating chunk: 规定化妆品标签必须标注的内容：
# Translating chunk: （1）产品名称和呈述：必须标注在外包装主展示面上。
# Translating chunk: 使用化妆品的常用名或者恰当的描述性名称。如果该化妆品的性质是显而易
# Translating chunk: 见的，则在不会造成公众对该化妆品误解和无法辨别的前提下，可以使用更为奇
# Translating chunk: 特有趣的名称。
# Translating chunk: （2）生产商、包装商或发行商的名称和地址：在内、外包装上标注。
# Translating chunk: 具体规定见《美国联邦法规》（CodeofFederalRegulations，CFR）第21卷
# Translating chunk: 第701.12部分。进口化妆品必须在容器外面用英语标明原产国及制造商或代理
# Translating chunk: 商（包括进口商）。原产国由以下语句标注：“由…（英文标写国家名）国制造”；
# Translating chunk: 或“…（英文标写的国家名）国产品”：或其他能清楚表明原产国意思的语句。
# Translating chunk: 如果原产国是北美自由贸易区（NAFTA）国家，可以用英语、法语或西班牙语。
# Translating chunk: （3）净含量：标注在内、外包装的主展示面上。
# Translating chunk: 强制以传统的美国惯例单位标注，另外，还可以用公制单位同时标注。如果
# Translating chunk: 化妆品为液体，声明必须用体积单位：如果化妆品为固体、半固体、粘性物或固
# Translating chunk: 体混合物，声明必须用重量单位。重量用磅和盘司表示。液体体积用美制加仑、
# Translating chunk: 夸脱、品脱和液量益司表示。美国的体积计算和英国以及其他国家的体积有微小
# Translating chunk: 的差别。净含量标签的具体规定见21CFR701.13。
# Translating chunk: （4）化妆品成分表：在外包装上标注。
# Translating chunk: 具体规定见21CFR701.3。供个人使用的零售产品在化妆品标签上必须列出
# Translating chunk: 化妆品的全部成分。一般情况下不零售的化妆品，例如，专业人士在专业机构中
# Translating chunk: 为顾客使用的发用品或彩妆品，以及在工作场所供人们使用的洁肤霜和润肤霜，
# Translating chunk: 而且这些产品也不会销售给消费者供他们在家使用，可以不注明成分。香水和香
# Translating chunk: 料例外，可以只列出非商标性名称。此外，出于商业保密的需要，经FDA批准
# Translating chunk: 33
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 豁免公之于众的成分可以不列于标签上，但必须于标签组分的最后部分声明：“以
# Translating chunk: 及其他成分”。如果包装上没有足够的标签空间或者是装饰性的容器，可使用附
# Translating chunk: 页标签（附带的标签、带子或卡片）（具体细节见CTFA标签手册（TheCosmetic，
# Translating chunk: Toiletry andFragranceAssociation，美国化妆品、盟洗用品和香料协会，现已更名
# Translating chunk: 为PersonCareProductsCouncil，美国个人用品护理用品协会））。
# Translating chunk: 标注顺序为：
# Translating chunk: 含量高于1%的成分以降序排列：含量小于1%的成分，其顺序可以是任意
# Translating chunk: 排列的：色素添加剂按任意顺序排列，以“含有…”语句引出，不能使用“+/-”
# Translating chunk: 符号：“以及其他成分”。
# Translating chunk: 标注的成份名称必须依次使用下列名称：21CFR701.30中列出的指定名称、
# Translating chunk: CTFA《化妆品成分词典》（此规定名称见INCI名称）、《美国药典》的名称、《国
# Translating chunk: 家处方集》的名称、《食品化学法典》的名称、《美国药品正名和药典药名词典》
# Translating chunk: 的名称、消费者公认的名称、化学或其他技术专用名称或描述。
# Translating chunk: （5）保质期
# Translating chunk: 要说明在什么时间内使用是安全的。
# Translating chunk: （6）生产批号
# Translating chunk: 化妆品不要求批量鉴定，但是应当建立在健康的商业活动基础上。
# Translating chunk: （7）警告声明：在内、外包装上标注。
# Translating chunk: 《化妆品类产品警告声明》（21CFR740）对警告声明作了详细规定。某些产
# Translating chunk: 品标签必须带有警示用语。例如以自加压容器包装的化妆品（如喷雾剂产品）
# Translating chunk: 女用除臭喷雾和儿童泡沫浴液等。当一个具体的警示用语得到法律认可后，就不
# Translating chunk: 能改变语句，并且在使用时必须按照相关法规确切使用。如果化妆品的安全性未
# Translating chunk: 能得到充分的证实，且没有在标签的主展示面上出现以下明确的声明：“警告一一
# Translating chunk: 该产品的安全性未经测定”，则该化妆品将会被视为错误标签产品。另外，还需
# Translating chunk: 要注意某些州制定的对警告有特殊要求的法令。
# Translating chunk: （8）必要时，标注储存条件。
# Translating chunk: 34

# %%
# Step 4: Combine and execute the modules
def translate_pdf(input_pdf, output_pdf):
    # Extract the PDF contents (text, images, tables)
    extracted_data = extract_text_from_pdf(input_pdf)

    # Create a translated PDF with the extracted data
    create_translated_pdf(extracted_data, output_pdf)

# %%
# Example usage:
input_pdf_path = "data/pdf2.pdf"  # Replace with your Chinese PDF path
output_pdf_path = "translated_english_document.pdf"  # Output path for the translated PDF
translate_pdf(input_pdf_path, output_pdf_path)
# Out:
# [2024/10/03 17:23:26] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/user/.paddleocr/whl/det/ch/ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/user/.paddleocr/whl/rec/ch/ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/user/Meet_Patel/AllChatbot-Project/chatenv/lib/python3.12/site-packages/paddleocr/ppocr/utils/ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir='/home/user/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/10/03 17:23:27] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:27] ppocr DEBUG: dt_boxes num : 6, elapsed : 0.19280266761779785
# [2024/10/03 17:23:28] ppocr DEBUG: rec_res num  : 6, elapsed : 0.6555283069610596
# [2024/10/03 17:23:28] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:28] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.1595447063446045
# [2024/10/03 17:23:30] ppocr DEBUG: rec_res num  : 25, elapsed : 1.7077569961547852
# [2024/10/03 17:23:30] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:30] ppocr DEBUG: dt_boxes num : 57, elapsed : 0.10202431678771973
# [2024/10/03 17:23:31] ppocr DEBUG: rec_res num  : 57, elapsed : 1.1862502098083496
# [2024/10/03 17:23:31] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:31] ppocr DEBUG: dt_boxes num : 46, elapsed : 0.1340029239654541
# [2024/10/03 17:23:33] ppocr DEBUG: rec_res num  : 46, elapsed : 1.4760105609893799
# [2024/10/03 17:23:33] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:33] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.15062236785888672
# [2024/10/03 17:23:36] ppocr DEBUG: rec_res num  : 113, elapsed : 3.1919374465942383
# [2024/10/03 17:23:36] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:36] ppocr DEBUG: dt_boxes num : 34, elapsed : 0.09730172157287598
# [2024/10/03 17:23:37] ppocr DEBUG: rec_res num  : 34, elapsed : 0.9455666542053223
# [2024/10/03 17:23:37] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:37] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.1203162670135498
# [2024/10/03 17:23:39] ppocr DEBUG: rec_res num  : 113, elapsed : 2.0287024974823
# [2024/10/03 17:23:40] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:40] ppocr DEBUG: dt_boxes num : 40, elapsed : 0.10101604461669922
# [2024/10/03 17:23:41] ppocr DEBUG: rec_res num  : 40, elapsed : 1.2858028411865234
# [2024/10/03 17:23:41] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:41] ppocr DEBUG: dt_boxes num : 99, elapsed : 0.10394096374511719
# [2024/10/03 17:23:43] ppocr DEBUG: rec_res num  : 99, elapsed : 1.5777544975280762
# [2024/10/03 17:23:43] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:43] ppocr DEBUG: dt_boxes num : 31, elapsed : 0.0964515209197998
# [2024/10/03 17:23:44] ppocr DEBUG: rec_res num  : 31, elapsed : 1.1473565101623535
# [2024/10/03 17:23:44] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:44] ppocr DEBUG: dt_boxes num : 155, elapsed : 0.11186361312866211
# [2024/10/03 17:23:47] ppocr DEBUG: rec_res num  : 155, elapsed : 2.803572416305542
# [2024/10/03 17:23:47] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:47] ppocr DEBUG: dt_boxes num : 45, elapsed : 0.09890913963317871
# [2024/10/03 17:23:48] ppocr DEBUG: rec_res num  : 45, elapsed : 0.8312435150146484
# [2024/10/03 17:23:48] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:48] ppocr DEBUG: dt_boxes num : 119, elapsed : 0.10666513442993164
# [2024/10/03 17:23:51] ppocr DEBUG: rec_res num  : 119, elapsed : 2.3951194286346436
# [2024/10/03 17:23:51] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:51] ppocr DEBUG: dt_boxes num : 79, elapsed : 0.13721013069152832
# [2024/10/03 17:23:52] ppocr DEBUG: rec_res num  : 79, elapsed : 1.5262012481689453
# [2024/10/03 17:23:52] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:52] ppocr DEBUG: dt_boxes num : 41, elapsed : 0.10036158561706543
# [2024/10/03 17:23:53] ppocr DEBUG: rec_res num  : 41, elapsed : 0.9257693290710449
# [2024/10/03 17:23:53] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:54] ppocr DEBUG: dt_boxes num : 30, elapsed : 0.0997922420501709
# [2024/10/03 17:23:55] ppocr DEBUG: rec_res num  : 30, elapsed : 1.0820283889770508
# [2024/10/03 17:23:55] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:55] ppocr DEBUG: dt_boxes num : 32, elapsed : 0.10282468795776367
# [2024/10/03 17:23:56] ppocr DEBUG: rec_res num  : 32, elapsed : 1.6220529079437256
# [2024/10/03 17:23:57] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:57] ppocr DEBUG: dt_boxes num : 36, elapsed : 0.09988880157470703
# [2024/10/03 17:23:58] ppocr DEBUG: rec_res num  : 36, elapsed : 1.1381630897521973
# [2024/10/03 17:23:58] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:23:58] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.09700584411621094
# [2024/10/03 17:24:00] ppocr DEBUG: rec_res num  : 27, elapsed : 1.8866171836853027
# [2024/10/03 17:24:00] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:00] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.09698343276977539
# [2024/10/03 17:24:02] ppocr DEBUG: rec_res num  : 29, elapsed : 2.062140464782715
# [2024/10/03 17:24:02] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:02] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.09657001495361328
# [2024/10/03 17:24:04] ppocr DEBUG: rec_res num  : 29, elapsed : 2.120182991027832
# [2024/10/03 17:24:04] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:04] ppocr DEBUG: dt_boxes num : 24, elapsed : 0.0951390266418457
# [2024/10/03 17:24:06] ppocr DEBUG: rec_res num  : 24, elapsed : 1.7189700603485107
# [2024/10/03 17:24:06] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:06] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.0968329906463623
# [2024/10/03 17:24:08] ppocr DEBUG: rec_res num  : 23, elapsed : 1.1647224426269531
# [2024/10/03 17:24:08] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:08] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.1293478012084961
# [2024/10/03 17:24:09] ppocr DEBUG: rec_res num  : 25, elapsed : 1.31565260887146
# [2024/10/03 17:24:09] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:09] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.16072440147399902
# [2024/10/03 17:24:11] ppocr DEBUG: rec_res num  : 26, elapsed : 2.003528594970703
# [2024/10/03 17:24:11] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:11] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.0985410213470459
# [2024/10/03 17:24:13] ppocr DEBUG: rec_res num  : 27, elapsed : 1.6864006519317627
# [2024/10/03 17:24:13] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:13] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.09682703018188477
# [2024/10/03 17:24:15] ppocr DEBUG: rec_res num  : 28, elapsed : 1.8496251106262207
# [2024/10/03 17:24:15] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:15] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.10185480117797852
# [2024/10/03 17:24:18] ppocr DEBUG: rec_res num  : 28, elapsed : 2.166071891784668
# [2024/10/03 17:24:18] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:18] ppocr DEBUG: dt_boxes num : 25, elapsed : 0.09971165657043457
# [2024/10/03 17:24:19] ppocr DEBUG: rec_res num  : 25, elapsed : 1.4832720756530762
# [2024/10/03 17:24:19] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:19] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.09938788414001465
# [2024/10/03 17:24:21] ppocr DEBUG: rec_res num  : 26, elapsed : 1.6795744895935059
# [2024/10/03 17:24:21] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:21] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.1321728229522705
# [2024/10/03 17:24:24] ppocr DEBUG: rec_res num  : 26, elapsed : 2.3100666999816895
# [2024/10/03 17:24:24] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:24] ppocr DEBUG: dt_boxes num : 23, elapsed : 0.14182114601135254
# [2024/10/03 17:24:24] ppocr DEBUG: rec_res num  : 23, elapsed : 0.6062026023864746
# [2024/10/03 17:24:24] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:25] ppocr DEBUG: dt_boxes num : 27, elapsed : 0.13050222396850586
# [2024/10/03 17:24:27] ppocr DEBUG: rec_res num  : 27, elapsed : 2.0489351749420166
# [2024/10/03 17:24:27] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/10/03 17:24:27] ppocr DEBUG: dt_boxes num : 28, elapsed : 0.10383892059326172
# [2024/10/03 17:24:29] ppocr DEBUG: rec_res num  : 28, elapsed : 2.05887770652771
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 一、适用范围
# Translating chunk: 本指南旨在提供我国的化妆品主要出口目标国家（地区）在化妆品标签方面
# Translating chunk: 的法规、标准、要求以及与我国的差异，提出达到目标市场要求的建议和指南。
# Translating chunk: 适用于所有出口或准备出口的化妆品企业。
# Translating chunk: MOFCOM
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 二、进出口化妆品基本情况概述
# Translating chunk: 2.1术语和定义
# Translating chunk: 化妆品cosmetios：指以涂抹、洒、喷或其它类似方式，施于人体表面任何部位
# Translating chunk: （皮肤、毛发、指甲、口唇）、牙齿和口腔粘膜，以达到清洁、芳香、改变外观、
# Translating chunk: 修正人体气味、保养、保持良好状态目的的产品。
# Translating chunk: 标签labelling：指粘贴或连接或印在化妆品销售包装上的文字、数字、符号、
# Translating chunk: 图案和置于销售包装内的说明性材料。
# Translating chunk: 销售包装salespaokaging：指以销售为目的，与内装物一起交付给消费者的包
# Translating chunk: 装。
# Translating chunk: 内装物contents：指包装容器内所装的产品。
# Translating chunk: 展示面displaypanels：指化妆品在陈列时，在自然状态下被消费者能看见的
# Translating chunk: 面。
# Translating chunk: 可视面visiblepanels：指化妆品在不破坏销售包装的情况下，消费者能够看
# Translating chunk: 到的任何面。
# Translating chunk: 净含量netcontent：指去除包装容器和其它包装材料后，内装物的实际质量或
# Translating chunk: 体积或长度。
# Translating chunk: 保质期sheIflife：指在化妆品产品标准和标签规定的条件下，保持化妆品品
# Translating chunk: 质的期限。在此期限内，化妆品完全适于销售，并符合产品标准和标签中所规定
# Translating chunk: 的品质。
# Translating chunk: 限期使用日期expirationdate：指在化妆品产品标准和标签规定的条件下，化
# Translating chunk: 妆品最佳的使用日期。在此期限内，化妆品完全适于销售，并符合产品标准和标
# Translating chunk: 签上所规定的品质。超过此期限，化妆品的品质可能会发生变化，此化妆品不再
# Translating chunk: 适于销售。
# Translating chunk: 裸装产品primarypaokagingproduct：指一次包装的化妆品。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 本指南中涉及的商品为化妆品产品，该类产品对应的海关出口目录商品编码
# Translating chunk: 如表2.1所示（数据来自中华人民共和国海关总署编《中国海关统计年鉴》）。
# Translating chunk: 表2.1化妆品类产品对应海关编码列表
# Translating chunk: 产品名称
# Translating chunk: 商品编号（海关编）
# Translating chunk: 精油包括浸膏及净油：香膏：提取的油树脂
# Translating chunk: 3301
# Translating chunk: 橙油
# Translating chunk: 33011200
# Translating chunk: 柠檬油
# Translating chunk: 33011300
# Translating chunk: 白柠檬油（酸橙油）
# Translating chunk: 33011910
# Translating chunk: 其他柑橘属果实精油
# Translating chunk: 33011990
# Translating chunk: 胡椒薄荷油
# Translating chunk: 33012400
# Translating chunk: 其他薄荷油
# Translating chunk: 33012500
# Translating chunk: 樟脑油
# Translating chunk: 33012910
# Translating chunk: 香茅油
# Translating chunk: 33012920
# Translating chunk: 茴香油
# Translating chunk: 33012930
# Translating chunk: 桂油
# Translating chunk: 33012940
# Translating chunk: 山苍子油
# Translating chunk: 33012950
# Translating chunk: 桉叶油
# Translating chunk: 33012960
# Translating chunk: 老鹤草油（香叶油）
# Translating chunk: 33012991
# Translating chunk: 未列名非柑橘属果实精油
# Translating chunk: 33012999
# Translating chunk: 鸢尾凝脂
# Translating chunk: 33013010
# Translating chunk: 其他香膏
# Translating chunk: 33013090
# Translating chunk: 提取的油树脂
# Translating chunk: 33019010
# Translating chunk: 柑桔属果实的精油脱的烯副产品
# Translating chunk: 33019020
# Translating chunk: 含浓缩精油的制品：其他烯副产品及精油液
# Translating chunk: 33019090
# Translating chunk: 香水及花露水
# Translating chunk: 3303
# Translating chunk: 香水及花露水
# Translating chunk: 33030000
# Translating chunk: 美容品或化妆品及护肤品：指（趾）甲化妆品
# Translating chunk: 3304
# Translating chunk: 唇用化妆品
# Translating chunk: 33041000
# Translating chunk: 眼用化妆品
# Translating chunk: 33042000
# Translating chunk: 3
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: （续表）
# Translating chunk: 产品名称
# Translating chunk: 商品编号（海关编）
# Translating chunk: 指（趾）甲化妆品
# Translating chunk: 33043000
# Translating chunk: 香粉，不论是否压紧
# Translating chunk: 33049100
# Translating chunk: 其他美容品或化妆品及护肤品
# Translating chunk: 33049900
# Translating chunk: 护发品
# Translating chunk: 3305
# Translating chunk: 洗发剂（香波）
# Translating chunk: 33051000
# Translating chunk: 烫发剂
# Translating chunk: 33052000
# Translating chunk: 定型剂
# Translating chunk: 33053000
# Translating chunk: 其他护发品
# Translating chunk: 33059000
# Translating chunk: 口腔及牙齿清洁剂：清洁牙缝用的纱线（牙线）
# Translating chunk: 3306
# Translating chunk: 牙膏
# Translating chunk: 33061010
# Translating chunk: 其他洁齿品
# Translating chunk: 33061090
# Translating chunk: 清洁牙缝用纱线（牙线）
# Translating chunk: 33062000
# Translating chunk: 口腔清洁剂
# Translating chunk: 33069000
# Translating chunk: 芳香料制品及化妆盟洗品：
# Translating chunk: 3307
# Translating chunk: 剃须用制剂
# Translating chunk: 33071000
# Translating chunk: 人体除臭剂及止汗剂
# Translating chunk: 33072000
# Translating chunk: 香浴盐及其他沐浴用制剂
# Translating chunk: 33073000
# Translating chunk: 脱毛剂和未列名的芳香料制品及化妆盟洗品
# Translating chunk: 33079000
# Translating chunk: 2.2最新海关统计口径
# Translating chunk: 统计口径为：该类产品的年度进出口总金额及数量。
# Translating chunk: 2.3近5年来的进出口额统计
# Translating chunk: 2.3.12007~2011年中国化妆品进出口额统计
# Translating chunk: 近5年来，我国化妆品进出口总体呈现增长趋势，且近两年增长迅速。据统
# Translating chunk: 计数据显示，2011年较2007年，我国化妆品出口数量增长42.77万吨，增幅达
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 175.51%，出口金额增长14.93亿美元，增幅达145.17%：化妆品进口数量上增
# Translating chunk: 长5.51万吨，增幅达103.50%，进口金额增长14.74亿美元，增幅达214.34%，
# Translating chunk: 我国化妆品贸易主要以出口为主。随着结构的调整，近年逐步趋向进出口贸
# Translating chunk: 易平衡。据统计数据显示，2007年到2011年，我国化妆品贸易顺差由3.41亿美
# Translating chunk: 元下滑至0.00亿美元，继而小幅增长至3.60亿美元，走势渐趋平稳。这一期间，
# Translating chunk: 我国化妆品进出口贸易总额由17.16亿美元增至46.84亿美元，增幅达172.88%。
# Translating chunk: 相比贸易值的快速增长，我国化妆品在质的方面还存在较大劣势。2007年，
# Translating chunk: 化妆品进口平均单价为12.92美元/千克，出口平均单价为4.22美元/千克，为进
# Translating chunk: 口单价的32.66%：2011年，化妆品进口平均单价为19.96美元/千克，出口平均
# Translating chunk: 单价为3.76美元/千克，为进口单价的18.84%。可以看出，差距仍在进一步扩大。
# Translating chunk: 这种价格方面的劣势说明我国出口化妆品含金量低，维持贸易增长是建立在大量
# Translating chunk: 出口基础上，是以价值牺牲为代价换取的。这种状况给我国的化妆品生产企业提
# Translating chunk: 出了非常严峻的课题，应尽快改善产品质量，大力提高附加值。
# Translating chunk: 表2.22007-2011年我国化妆品出口数量、金额一览表
# Translating chunk: 年份
# Translating chunk: 数量
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: 金额
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: （万吨）
# Translating chunk: （万吨）
# Translating chunk: （%）
# Translating chunk: （亿美元）
# Translating chunk: （亿美元）
# Translating chunk: (%)
# Translation returned None for chunk: (%)
# Translating chunk: 2007
# Translating chunk: 24.37
# Translating chunk: 一
# Translating chunk: 10.29
# Translating chunk: 一
# Translating chunk: 2008
# Translating chunk: 20.20
# Translating chunk: -4.17
# Translating chunk: -17.11
# Translating chunk: 9.36
# Translating chunk: -0.93
# Translating chunk: -9.04
# Translating chunk: 2009
# Translating chunk: 31.37
# Translating chunk: 11.17
# Translating chunk: 55.30
# Translating chunk: 11.66
# Translating chunk: 2.30
# Translating chunk: 24.57
# Translating chunk: 2010
# Translating chunk: 41.58
# Translating chunk: 10.21
# Translating chunk: 32.55
# Translating chunk: 17.50
# Translating chunk: 5.84
# Translating chunk: 50.09
# Translating chunk: 2011
# Translating chunk: 67.14
# Translating chunk: 25.56
# Translating chunk: 61.47
# Translating chunk: 25.22
# Translating chunk: 7.72
# Translating chunk: 44.11
# Translating chunk: 表2.3
# Translating chunk: 2007~2011年化妆品进口数量、金额一览表
# Translating chunk: 年份
# Translating chunk: 数量
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: 金额
# Translating chunk: 增长量
# Translating chunk: 增长率
# Translating chunk: （万吨）
# Translating chunk: （万吨）
# Translating chunk: （%）
# Translating chunk: （亿美元）
# Translating chunk: （亿美元）
# Translating chunk: （%）
# Translating chunk: 2007
# Translating chunk: 5.32
# Translating chunk: 一
# Translating chunk: 一
# Translating chunk: 6.88
# Translating chunk: 一
# Translating chunk: 一
# Translating chunk: 2008
# Translating chunk: 6.11
# Translating chunk: 0.79
# Translating chunk: 14.85
# Translating chunk: 9.36
# Translating chunk: 2.48
# Translating chunk: 36.05
# Translating chunk: 2009
# Translating chunk: 5.90
# Translating chunk: -0.21
# Translating chunk: -3.44
# Translating chunk: 10.70
# Translating chunk: 1.34
# Translating chunk: 14.32
# Translating chunk: 2010
# Translating chunk: 7.55
# Translating chunk: 1.65
# Translating chunk: 27.97
# Translating chunk: 15.00
# Translating chunk: 4.30
# Translating chunk: 40.19
# Translating chunk: 2011
# Translating chunk: 10.83
# Translating chunk: 3.28
# Translating chunk: 43.44
# Translating chunk: 21.62
# Translating chunk: 6.62
# Translating chunk: 44.13
# Translating chunk: 5
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 出口
# Translating chunk: 进口
# Translating chunk: 单位：万吨
# Translating chunk: 80
# Translating chunk: 60
# Translating chunk: 40
# Translating chunk: 20
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 图2.12007~2011年我国化妆品进出口数量分析图
# Translating chunk: 出口
# Translating chunk: 进口
# Translating chunk: 单位：亿美元
# Translating chunk: 30
# Translating chunk: 20
# Translating chunk: 15
# Translating chunk: 10
# Translating chunk: 5
# Translating chunk: 0
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 图2.22007-2011年我国化妆品进出口金额分析图
# Translating chunk: 2.3.22007~2011年中国化妆品出口构成
# Translating chunk: 近5年来，我国化妆品出口主要以肤用化妆品、发用化妆品、口腔类化妆品
# Translating chunk: 及美容化妆品为主，占总出口额的80%以上。其中，增幅列居首位的是肤用化妆
# Translating chunk: 品，其平均年增长达1.42亿美元，所占比重上升了14%：其次是口腔类化妆品，
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 平均年增长达0.61亿美元，所占比重上升8%：再者是美容化妆品，平均年增长
# Translating chunk: 达0.36亿美元，所占比重下降23%：其余种类增幅相对较低。
# Translating chunk: 表2.42007-2011年我国各类化妆品出口数量、金额一览表
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 化妆品类别
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 肤用化妆品
# Translating chunk: 4.18
# Translating chunk: 2.32
# Translating chunk: 4.86
# Translating chunk: 2.25
# Translating chunk: 11.38
# Translating chunk: 3.46
# Translating chunk: 14.49
# Translating chunk: 6.12
# Translating chunk: 21.76
# Translating chunk: 9.43
# Translating chunk: 发用化妆品
# Translating chunk: 6.09
# Translating chunk: 1.23
# Translating chunk: 5.53
# Translating chunk: 1.19
# Translating chunk: 6.97
# Translating chunk: 1.41
# Translating chunk: 10.06
# Translating chunk: 1.90
# Translating chunk: 10.21
# Translating chunk: 2.26
# Translating chunk: 口腔类化妆品
# Translating chunk: 3.50
# Translating chunk: 0.71
# Translating chunk: 2.14
# Translating chunk: 0.43
# Translating chunk: 5.61
# Translating chunk: 0.97
# Translating chunk: 7.65
# Translating chunk: 1.36
# Translating chunk: 20.60
# Translating chunk: 3.74
# Translating chunk: 美容化妆品
# Translating chunk: 8.91
# Translating chunk: 5.38
# Translating chunk: 6.40
# Translating chunk: 5.00
# Translating chunk: 5.28
# Translating chunk: 4.82
# Translating chunk: 6.60
# Translating chunk: 6.63
# Translating chunk: 7.07
# Translating chunk: 7.18
# Translating chunk: 香水类化妆品
# Translating chunk: 0.85
# Translating chunk: 0.53
# Translating chunk: 0.73
# Translating chunk: 0.42
# Translating chunk: 1.36
# Translating chunk: 0.73
# Translating chunk: 1.81
# Translating chunk: 1.07
# Translating chunk: 2.56
# Translating chunk: 1.21
# Translating chunk: 特殊功能化妆品
# Translating chunk: 0.78
# Translating chunk: 0.11
# Translating chunk: 0.44
# Translating chunk: 0.07
# Translating chunk: 0.68
# Translating chunk: 0.26
# Translating chunk: 0.77
# Translating chunk: 0.26
# Translating chunk: 0.82
# Translating chunk: 0.33
# Translating chunk: 其他化妆品
# Translating chunk: 0.05
# Translating chunk: 0.01
# Translating chunk: 0.10
# Translating chunk: 0.01
# Translating chunk: 0.08
# Translating chunk: 0.01
# Translating chunk: 0.21
# Translating chunk: 0.17
# Translating chunk: 4.11
# Translating chunk: 1.06
# Translating chunk: 总计
# Translating chunk: 24.37
# Translating chunk: 10.29
# Translating chunk: 20.20
# Translating chunk: 9.36
# Translating chunk: 31.37
# Translating chunk: 1.66
# Translating chunk: 41.58
# Translating chunk: 17.50
# Translating chunk: 67.14
# Translating chunk: 25.22
# Translating chunk: 单位：亿美元
# Translating chunk: 10
# Translating chunk: ■2007年2008年2009年2010年2011年
# Translating chunk: 图2.32007~2011年我国各类化妆品出口金额分析图
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 香水类化妆品
# Translating chunk: 口腔类化妆品
# Translating chunk: 特殊功能化妆
# Translating chunk: 5%
# Translating chunk: 发用化妆品
# Translating chunk: 7%
# Translating chunk: 品1%
# Translating chunk: 其他化妆品
# Translating chunk: 12%
# Translating chunk: 0%
# Translating chunk: 肤用化妆品
# Translating chunk: 美容化妆品
# Translating chunk: 23%
# Translating chunk: 52%
# Translating chunk: 图2.42007年我国各类化妆品出口金额占比分析图
# Translating chunk: 香水类化妆品
# Translating chunk: 其他化妆品4%
# Translating chunk: 发用化妆品9%
# Translating chunk: 5%
# Translating chunk: 特殊功能化妆
# Translating chunk: 品1%
# Translating chunk: 口腔类化妆品
# Translating chunk: 15%
# Translating chunk: 肤用化妆品
# Translating chunk: 美容化妆品
# Translating chunk: 37%
# Translating chunk: 29%
# Translating chunk: 图2.52
# Translating chunk: 2011年我国各类化妆品出口金额占比分析图
# Translating chunk: 2.4近年的主要出口目标市场
# Translating chunk: 2.4.12007~2011年中国化妆品出口五大洲数量及金额分析
# Translating chunk: 据统计数据显示，亚洲、美洲和欧洲为我国化妆品主要出口地区。相比2007
# Translating chunk: 年，2011年我国化妆品出口亚洲的数量和金额分别增长了13.03万吨和6.14亿
# Translating chunk: 美元，所占比重前者下降3%，后者上升19%：出口美洲的数量和金额分别增长
# Translating chunk: 了8.25万吨和2.76亿美元，所占比重依次下降5%和10%：出口欧洲的数量和
# Translating chunk: 金额分别增长了9.87万吨和3.88亿美元，所占比重前者上升6%，后者下降7%；
# Translating chunk: 出口非洲的数量和金额分别增加了2.63万吨和0.53亿美元，所占比重依次上升
# Translating chunk: 3%和1%：出口大洋洲的数量和金额分别增加了0.61万吨和0.01亿美元，所占
# Translating chunk: 比重依次下降1%和3%。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 表2.52007~2011年化妆品出口五大洲数量及金额
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 洲别
# Translating chunk: 亚洲
# Translating chunk: 美洲
# Translating chunk: 欧洲
# Translating chunk: 非洲
# Translating chunk: 大洋洲
# Translating chunk: 年份
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 2007
# Translating chunk: 9.60
# Translating chunk: 2.93
# Translating chunk: 7.40
# Translating chunk: 3.35
# Translating chunk: 4.36
# Translating chunk: 1.97
# Translating chunk: 0.78
# Translating chunk: 0.20
# Translating chunk: 0.91
# Translating chunk: 0.44
# Translating chunk: 2008
# Translating chunk: 9.53
# Translating chunk: 3.56
# Translating chunk: 4.73
# Translating chunk: 2.47
# Translating chunk: 3.31
# Translating chunk: 1.96
# Translating chunk: 1.40
# Translating chunk: 0.31
# Translating chunk: 0.46
# Translating chunk: 0.14
# Translating chunk: 2009
# Translating chunk: 14.38
# Translating chunk: 4.83
# Translating chunk: 6.96
# Translating chunk: 2.71
# Translating chunk: 6.52
# Translating chunk: 2.61
# Translating chunk: 1.67
# Translating chunk: 0.35
# Translating chunk: 0.70
# Translating chunk: 0.19
# Translating chunk: 2010
# Translating chunk: 17.82
# Translating chunk: 6.06
# Translating chunk: 9.67
# Translating chunk: 3.92
# Translating chunk: 8.24
# Translating chunk: 4.21
# Translating chunk: 1.99
# Translating chunk: 0.44
# Translating chunk: 0.78
# Translating chunk: 0.25
# Translating chunk: 2011
# Translating chunk: 22.63
# Translating chunk: 9.07
# Translating chunk: 15.64
# Translating chunk: 6.11
# Translating chunk: 14.23
# Translating chunk: 5.85
# Translating chunk: 3.41
# Translating chunk: 0.73
# Translating chunk: 1.53
# Translating chunk: 0.45
# Translating chunk: 非洲
# Translating chunk: 大洋洲
# Translating chunk: 3%
# Translating chunk: 4%
# Translating chunk: 欧洲
# Translating chunk: 19%
# Translating chunk: 亚洲
# Translating chunk: 42%
# Translating chunk: 美洲
# Translating chunk: 32%
# Translating chunk: 图2.6
# Translating chunk: 2007年我国出口各大洲化妆品数量占比分析图
# Translating chunk: 大洋洲
# Translating chunk: 非洲
# Translating chunk: 6%
# Translating chunk: 3%
# Translating chunk: 欧洲
# Translating chunk: 亚洲
# Translating chunk: 25%
# Translating chunk: 39%
# Translating chunk: 美洲
# Translating chunk: 27%
# Translating chunk: 图2.72011年我国出口各大洲化妆品金额占比分析图
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 大洋洲
# Translating chunk: 非洲
# Translating chunk: 5%
# Translating chunk: 2%
# Translating chunk: 亚洲
# Translating chunk: 22%
# Translating chunk: 欧洲
# Translating chunk: 33%
# Translating chunk: 美洲
# Translating chunk: 38%
# Translating chunk: 图2.82007年我国出口各大洲化妆品金额占比分析图
# Translating chunk: 非洲
# Translating chunk: 大洋洲
# Translating chunk: 3%
# Translating chunk: 2%
# Translating chunk: 欧洲
# Translating chunk: 26%
# Translating chunk: 亚洲
# Translating chunk: 41%
# Translating chunk: 美洲
# Translating chunk: 28%
# Translating chunk: 图2.92011年我国出口各大洲化妆品金额占比分析图
# Translating chunk: 2.4.22007~2011年中国化妆品主要出口地区数量及金额分析
# Translating chunk: 近5年来，北美、欧盟和香港地区一直是我国化妆品出口较多的地区。2011
# Translating chunk: 年较2007年，出口至北美地区的数量和金额分别增长了6.68万吨和2.04亿美元，
# Translating chunk: 所占比重依次下降2%和9%：出口至欧盟地区的数量和金额分别增长了4.52万
# Translating chunk: 吨和3.00亿美元，所占比重依次上升2%和3%：出口至香港地区的数量和金额
# Translating chunk: 分别增长了5.82万吨和2.75亿美元，数量所占比重下降3%，金额所占比重上升
# Translating chunk: 4%。2011年出口到这3个地区的数量和金额均占化妆品出口总量和总额的60%
# Translating chunk: 10
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 以上。
# Translating chunk: 表2.6
# Translating chunk: 2007-2011年我国化妆品主要出口地区数量及金额
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 地区
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 北美
# Translating chunk: 6.56
# Translating chunk: 3.04
# Translating chunk: 3.90
# Translating chunk: 2.14
# Translating chunk: 6.07
# Translating chunk: 2.36
# Translating chunk: 7.93
# Translating chunk: 3.26
# Translating chunk: 13.24
# Translating chunk: 5.08
# Translating chunk: 欧盟
# Translating chunk: 2.89
# Translating chunk: 1.60
# Translating chunk: 2.85
# Translating chunk: 1.81
# Translating chunk: 3.56
# Translating chunk: 2.09
# Translating chunk: 4.79
# Translating chunk: 3.58
# Translating chunk: 7.41
# Translating chunk: 4.60
# Translating chunk: 香港
# Translating chunk: 6.10
# Translating chunk: 1.37
# Translating chunk: 5.48
# Translating chunk: 1.93
# Translating chunk: 8.92
# Translating chunk: 2.66
# Translating chunk: 10.63
# Translating chunk: 3.34
# Translating chunk: 11.92
# Translating chunk: 4.12
# Translating chunk: 东亚
# Translating chunk: 0.96
# Translating chunk: 0.66
# Translating chunk: 0.82
# Translating chunk: 0.74
# Translating chunk: 1.06
# Translating chunk: 0.82
# Translating chunk: 1.79
# Translating chunk: 1.01
# Translating chunk: 2.93
# Translating chunk: 1.51
# Translating chunk: 东盟
# Translating chunk: 0.96
# Translating chunk: 0.80
# Translating chunk: 0.65
# Translating chunk: 0.86
# Translating chunk: 0.99
# Translating chunk: 0.90
# Translating chunk: 1.37
# Translating chunk: 1.29
# Translating chunk: 2.33
# Translating chunk: 1.70
# Translating chunk: 台湾
# Translating chunk: 0.82
# Translating chunk: 0.31
# Translating chunk: 0.81
# Translating chunk: 0.36
# Translating chunk: 1.23
# Translating chunk: 0.47
# Translating chunk: 1.41
# Translating chunk: 0.56
# Translating chunk: 1.57
# Translating chunk: 0.62
# Translating chunk: 中东
# Translating chunk: 1.26
# Translating chunk: 0.47
# Translating chunk: 1.42
# Translating chunk: 0.41
# Translating chunk: 1.46
# Translating chunk: 0.52
# Translating chunk: 1.71
# Translating chunk: 0.60
# Translating chunk: 2.42
# Translating chunk: 0.80
# Translating chunk: 拉美
# Translating chunk: 0.83
# Translating chunk: 0.31
# Translating chunk: 0.82
# Translating chunk: 0.33
# Translating chunk: 0.86
# Translating chunk: 0.33
# Translating chunk: 1.71
# Translating chunk: 0.65
# Translating chunk: 2.37
# Translating chunk: 1.02
# Translating chunk: 东欧
# Translating chunk: 1.43
# Translating chunk: 0.36
# Translating chunk: 0.44
# Translating chunk: 0.14
# Translating chunk: 2.93
# Translating chunk: 0.50
# Translating chunk: 1.37
# Translating chunk: 1.29
# Translating chunk: 2.33
# Translating chunk: 1.70
# Translating chunk: 大洋洲
# Translating chunk: 0.91
# Translating chunk: 0.44
# Translating chunk: 0.45
# Translating chunk: 0.14
# Translating chunk: 0.70
# Translating chunk: 0.19
# Translating chunk: 0.78
# Translating chunk: 0.25
# Translating chunk: 1.52
# Translating chunk: 0.45
# Translating chunk: 非洲
# Translating chunk: 0.78
# Translating chunk: 0.20
# Translating chunk: 1.40
# Translating chunk: 0.31
# Translating chunk: 1.67
# Translating chunk: 0.35
# Translating chunk: 1.99
# Translating chunk: 0.44
# Translating chunk: 3.41
# Translating chunk: 0.73
# Translating chunk: [注]北美：美国、加拿大，共2国：
# Translating chunk: 欧盟：法国、意大利、荷兰、比利时、卢森堡、德国、爱尔兰、丹麦、英国、希腊、
# Translating chunk: 葡萄牙、西班牙、奥地利、芬兰、瑞典、波兰、拉脱维亚、立陶宛、爱沙尼亚、
# Translating chunk: 匈牙利、捷克、斯洛伐克、斯洛文尼亚、马耳他、塞浦路斯、保加利亚、罗马
# Translating chunk: 尼亚，共27国：
# Translating chunk: 东亚：日本、韩国、朝鲜、蒙古，共4国：
# Translating chunk: 东盟：印度尼西亚、新加坡、泰国、菲律宾、马来西亚、文莱、缅甸、越南、老挝、
# Translating chunk: 柬埔赛，共10国：
# Translating chunk: 中东：巴林、埃及、伊朗、伊拉克、以色列、约旦、科威特、黎巴嫩、阿曼、卡塔尔、
# Translating chunk: 沙特阿拉伯、叙利亚、阿拉伯联合首长国、也门、巴勒斯坦、阿尔及利亚、利
# Translating chunk: 比亚、摩洛哥、突尼斯、苏丹、毛里塔尼亚、索马里，共22国：
# Translating chunk: 东欧：俄罗斯联邦、白俄罗斯、乌克兰、摩尔多瓦，共4国。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 东欧6%中东5%
# Translating chunk: 东盟4%
# Translating chunk: 欧盟12%
# Translating chunk: 东亚4%
# Translating chunk: 大洋洲4%
# Translating chunk: 拉美4%
# Translating chunk: 香港26%
# Translating chunk: 其他15%
# Translating chunk: 台湾4%
# Translating chunk: 非洲3%
# Translating chunk: 北美28%
# Translating chunk: 图2.10
# Translating chunk: 2007年我国化妆品主要出口地区数量分布占比分析图
# Translating chunk: 东亚6%
# Translating chunk: 非洲
# Translating chunk: 中东5%
# Translating chunk: 7%
# Translating chunk: 拉美5%
# Translating chunk: 欧盟14%
# Translating chunk: 东盟4%
# Translating chunk: 其他14%
# Translating chunk: 东欧4%
# Translating chunk: 香港23%
# Translating chunk: 台湾3%
# Translating chunk: 大洋洲3%
# Translating chunk: 北美26%
# Translating chunk: 图2.11
# Translating chunk: 2011年我国化妆品主要出口地区数量分布占比分析图
# Translating chunk: 东盟
# Translating chunk: 东亚
# Translating chunk: 中东5%
# Translating chunk: 8%
# Translating chunk: 7%
# Translating chunk: 大洋洲5
# Translating chunk: 香港14%
# Translating chunk: 东欧4%
# Translating chunk: 其他12%
# Translating chunk: 台湾3%
# Translating chunk: 欧盟17%
# Translating chunk: 拉美3%
# Translating chunk: 北美32%
# Translating chunk: 非洲2%
# Translating chunk: 图2.122007年我国化妆品主要出口地区金额分布占比分析图
# Translating chunk: 12
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 东盟
# Translating chunk: 东欧
# Translating chunk: 东亚7%
# Translating chunk: 8%
# Translating chunk: 8%
# Translating chunk: 拉美4
# Translating chunk: 中东3%
# Translating chunk: 香港18%
# Translating chunk: 其他11%
# Translating chunk: 非3%
# Translating chunk: 欧盟21%
# Translating chunk: 台湾3%
# Translating chunk: 北美23%
# Translating chunk: 大洋洲2%
# Translating chunk: 图2.132011年我国化妆品主要出口地区金额分布占比分析图
# Translating chunk: 2.4.32007~20011年中国化妆品主要出口国家或地区数量及金额分析
# Translating chunk: 2011年，我国化妆品出口贸易共涉及180多个国家或地区。以金额计，列
# Translating chunk: 居前十的国家或地区依次为：美国、香港、英国、保税区、日本、俄罗斯、法国、
# Translating chunk: 波兰、新加坡和台湾。其2011年共计从我国进口化妆品40.82万吨，价值17.58
# Translating chunk: 亿美元，分别占比60.79%和69.70%.其中美国和香港远超其他国家或地区，出
# Translating chunk: 口数量和金额占比均大于50%。然而从出口平均单价来看，新加坡、波兰和法国
# Translating chunk: 优势明显，价格较高，俄罗斯最低，仅为1.78美元/千克，约为新加坡的1/10。
# Translating chunk: 表2.72007~2011年我国化妆品主要出口国家（地区）数量及金额分布
# Translating chunk: 单位：万吨/亿美元
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 国家
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 美国
# Translating chunk: 6.36
# Translating chunk: 2.98
# Translating chunk: 3.70
# Translating chunk: 2.06
# Translating chunk: 5.81
# Translating chunk: 2.29
# Translating chunk: 7.58
# Translating chunk: 3.14
# Translating chunk: 12.46
# Translating chunk: 4.85
# Translating chunk: 香港
# Translating chunk: 6.10
# Translating chunk: 1.37
# Translating chunk: 5.48
# Translating chunk: 1.93
# Translating chunk: 8.92
# Translating chunk: 2.66
# Translating chunk: 10.63
# Translating chunk: 3.34
# Translating chunk: 11.92
# Translating chunk: 4.12
# Translating chunk: 英国
# Translating chunk: 1.10
# Translating chunk: 0.40
# Translating chunk: 1.26
# Translating chunk: 0.56
# Translating chunk: 1.66
# Translating chunk: 0.77
# Translating chunk: 2.21
# Translating chunk: 1.13
# Translating chunk: 3.77
# Translating chunk: 1.65
# Translating chunk: 保税区
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.00
# Translating chunk: 0.10
# Translating chunk: 0.10
# Translating chunk: 1.23
# Translating chunk: 1.37
# Translating chunk: 日本
# Translating chunk: 0.73
# Translating chunk: 0.59
# Translating chunk: 0.58
# Translating chunk: 0.65
# Translating chunk: 0.77
# Translating chunk: 0.71
# Translating chunk: 1.44
# Translating chunk: 0.87
# Translating chunk: 2.23
# Translating chunk: 1.27
# Translating chunk: 俄罗斯
# Translating chunk: 1.15
# Translating chunk: 0.26
# Translating chunk: 0.39
# Translating chunk: 0.11
# Translating chunk: 2.45
# Translating chunk: 0.40
# Translating chunk: 2.68
# Translating chunk: 0.47
# Translating chunk: 6.12
# Translating chunk: 1.09
# Translating chunk: 法国
# Translating chunk: 0.32
# Translating chunk: 0.45
# Translating chunk: 0.23
# Translating chunk: 0.52
# Translating chunk: 0.27
# Translating chunk: 0.50
# Translating chunk: 0.43
# Translating chunk: 0.86
# Translating chunk: 0.54
# Translating chunk: 0.93
# Translating chunk: 13
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: （续表）
# Translating chunk: 2007年
# Translating chunk: 2008年
# Translating chunk: 2009年
# Translating chunk: 2010年
# Translating chunk: 2011年
# Translating chunk: 国家
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 数量
# Translating chunk: 金额
# Translating chunk: 波兰
# Translating chunk: 0.03
# Translating chunk: 0.02
# Translating chunk: 0.14
# Translating chunk: 0.13
# Translating chunk: 0.11
# Translating chunk: 0.13
# Translating chunk: 0.40
# Translating chunk: 0.69
# Translating chunk: 0.49
# Translating chunk: 0.85
# Translating chunk: 新加坡
# Translating chunk: 0.31
# Translating chunk: 0.42
# Translating chunk: 0.22
# Translating chunk: 0.48
# Translating chunk: 0.35
# Translating chunk: 0.46
# Translating chunk: 0.41
# Translating chunk: 0.72
# Translating chunk: 0.48
# Translating chunk: 0.84
# Translating chunk: 台湾
# Translating chunk: 0.82
# Translating chunk: 0.31
# Translating chunk: 0.81
# Translating chunk: 0.36
# Translating chunk: 1.23
# Translating chunk: 0.47
# Translating chunk: 1.41
# Translating chunk: 0.56
# Translating chunk: 1.57
# Translating chunk: 0.62
# Translating chunk: 俄罗斯15%
# Translating chunk: 英国9%
# Translating chunk: 日本6
# Translating chunk: 台湾4%
# Translating chunk: 香港29%
# Translating chunk: 其他10%
# Translating chunk: 保税区3%
# Translating chunk: 法国
# Translating chunk: 1%
# Translating chunk: 波兰1%
# Translating chunk: 美国31%
# Translating chunk: 新加坡1%
# Translating chunk: 图2.142011年我国化妆品主要出口国家或地区数量分布占比分析图
# Translating chunk: 保税区
# Translating chunk: 英国9%
# Translating chunk: 8%
# Translating chunk: 日本
# Translating chunk: 7%
# Translating chunk: 俄罗斯6%
# Translating chunk: 法国5%
# Translating chunk: 香港23%
# Translating chunk: 其他25%
# Translating chunk: 波兰5%
# Translating chunk: 新加坡5%
# Translating chunk: 台湾4%
# Translating chunk: 美国28%
# Translating chunk: 图2.152011年我国化妆品主要出口国家或地区金额分布占比分析图
# Translating chunk: 14
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 单位：美元/千克
# Translating chunk: 20
# Translating chunk: 17.30
# Translating chunk: 17.38
# Translating chunk: 15
# Translating chunk: 17.50
# Translating chunk: 11.10
# Translating chunk: 10
# Translating chunk: 4.37
# Translating chunk: 5.66
# Translating chunk: 3.90
# Translating chunk: 3.45
# Translating chunk: 1.78
# Translating chunk: 3.91
# Translating chunk: 美国
# Translating chunk: 香港
# Translating chunk: 英国
# Translating chunk: 保税区
# Translating chunk: 日本
# Translating chunk: 俄罗斯
# Translating chunk: 法国
# Translating chunk: 波兰
# Translating chunk: 新加坡台湾
# Translating chunk: 图2.16
# Translating chunk: 2011年我国化妆品主要出口国家出口化妆品平均单价
# Translating chunk: 此外，较2007年，以上10个国家或地区的出口贸易均呈现出不同程度的增
# Translating chunk: 长，按金额统计，增幅列居前三的国家依次为：波兰、俄罗斯和英国。
# Translating chunk: 单位：万吨
# Translating chunk: 14
# Translating chunk: 2007年
# Translating chunk: 12
# Translating chunk: 2011年
# Translating chunk: 10
# Translating chunk: 美国
# Translating chunk: 香港英国保税区日本俄罗斯法国波兰新加坡台湾
# Translating chunk: 图2.172007、2011年我国化妆品主要出口国家或地区数量分析图
# Translating chunk: 15
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 单位：亿美元
# Translating chunk: 2007年
# Translating chunk: 2011年
# Translating chunk: 美国
# Translating chunk: 香港
# Translating chunk: 英国保税区日本俄罗斯法国
# Translating chunk: 波兰新加坡台湾
# Translating chunk: 图2.182007、2011年我国化妆品主要出口国家或地区金额分析图
# Translating chunk: 2.4.4主要出口目标市场分析
# Translating chunk: 2.4.4.1美国
# Translating chunk: 美国是化妆品业的全球巨头。2011年我国对美出口化妆品共计4.85亿美元，
# Translating chunk: 其中肤用化妆品出口2.16亿美元，占比44%：美容化妆品出口1.79亿美元，占
# Translating chunk: 比37%：其他化妆品出口0.29亿美元，占比6%：香水类化妆品出口0.28亿美
# Translating chunk: 元，占比6%：发用化妆品出口0.27亿美元，占比6%：特殊功能化妆品出口0.04
# Translating chunk: 亿美元，占比1%：口腔类化妆品出口0.02亿美元，占比不足0.5%
# Translating chunk: 其他化妆品6%
# Translating chunk: 美容化妆品
# Translating chunk: 香水类化妆品
# Translating chunk: 37%
# Translating chunk: 6%
# Translating chunk: 发用化妆品6%
# Translating chunk: 特殊功能化妆
# Translating chunk: 品1%
# Translating chunk: 口腔类化妆品
# Translating chunk: 肤用化妆品
# Translating chunk: 0%
# Translating chunk: 44%
# Translating chunk: 图2.192011年我国各类化妆品出口至美国金额占比分析图
# Translating chunk: 16
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 2.4.4.2日本
# Translating chunk: 日本在化妆品生产和消费方面均为比较发达的国家，市场规模仅次于美国。
# Translating chunk: 其拥有亚洲最大的化妆品市场和研究开发中心，在经历高速发展之后，目前已进
# Translating chunk: 入成熟期。2011年我国对日出口化妆品共计1.27亿美元，其中肤用化妆品出口
# Translating chunk: 0.47亿美元，占比37%：美容化妆品出口0.40亿美元，占比32%：发用化妆品
# Translating chunk: 出口0.31亿美元，占比25%：特殊功能化妆品出口0.05亿美元，占比4%：其
# Translating chunk: 他化妆品出口0.02亿美元，占比1%：口腔类化妆品出口0.01亿美元，占比1%：
# Translating chunk: 香水类化妆品出口较小，不足0.01亿美元。
# Translating chunk: 发用化妆品
# Translating chunk: 特殊功能化妆
# Translating chunk: 25%
# Translating chunk: 品4%
# Translating chunk: 其他化妆品1%
# Translating chunk: 美容化妆品
# Translating chunk: 口腔类化妆品
# Translating chunk: 32%
# Translating chunk: 1%
# Translating chunk: 香水类化妆品
# Translating chunk: 肤用化妆品
# Translating chunk: 0%
# Translating chunk: 37%
# Translating chunk: 图2.202011年我国各类化妆品出口至日本金额占比分析图
# Translating chunk: 2.4.4.3欧盟
# Translating chunk: 欧盟是我国最大的贸易伙伴，其化妆品制造业尤为发达，英国、法国、德国、
# Translating chunk: 意大利等都是传统的化妆品制造强国，拥有众多大型化妆品企业和久负胜名的化
# Translating chunk: 妆品领军品牌。2011年我国向欧盟出口化妆品共计4.60亿美元，其中肤用化妆
# Translating chunk: 品出口2.12亿美元，占比46%：美容化妆品出口1.69亿美元，占比37%：香水
# Translating chunk: 类化妆品出口0.53亿美元，占比12%：发用化妆品出口0.09亿美元，占比2%；
# Translating chunk: 口腔类化妆品出口0.08亿美元，占比2%：其他化妆品出口0.06亿美元，占比
# Translating chunk: 1%：特殊功能化妆品出口0.01亿美元，占比不足0.3%。
# Translating chunk: 17
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 美容化妆品
# Translating chunk: 香水类化妆品
# Translating chunk: 37%
# Translating chunk: 12%
# Translating chunk: 发用化妆品2%
# Translating chunk: 口腔类化妆品
# Translating chunk: 其他化妆品1%
# Translating chunk: 2%
# Translating chunk: 特殊功能化妆
# Translating chunk: 肤用化妆品
# Translating chunk: 品0%
# Translating chunk: 46%
# Translating chunk: 图2.212011年我国各类化妆品出口至欧盟金额占比分析图
# Translating chunk: 2.4.4.4香港
# Translating chunk: 香港化妆品的本销及转口贸易均相当发达，是我国主要出口地区之一。2011
# Translating chunk: 年，我国对港出口化妆品共计4.12亿美元，其中肤用化妆品出口1.48亿美元，
# Translating chunk: 占比36%：美容化妆品出口0.84亿美元，占比20%：发用化妆品出口0.72亿美
# Translating chunk: 元，占比18%：口腔类化妆品出口0.56亿美元，占比14%：其他化妆品出口0.37
# Translating chunk: 亿美元，占比9%：香水类化妆品出口0.09亿美元，占比2%：特殊功能化妆品
# Translating chunk: 出口0.05亿美元，占比1%。
# Translating chunk: 发用化妆品
# Translating chunk: 口腔类化妆
# Translating chunk: 品14%
# Translating chunk: 其他化妆品9%
# Translating chunk: 18%
# Translating chunk: 香水类化妆品
# Translating chunk: 美容化妆品
# Translating chunk: 2%
# Translating chunk: 20%
# Translating chunk: 特殊功能化妆
# Translating chunk: 品1%
# Translating chunk: 肤用化妆品
# Translating chunk: 36%
# Translating chunk: 图2.222011年我国各类化妆品出口至香港金额占比分析图
# Translating chunk: 18
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 2.4.4.5其他市场
# Translating chunk: 随着中国与东盟的自由贸易区的建立，东盟成为我国化妆品出口的重要市场
# Translating chunk: 之一。2011年对东盟化妆品出口占我国化妆品出口总额的8%，仅次于北美、欧
# Translating chunk: 盟和香港。我国向东盟出口的化妆品涵盖了较大的范围，既有化妆品、护肤品、
# Translating chunk: 须后水等较高级阶段的制成品，也有香精、精油等原料型产品，这在一定程度上
# Translating chunk: 说明我国的化妆品工业的生产技术和经验比东盟更为丰富，处于一定的竞争优势
# Translating chunk: 地位，值得国内企业关注，并积极开拓东南亚化妆品市场。此外，中国和东盟国
# Translating chunk: 家化妆品关税的削减也将在一定程度上推动双方相关产品进出口贸易增长。
# Translating chunk: 2.5我国产品在国际市场的主要优势
# Translating chunk: 2.5.1价格优势
# Translating chunk: 我国化妆品主要集中在中低档产品，品质优良，但包装简易、产品线简单，
# Translating chunk: 因而造就了低成本、低售价。我国有丰富的劳动力资源，劳动力成本较低。我国
# Translating chunk: 具有丰富的自然资源，为化妆品的生产提供了原料保障。我国入世后，化工原料
# Translating chunk: 进口关税下调，降低了产品的成本。
# Translating chunk: 2.5.2技术优势
# Translating chunk: 我国化妆品的生产和使用有着悠久的历史，有着深厚底蕴的文化内涵。我国
# Translating chunk: 上海家化、天津郁美净等化妆品企业有较长的生产历史，拥有先进的工艺设备和
# Translating chunk: 雄厚的技术力量。他们实施规范的生产程序，导入科学管理方法，创建护肤研究
# Translating chunk: 中心，严格监控产品质量，研制出大量优质的护肤产品：注重新产品的开发，应
# Translating chunk: 用现代高科技手段，从根本上改变产品结构，增加产品的附加值和技术含量。
# Translating chunk: 化妆品是多种学科相互交叉的结品，近年来我国与化妆品相关的产业，如机
# Translating chunk: 械工业、包装工业、化学工业、医药工业、中医药工业和微电子工业的快速发展，
# Translating chunk: 为化妆品提供更多的优质原料、包装材料、装备技术和拓展化妆品需用的中医中
# Translating chunk: 药，使化妆品业不断向深度和广度进展，呈现出前所未有的兴旺景象。
# Translating chunk: 我国具有得天独厚的中草药资源条件，中药化妆品历史悠久、品种齐全、剂
# Translating chunk: 19
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 型多样，与中医药融为一体，具有明显的功能性。以化学合成物质为原料的化妆
# Translating chunk: 品易产生毒副作用和皮肤过墩反应，而天然植物为原料的化妆品具有安全可靠、
# Translating chunk: 标本兼治的特点，是生物功能性化妆品的最好原料，我国传统的中草药在几千年
# Translating chunk: 外敷内服的应用实践中已积累了许多药效记录和经验，对它们的用量、安全性和
# Translating chunk: 副作用也有许多验证，这就为化妆品的原料探寻开辟了广阔的资源，并对新型化
# Translating chunk: 妆品的开发提供了有利的条件，因此，我国在开发天然营养型和疗效性化妆品方
# Translating chunk: 面具备了很强的优势。
# Translating chunk: 另外，众多跨国化妆品公司来华投资，他们具备技术优势、产品优势、经营
# Translating chunk: 管理优势、世界性的协作优势和资讯优势，在中国生产国际一流的品牌，促进了
# Translating chunk: 高档次化妆品市场的发展：在中国投资数百万甚至上千万美元建立规模相当大的
# Translating chunk: 研究机构和研究发展中心，促进了我国化妆品业的蓬勃发展。另外，他们还是国
# Translating chunk: 际化妆品行业相关法规、产品标准的研究和制定的参与者，有关政府部门提出有
# Translating chunk: 关化妆品的监督管理的措施和方法，提供相关资讯，更有利于我国化妆品更快的
# Translating chunk: 与国际接轨。
# Translating chunk: 2.5.3规模优势
# Translating chunk: 目前，全国约有化妆品生产企业3300余家，逾2500种产品品种、14个中
# Translating chunk: 国名牌产地、25个中国驰名商标及150多个国家和地区的海外销售地，我国的
# Translating chunk: 化妆品工业已经初步形成了以化妆品产品为核心的庞大的化妆品经济链。2011
# Translating chunk: 年我国化妆品工业制造累计工业（现价）总产值为790.33亿元，同比增长21.6%，
# Translating chunk: 产销率为99%，2010年完成总产值为695.07亿元，同比增长18.7%，产销率为
# Translating chunk: 100.8%,(1)
# Translating chunk: 2.6潜在目标市场
# Translating chunk: 2.6.1东欧
# Translating chunk: 由于上世纪末多国化妆品公司的人驻，东欧地区的化妆品市场现已接近于成
# Translating chunk: 熟的西欧市场。诸多大销量的领先品牌诸如欧瑞莲、多芬和妮维雅等统领着整个
# Translating chunk: 市场，主要以护肤品和护发品为主。但各个地区细分市场却不尽相同。在克罗地
# Translating chunk: 亚，皮肤护理品是最大的市场，2007年的市场价值为5600万欧元，其次是护发
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 用品市场，为3900万欧元：在捷克共和国，护发品的市场价值超过了护肤品1.5
# Translating chunk: 亿欧元，达到1.95亿欧元：而在爱沙尼亚，护肤品市场价值为3000万欧元，护
# Translating chunk: 发品市场价值仅为1900万欧元：在斯洛文尼亚，护肤品市场占最大份额，价值
# Translating chunk: 3900万欧元，护发品次之，价值为3600万欧元，分别占据化妆品市场第一和第
# Translating chunk: 二的位置3。
# Translating chunk: 2.6.2拉美
# Translating chunk: 近年来，随着全球经济的复苏，化妆品产业出现了一些新的动态。2009年，
# Translating chunk: 在全球遭遇金融危机的背景下，拉美地区逆势走高，化妆品销售额增长15%：
# Translating chunk: 2010年，增长20%，BPC规模达6400万美元，几乎和北美市场媲美。业界人
# Translating chunk: 士对未来拉丁美洲的化妆品工业市场持以乐观的态度。2009年拉美排名前十的
# Translating chunk: 化妆品品牌依次为雅芳、娜图、高露洁、吉列、博蒂卡、Sunsilk、欧莱雅、妮维
# Translating chunk: 雅、棕榄和德芙。巴西作为拉美地区美容和个人护理品工业的销售区域中心，
# Translating chunk: 2009年化妆品市场销售额达290亿美元，占巴西GDP的1.3%。欧睿国际分析报
# Translating chunk: 告指出，未来，在更大的消费量的推动下，如购买频率的增加、低收入群体消费
# Translating chunk: 观念的转变，防晒护理品、婴儿护理品、脱毛剂和彩色化妆品都将保持动态增长
# Translating chunk: [5]。与此同时，拉美本土企业，诸如 Natura Cosmestics,Botica Comercial
# Translating chunk: FarmaceuticaLtda,L'Bel和Unique-Yanbal Group的发展也日益壮大起来"。拉丁
# Translating chunk: 美洲地区的化妆品工业正在努力发展和改进自然有机产品、环境主题、社会责任
# Translating chunk: 和所在地区不同国家之间的贸易。
# Translating chunk: 2.6.3中东
# Translating chunk: 近年来，随着人口的增加和当地旅游业的发展，中东地区逐渐成为全球范围
# Translating chunk: 内化妆品和个人护理用品产品发展较快地区之一。产品种类主要以美容类化妆品
# Translating chunk: 和香水为主，销售额年增长率保持在10%~15%。据海湾合作委员会统计显示，
# Translating chunk: 2006年，中东地区奢侈品/高端化妆品市场达8~10亿美元，阿联首占据28%的
# Translating chunk: 市场份额，拥有中东地区化妆品消费者最多的国家之一的沙特阿拉伯则占据了
# Translating chunk: 45%的市场份额。2007年，沙特阿拉伯的化妆品和香水销售额分别为13.2亿美
# Translating chunk: 元和2.38亿美元：2008年，迪拜的化妆品和香水的销售额分别增长了39%和34%。
# Translating chunk: 21
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 阿联酋的化妆品消费群体中，25%~30%为当地阿拉伯女性，25%~30%为外国人，
# Translating chunk: 15%~20%为游客。阿联酋和迪拜相对于沙特阿拉伯，市场管理较为宽松，发展
# Translating chunk: 较快，而消费者也表现得更加成熟和专业。
# Translating chunk: 2.6.4非洲
# Translating chunk: 近年来非洲化妆品市场需求量正在迅速增长，市场潜力巨大。在南非，化妆
# Translating chunk: 品市场每年的需求量就超过11.5亿美元，科特迪瓦在润肤霜和洗发剂类需求量
# Translating chunk: 每年能达到4000万美元。据统计整个非洲化妆品市场需求量年增长率达30%。
# Translating chunk: 来自诸多国家的化妆品企业已经相继进军非洲化妆品市场。任何一个地区的人们
# Translating chunk: 都不愿意亏待自已的皮肤，非洲人也不例外，即使是一些贫困国家大街小巷也不
# Translating chunk: 乏装扮时尚的女郎，化妆品专卖店、超市化妆品专柜和各种美容院也数不胜数。
# Translating chunk: 非洲人最喜欢在他们富有特点的头发上狠下功夫，在非洲化妆品专营店里面，用
# Translating chunk: 于洗发、护发、染发、美发的各种化妆品应有尽有。由于非洲大陆普遍炎热干燥，
# Translating chunk: 皮肤容易丧失水分，保湿霜、润肤油、爽肤水普遍受到消费者青睐。此外，非洲
# Translating chunk: 人还比较喜欢涂口红、擦指甲油、酒香气较浓的香水，而且在这方面，非洲男性
# Translating chunk: 比女性有过之而无不及。
# Translating chunk: 非洲化妆品主要来自进口。由于税收高，利润多，化妆品走私现象比较严重。
# Translating chunk: 法国产品在非洲市场的占有率最高，其次为美国。中国化妆品在非洲市场还比较
# Translating chunk: 少，作为中国化妆品企业可以通过参加非洲商品交易会、网络营销、参加化妆品
# Translating chunk: 展览会，做大做强我们的化妆品品牌，让非洲人了解中国的化妆品，尽早健康地
# Translating chunk: 进入非洲化妆品市场。中国企业生产的化妆品一般都不适合非洲人的皮肤和头发
# Translating chunk: 特征，所以中国化妆品想进入非洲市场的话，应该专门为这个市场开发一些产品，
# Translating chunk: 新产品的研究开发这一步不能省。
# Translating chunk: 22
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 三、主要市场化妆品标签要求及与我国的差异
# Translating chunk: 3.1欧盟
# Translating chunk: 3.1.1法律文件
# Translating chunk: ·Directive76/768/EEC（《指令76/768/EEC》）：《欧盟化妆品指令》（2013
# Translating chunk: 年7月11日废止）
# Translating chunk: ·Directive95/17/EC（《指令95/17/EC》）：有关化妆品一到多种成分在标
# Translating chunk: 签成分表中可不标注的详细规定
# Translating chunk: （EC）1223/2009（《欧洲议会和欧盟理事会化妆品法规》）：2013年7月11
# Translating chunk: 日开始生效，将取代旧的化妆品指令76/768/EEC及其到目前为止的67项修订文件
# Translating chunk: （注：其中部分要求将先于上述日期开始执行）
# Translating chunk: 3.1.2主管机关
# Translating chunk: 化妆品由欧盟委员会企业理事会化妆品和医学部门负责，各成员国有各自的
# Translating chunk: 官方机构负责本国的监督和管理，主要着重于上市后管理。
# Translating chunk: 各国政府主管部门的主要工作有三个方面：在销售、生产和分销地进行稽查：
# Translating chunk: 审查标签：审查所提供的文件。
# Translating chunk: 监督主要有三种方式：
# Translating chunk: ①健康危害或跟踪调查：
# Translating chunk: ②按照产品类别进行专项调查：
# Translating chunk: ③现场检查。
# Translating chunk: 3.1.3化妆品定义
# Translating chunk: 化妆品指用于人体外部任何部位（皮肤、毛发、指甲、口唇和外阴部）或牙
# Translating chunk: 23
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 齿及口腔粘膜的物质或制品，主要起到清洁、香化或保护作用，以达到良好状态、
# Translating chunk: 美容或消除体臭为目的。
# Translating chunk: 3.1.4化妆品分类
# Translating chunk: （1）膏霜、乳液、液、凝胶和油（手、脸、脚等）：
# Translating chunk: （2）面膜（化学性脱皮产品除外）；
# Translating chunk: （3）色彩固定剂：
# Translating chunk: （4）化妆粉、浴后用粉、卫生用粉等：
# Translating chunk: （5）盟洗用皂、除臭皂等：
# Translating chunk: （6）香水、卫生间水、古龙水：
# Translating chunk: （7）沐浴、冲洗用品（浴盐、浴泡、浴油、凝胶等）：
# Translating chunk: （8）脱毛剂：
# Translating chunk: （9）除臭剂和抑汗剂：
# Translating chunk: （10）发用产品（染发剂和漂白剂、卷发、直发和定型剂、定型产品、清洁
# Translating chunk: 产品（液、粉、香波）、护发产品（液、膏霜、油）、美发产品（液、光亮剂、
# Translating chunk: 油）：
# Translating chunk: （11）剃须产品（膏霜、泡沫、液等）：
# Translating chunk: （12）脸和眼部化妆和卸妆产品：
# Translating chunk: （13）唇部用产品：
# Translating chunk: （14）牙齿和口腔保护产品：
# Translating chunk: （15）指甲保护和化妆产品：
# Translating chunk: （16）外用个人卫生用品：
# Translating chunk: （17）日光浴产品：
# Translating chunk: （18）非日光黑肤产品：
# Translating chunk: 24
# Translating chunk: 各国化救品标签管理指南
# Translating chunk: （19）皮肤增白产品：
# Translating chunk: （20）抗皱产品。
# Translating chunk: 3.1.5化妆品标签要求
# Translating chunk: 3.1.5.1化妆品标签一般要求
# Translating chunk: 《欧盟化妆品指令》条款6规定了化妆品标签要求，规定必须注明以下内容：
# Translating chunk: （1）产品名称或类型
# Translating chunk: （2）生产商或欧盟内经销商的地址或注册的办事处
# Translating chunk: 提供多个地址时，必须注明保存产品资料的地址，可以在该地址下划线标明。
# Translating chunk: 欧盟指令不要求注明进口化妆品的原产国，但有的成员国可能要求注明：
# Translating chunk: （3）净含量
# Translating chunk: 以重量或体积标明。强制以SI公制单位标注，同时可以标注美国惯例单位。
# Translating chunk: 当两种单位都使用时，SI公制单位必须占支配地位。双标签只能使用到2009年。
# Translating chunk: 《指令76/211/EC》对净含量的标注要求做了规定，其修补法介绍了一系列
# Translating chunk: 平均体积或重量的管理。标签上净含量旁边的标志“e”表示净含量的标注符合
# Translating chunk: 该指令。《喷雾剂指令75/324/EEC》要求喷雾剂产品同时标注重量及体积。
# Translating chunk: （4）化妆品成分表
# Translating chunk: 要求在外包装上标注化妆品全部成分的名称。如果实际原因无法做到时，可
# Translating chunk: 印在附带的小册子、标签、带子或卡片上，但同时应该在外包装上印制简语或附
# Translating chunk: 录I中的符号指示消费者参看。应在句头以“成分（INGERDIENTS）”作为引
# Translating chunk: 导语引出成分表。
# Translating chunk: 标注顺序为：
# Translating chunk: ①含量高于1%的各成分名称按加入量的降序列出，含量低于1%的成分可
# Translating chunk: 按任意顺序列于其后。
# Translating chunk: ②着色剂可以以任意顺序标注在其他成分之后。对于有多种色号的美容化
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 妆品，使用范围内所有的着色剂都应列出，并标注字样“可能含有（maycontain）”
# Translating chunk: 或符号“+/-”。
# Translating chunk: 标注的成分名称：
# Translating chunk: ①成份必须使用下列法规规定或采用的名称：INCI名称（International
# Translating chunk: NomencaltureCosmeticIngredienr，化妆品成分国际名称）、欧洲药典名称、世界
# Translating chunk: 卫生组织推荐的非专利名称、欧洲现有流通商业化学物品目录（EINECS)索引号、
# Translating chunk: 国际纯化学与应用化学联盟（IUPAC）索引号、美国化学文摘（CAS）索引号、色
# Translating chunk: 素索引号以及条款7（2）中推荐的普通名称。
# Translating chunk: 下列情况不属于成分物质：
# Translating chunk: 一原料中的杂质；
# Translating chunk: 一生产中用到但成品中不含有的辅料：
# Translating chunk: 一作为香料或芳香物质的溶剂或载体且使用量受到严格控制的物质。
# Translating chunk: ②香料和芳香成分及其原料应以单词“香味”或“香型”（“perfume”或
# Translating chunk: “aroma”）给予提示：
# Translating chunk: ③着色剂必须采用染料颜色索引号（CI号），没有相应的CI号时，使用INCI
# Translating chunk: 名称：
# Translating chunk: 当含有附录Ⅲ中“其他限制和要求”表列出的要求提到的物质时，无论其功
# Translating chunk: 能如何，都应标注在成分表中。
# Translating chunk: 有时生产商出于商业秘密的原因，会提出不在成分表中公布一种或几种成分
# Translating chunk: 的申请，必须符合《指令95/17/EC》的规定。
# Translating chunk: （5）保质期
# Translating chunk: 保质期应标注为：“最好在·…（日期）前使用（bestused before the endof...）”，
# Translating chunk: 日期按下列标注方式之一进行标注：
# Translating chunk: 一日期（按“月，年”或是“日，月，年”顺序）
# Translating chunk: 一指示标注日期的地方
# Translating chunk: 26
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 对于保质期超过30个月的化妆品，不强制要求标注保质期，但需要标明开
# Translating chunk: 启后产品可以安全使用的时间。按附录Ⅲ（a）中给出的符号“开启后期限（Period
# Translating chunk: AfterOpening，PAO)”标注，在符号后注明使用期限：“数字十M”表示可使用
# Translating chunk: 多少个月，不需要翻译成各成员国的母语：也可用“数字十years”表示可使用
# Translating chunk: 多少年，但“years”必须翻译成销售国的母语。
# Translating chunk: （6）生产批号或产品识别号
# Translating chunk: 如果因产品本身体积太小无法做到时，允许只标注在外包装上（其次也可以
# Translating chunk: 标注在外容器上）。
# Translating chunk: （7）必要的警告声明（注意事项）
# Translating chunk: 包含特定组分的产品必须依照《欧盟化妆品指令》附录标注警告声明。所有
# Translating chunk: 成员国要求用自己各自国家的语言标注警示用语，在内外包装上都必须标注。如
# Translating chunk: 果因实际原因无法做到，可以标注在说明书、标签或卡片上，但同时必须在包装
# Translating chunk: 容器或外包装上印制简语或附录Ⅲ中的符号指示给消费者看。
# Translating chunk: 对喷雾剂产品和易燃产品有特殊警告规定，见《喷雾剂指令75/324/EEC》
# Translating chunk: 和修订版94/1/EC。此外，欧洲化妆品盟洗用品及香水协会（TheEuropean
# Translating chunk: Cosmetic，Tioletry，and PerfumeryAssociation，Colipa）联络委员会发布了关于易
# Translating chunk: 燃性产品标签政策，界定了某些化妆品在哪种情况下要求或者不要求标注此警告
# Translating chunk: 声明。
# Translating chunk: （8）必要的使用说明
# Translating chunk: 必须以官方语言或销售国的母语注明。该信息可以标注在附带的小册子、带
# Translating chunk: 子或标签条上，并印制简语或附录Ⅲ中的符号指示消费者参看。
# Translating chunk: （9）必要的储存条件
# Translating chunk: （10）产品功效
# Translating chunk: 如果产品的外观可以清楚的显示其功效，则可以不标注。
# Translating chunk: 功效宣称用语不得具有误导性。当主管机关认为一个产品的描述、标签、生
# Translating chunk: 产商或负责机构提供的其他信息可能使得该产品对人体健康有危害时，将禁止其
# Translating chunk: 27
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 投放市场。另外，有的成员国有本国的详细规定。
# Translating chunk: 《误导性广告84/450/EEC》及修订版97/55/EEC是专门关于对比性广告的指
# Translating chunk: 令。其中规定允许在指令指定条件下使用对比性广告。
# Translating chunk: 其中产品名称或类型、生产商或欧盟内经销商的地址或注册的办事处、净含
# Translating chunk: 量、保质期、使用说明、生产批号、必要的警告声明、产品功效和保存条件必须
# Translating chunk: 在内外包装上同时标注。
# Translating chunk: 所有标签内容至少应以各国母语或欧盟官方语言或上述两种语言进行标注。
# Translating chunk: 对字体大小没有要求（除了《指令76/211/EC》中对净含量有要求）。但建
# Translating chunk: 议使用可以确保视力正常的人在距离约30厘米处能轻松识读的字号。
# Translating chunk: （EC)1223/2009（《欧洲议会和欧盟理事会化妆品法规》）将从2013年7
# Translating chunk: 月11日起，取代旧的化妆品指令76/768/EEC及其到目前为止的67项修订文件，
# Translating chunk: 以欧盟法规的形式发布，在27个欧盟成员国（以及挪威、冰岛和列支敦士登）中
# Translating chunk: 作为国家法律实施。届时，欧洲经济区1（EEA)市场中销售的化妆品必须符合新
# Translating chunk: 颁布的欧盟化妆品法规（EC)No1223/20092的要求，其中部分要求将先于上述日
# Translating chunk: 期开始执行，如对于CMR（致癌、诱导有机体突变或对生殖有毒害的物质）和
# Translating chunk: 纳米材料的规定将分别于2010年12月1日和2013年1月11日开始执行。
# Translating chunk: 新法规简化了欧洲经济区对化妆品的要求，使其成为单一法律，消除了可能
# Translating chunk: 在成员国执法过程中产生分歧的内容。化妆品通报只需递交给由中央委员会和
# Translating chunk: COLIPA（欧洲化妆品协会）联合开发的数据库，而不是现在的各个成员国。不过，
# Translating chunk: 企业需要自行通报并保存相关文件，而不是由行业协会代管。
# Translating chunk: 《欧洲议会和欧盟理事会化妆品法规》对责任人的定义变得更加明确，规定
# Translating chunk: 责任人具体包括：①EEA内的生产商、②将产品输入EEA的进口商及③使用其
# Translating chunk: 自己的名称或商标将化妆品投放市场或者对化妆品的更改可能影响其法规符合
# Translating chunk: 性（不包括仅文字翻译）的分销商。根据新要求，责任人将承担更多的法律责任，
# Translating chunk: 涉及化妆品生产规范（GMP)、产品安全报告、产品资料档案（PIF)、产品通报、产
# Translating chunk: 品声明等。其中有关标签的规定有：
# Translating chunk: 28
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: （1）原产国：
# Translating chunk: 进口至EEA的化妆品必须标明原产国：
# Translating chunk: （2）最短有效期
# Translating chunk: 日期前的文字"有效期至"(best used before theendof")可由新的煮蛋计时
# Translating chunk: 器标志取代：如果开启后有效期无关紧要（现实实践确认）则无需注明开启后有效
# Translating chunk: 期。
# Translating chunk: 最短有效期煮蛋计时器标志
# Translating chunk: （3）在将产品投放市场前，分销商应确保符合以下标签要求：
# Translating chunk: 责任人的姓名或注册名称和地址：
# Translating chunk: 化妆品的批号或识别信息：
# Translating chunk: -成份表：（成份表中纳米材料的名称后应带有"（nano)字样）
# Translating chunk: -肥皂、沐浴球和其它小产品的减损：
# Translating chunk: 有关非预包装的、按买方要求在销售时进行包装的，或为立即销售进行预
# Translating chunk: 包装的化妆品的国家法规。
# Translating chunk: 3.1.5.2环境标签
# Translating chunk: 欧盟于1992年通过第EEC880/92号条例出台了生态标签体系，提出对声称
# Translating chunk: “环境友好（environmentalfriendly）”产品的最低要求，并于2000年通过欧盟
# Translating chunk: 1980/2000号条例进一步修改补充。该条例适用于全体成员国，提供了一个关于
# Translating chunk: 如何授予达到了各自行业既定的标准的产品生态标签的机制。它评价的是一种产
# Translating chunk: 品从生产到处理掉的整个过程产生的影响。该标签是自愿的，而且需要交纳使用
# Translating chunk: 费。每个成员国都有指定的本国范围内管理此项事务的实体。到目前为止，还没
# Translating chunk: 有一类化妆品制定完成此生态标签的授予标准。部分成员国有本国强制性的环境
# Translating chunk: 标签法。
# Translating chunk: 29
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 3.1.5.3小包装产品标签和其他豁免
# Translating chunk: 以下情况无需标注净含量：①包装容量小于5g或5ml的样品：②免费样品：
# Translating chunk: ③独立包装的样品：④通常按数量销售的样品。但仍需标注其他标签强制要求的
# Translating chunk: 内容。警告（预防措施）、使用说明、成份表可以标注在附带的说明书、标签、
# Translating chunk: 带子或卡片上，此时必须在外包装上印制符号指示消费者参看这些附带信息。
# Translating chunk: 《危险品制备指令1999/45/EC》提到了使用有害原材料和特定的免除标签化
# Translating chunk: 妆品的标签要求，指令的第10条要求在使用此危险品的场所建立安全数据表
# Translating chunk: （SDSs），这些准则在《指令91/155/EEC》上有规定，此契约也免除化妆品，但
# Translating chunk: 是使用者可以要求以其他方式给出同等的产品信息。
# Translating chunk: 3.2美国
# Translating chunk: 3.2.1法律文件
# Translating chunk: ·The Food,Drugs and Cosmetics Act（FD&CAct）（《食品、药品和化妆品
# Translating chunk: 法案》）：化妆品主要法规
# Translating chunk: ·The FairPackaging and Labelling Act（FPLA）（《合理包装及标签法》）：规
# Translating chunk: 定了化妆品的标签、包装和广告
# Translating chunk: ·CosmeticLabelling（《化妆品标签》）：21 CFR701
# Translating chunk: ·CosmeticLabellingManual（《化妆品标签指南》）
# Translating chunk: ·LabelingRequirementsforOver-the-CounterDrugs（《非处方药品（OTC）标签
# Translating chunk: 要求》）：21CFR201.66
# Translating chunk: 3.2.2主管机关
# Translating chunk: 美国食品药品管理局（The Food and DrugAdministration，FDA）主管化妆
# Translating chunk: 品和药品。化妆品由食品安全和营养学中心（TheCenterforFood Safety and
# Translating chunk: Applied Nutrition，CFSAN）下属色素和化妆品办公室负责，负责从生产到上市
# Translating chunk: 后的监督管理工作，可以不经通知进入到生产厂地进行检查，从上市产品中抽查
# Translating chunk: 30
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 产品。进口产品要遵循《进口化妆品规程》。OTC药品由药品评估和研究中心（The
# Translating chunk: Center forDrugEvaluation and Research，CDER）负责管理。既是化妆品又是OTC
# Translating chunk: 药品的产品由CFSAN和CDER共同管理。对于进口美国的海外产品，FDA可以到
# Translating chunk: 海外施行检查。
# Translating chunk: 3.2.3化妆品定义
# Translating chunk: 《FD&C法案》将化妆品定义为两类：
# Translating chunk: ·化妆品
# Translating chunk: ·非处方药品
# Translating chunk: 产品属于化妆品或药品取决于它们的用途，而用途则根据产品功效声明和消
# Translating chunk: 费者的认知（通过产品的口碑或成分的治疗功能）来确定。根据《FD&C法案》，
# Translating chunk: 产品可以是药品，也可以是化妆品，或既是药品也是化妆品（与欧盟刚好相反）。
# Translating chunk: 第三种情况只有在产品有两种用途，符合两种定义的时候才会发生，例如：防头
# Translating chunk: 皮屑香波是化妆品，因为它的声明表明产品的用途是用来清洁头发：但是它同样
# Translating chunk: 也可视作药品，因为它含有公认的防头皮屑成分且它的声明表明它是用来治疗头
# Translating chunk: 皮屑的。确定为既是化妆品又是药品的产品必须符合两种类别产品的法规要求。
# Translating chunk: 化妆品的定义：指除了脂肪酸碱性盐肥皂之外的施用于人体（擦、注、撒或
# Translating chunk: 喷）或其任何部位用于清洁、美化、增强吸引力或改善外貌而对人体结构或功能
# Translating chunk: 没有影响的产品。
# Translating chunk: 药品的定义：用于治疗、缓解、医治或预防人类和其他动物疾病的物品以及
# Translating chunk: 食品之外的用于影响人体或其他动物体结构和功能的物品。
# Translating chunk: 非处方药品是指可以无需医生处方即可买到的药品。
# Translating chunk: 某些在欧盟被分为化妆品的产品在美国被分为新药品而非OTC药品。新药
# Translating chunk: 品是指尚未被专家们广泛认可在预期使用目的下安全有效的药品，或是尚未在确
# Translating chunk: 切的范围或时间内使用的药品。
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 3.2.4化妆品分类
# Translating chunk: （1）化妆品分类：
# Translating chunk: ·皮肤护理
# Translating chunk: ·香水
# Translating chunk: ·眼部化妆品
# Translating chunk: ·眼部外的化妆品
# Translating chunk: ·指甲产品
# Translating chunk: ·沐浴油和泡沫浴液
# Translating chunk: ·漱口水
# Translating chunk: ·染发预处理
# Translating chunk: ·洗发水、烫发剂或其他护发产品
# Translating chunk: ·除臭剂
# Translating chunk: ·剃须产品
# Translating chunk: ·儿童产品
# Translating chunk: ·晒黑产品
# Translating chunk: （2）OTC药品（化妆品）分类：
# Translating chunk: ·防齿（含氟化物）的牙膏
# Translating chunk: ·保湿产品
# Translating chunk: ·防晒化妆品
# Translating chunk: ·抑汗剂
# Translating chunk: ·防头屑洗发水
# Translating chunk: 32
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 3.2.5化妆品标签要求
# Translating chunk: 3.2.5.1化妆品标签一般要求
# Translating chunk: 规定化妆品标签必须标注的内容：
# Translating chunk: （1）产品名称和呈述：必须标注在外包装主展示面上。
# Translating chunk: 使用化妆品的常用名或者恰当的描述性名称。如果该化妆品的性质是显而易
# Translating chunk: 见的，则在不会造成公众对该化妆品误解和无法辨别的前提下，可以使用更为奇
# Translating chunk: 特有趣的名称。
# Translating chunk: （2）生产商、包装商或发行商的名称和地址：在内、外包装上标注。
# Translating chunk: 具体规定见《美国联邦法规》（CodeofFederalRegulations，CFR）第21卷
# Translating chunk: 第701.12部分。进口化妆品必须在容器外面用英语标明原产国及制造商或代理
# Translating chunk: 商（包括进口商）。原产国由以下语句标注：“由…（英文标写国家名）国制造”；
# Translating chunk: 或“…（英文标写的国家名）国产品”：或其他能清楚表明原产国意思的语句。
# Translating chunk: 如果原产国是北美自由贸易区（NAFTA）国家，可以用英语、法语或西班牙语。
# Translating chunk: （3）净含量：标注在内、外包装的主展示面上。
# Translating chunk: 强制以传统的美国惯例单位标注，另外，还可以用公制单位同时标注。如果
# Translating chunk: 化妆品为液体，声明必须用体积单位：如果化妆品为固体、半固体、粘性物或固
# Translating chunk: 体混合物，声明必须用重量单位。重量用磅和盘司表示。液体体积用美制加仑、
# Translating chunk: 夸脱、品脱和液量益司表示。美国的体积计算和英国以及其他国家的体积有微小
# Translating chunk: 的差别。净含量标签的具体规定见21CFR701.13。
# Translating chunk: （4）化妆品成分表：在外包装上标注。
# Translating chunk: 具体规定见21CFR701.3。供个人使用的零售产品在化妆品标签上必须列出
# Translating chunk: 化妆品的全部成分。一般情况下不零售的化妆品，例如，专业人士在专业机构中
# Translating chunk: 为顾客使用的发用品或彩妆品，以及在工作场所供人们使用的洁肤霜和润肤霜，
# Translating chunk: 而且这些产品也不会销售给消费者供他们在家使用，可以不注明成分。香水和香
# Translating chunk: 料例外，可以只列出非商标性名称。此外，出于商业保密的需要，经FDA批准
# Translating chunk: 33
# Translating chunk: 各国化妆品标签管理指南
# Translating chunk: 豁免公之于众的成分可以不列于标签上，但必须于标签组分的最后部分声明：“以
# Translating chunk: 及其他成分”。如果包装上没有足够的标签空间或者是装饰性的容器，可使用附
# Translating chunk: 页标签（附带的标签、带子或卡片）（具体细节见CTFA标签手册（TheCosmetic，
# Translating chunk: Toiletry andFragranceAssociation，美国化妆品、盟洗用品和香料协会，现已更名
# Translating chunk: 为PersonCareProductsCouncil，美国个人用品护理用品协会））。
# Translating chunk: 标注顺序为：
# Translating chunk: 含量高于1%的成分以降序排列：含量小于1%的成分，其顺序可以是任意
# Translating chunk: 排列的：色素添加剂按任意顺序排列，以“含有…”语句引出，不能使用“+/-”
# Translating chunk: 符号：“以及其他成分”。
# Translating chunk: 标注的成份名称必须依次使用下列名称：21CFR701.30中列出的指定名称、
# Translating chunk: CTFA《化妆品成分词典》（此规定名称见INCI名称）、《美国药典》的名称、《国
# Translating chunk: 家处方集》的名称、《食品化学法典》的名称、《美国药品正名和药典药名词典》
# Translating chunk: 的名称、消费者公认的名称、化学或其他技术专用名称或描述。
# Translating chunk: （5）保质期
# Translating chunk: 要说明在什么时间内使用是安全的。
# Translating chunk: （6）生产批号
# Translating chunk: 化妆品不要求批量鉴定，但是应当建立在健康的商业活动基础上。
# Translating chunk: （7）警告声明：在内、外包装上标注。
# Translating chunk: 《化妆品类产品警告声明》（21CFR740）对警告声明作了详细规定。某些产
# Translating chunk: 品标签必须带有警示用语。例如以自加压容器包装的化妆品（如喷雾剂产品）
# Translating chunk: 女用除臭喷雾和儿童泡沫浴液等。当一个具体的警示用语得到法律认可后，就不
# Translating chunk: 能改变语句，并且在使用时必须按照相关法规确切使用。如果化妆品的安全性未
# Translating chunk: 能得到充分的证实，且没有在标签的主展示面上出现以下明确的声明：“警告一一
# Translating chunk: 该产品的安全性未经测定”，则该化妆品将会被视为错误标签产品。另外，还需
# Translating chunk: 要注意某些州制定的对警告有特殊要求的法令。
# Translating chunk: （8）必要时，标注储存条件。
# Translating chunk: 34

# %% [markdown]
# Image - chinese to english

# %%
import cv2
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from paddleocr import PaddleOCR
from deep_translator import GoogleTranslator

# Step 1: Initialize PaddleOCR for Chinese and English text detection
ocr = PaddleOCR(use_angle_cls=True, lang='ch')  # 'ch' supports Chinese and English text detection

# Step 2: Read the image
image_path = 'pdf_page.png'
image = cv2.imread(image_path)

# Step 3: Use PaddleOCR to detect and extract text along with bounding boxes
ocr_results = ocr.ocr(image, cls=True)

# Step 4: Create a PIL image from the OpenCV image for easier text overlay
pil_image = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
draw = ImageDraw.Draw(pil_image)

# Load a suitable font for overlaying the translated text
font_path = "ArialUnicodeMS.ttf"  # Specify the path to your TTF font file
font_size = 16  # Adjust based on image size and resolution
font = ImageFont.truetype(font_path, font_size)

# Define the translation function as provided by the user
def translate_text(text, source_lang='zh-CN', target_lang='en'):
    if not isinstance(text, str):
        print(f"Invalid input type for translation: {type(text)}")  # Debugging line
        return ""  # Return empty string for invalid input

    max_chunk_size = 5000
    translated_chunks = []

    # Split the text into smaller chunks
    for i in range(0, len(text), max_chunk_size):
        chunk = text[i:i + max_chunk_size]
        print(f"Translating chunk: {chunk}")  # Debugging line

        try:
            translated_chunk = GoogleTranslator(source=source_lang, target=target_lang).translate(chunk)
            if translated_chunk:  # Ensure we only append valid strings
                translated_chunks.append(translated_chunk)
            else:
                print(f"Translation returned None for chunk: {chunk}")  # Debugging line

        except Exception as e:
            print(f"Error translating chunk '{chunk}': {e}")  # Print the error for debugging

    # Join all the translated chunks into a single string
    translated_text = ''.join(translated_chunks)
    return translated_text

# Step 5: Iterate through detected text boxes, translate, and replace text in the image
if ocr_results[0]:
    for line in ocr_results:
        for (bbox, (text, confidence)) in line:  # Correctly unpack the tuple to get text and confidence
            if isinstance(text, str):  # Check if text is a valid string
                print(f"Detected text: {text}")  # Debugging line
                translated_text = translate_text(text)  # Use the translate_text function

                # Bounding box coordinates
                top_left = bbox[0]
                bottom_right = bbox[2]
                x_min, y_min = int(top_left[0]), int(top_left[1])
                x_max, y_max = int(bottom_right[0]), int(bottom_right[1])

                # Step 6: Draw a white rectangle over the original text region
                draw.rectangle([x_min, y_min, x_max, y_max], fill="white")

                # Step 7: Overlay the translated text back on the image
                draw.text((x_min, y_min), translated_text, fill="black", font=font)

# Step 8: Convert PIL image back to OpenCV format and save the image
final_image = cv2.cvtColor(np.array(pil_image), cv2.COLOR_RGB2BGR)
output_path = 'translated_image_paddleocr.jpg'  # Path to save the final image
cv2.imwrite(output_path, final_image)

print(f"Translation and text overlay completed successfully! Image saved at {output_path}")
# Out:
# [2024/10/04 13:20:47] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/user/.paddleocr/whl/det/ch/ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/user/.paddleocr/whl/rec/ch/ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/user/Meet_Patel/AllChatbot-Project/chatenv/lib/python3.12/site-packages/paddleocr/ppocr/utils/ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/home/user/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/10/04 13:20:48] ppocr DEBUG: dt_boxes num : 90, elapsed : 0.17946791648864746
# [2024/10/04 13:20:48] ppocr DEBUG: cls num  : 90, elapsed : 0.16568255424499512
# [2024/10/04 13:20:50] ppocr DEBUG: rec_res num  : 90, elapsed : 2.1707606315612793
# Detected text: 各国化集品标管普理指店
# Translating chunk: 各国化集品标管普理指店
# Detected text: 以上。
# Translating chunk: 以上。
# Detected text: 表2.62007-2011年我国化妆品主要出口地区数量及金割
# Translating chunk: 表2.62007-2011年我国化妆品主要出口地区数量及金割
# Detected text: 单位：万吨亿美元
# Translating chunk: 单位：万吨亿美元
# Detected text: 地区
# Translating chunk: 地区
# Detected text: 2007年
# Translating chunk: 2007年
# Detected text: 2008年
# Translating chunk: 2008年
# Detected text: 2000年
# Translating chunk: 2000年
# Detected text: 2010年
# Translating chunk: 2010年
# Detected text: 2011年
# Translating chunk: 2011年
# Detected text: 最量
# Translating chunk: 最量
# Detected text: 金额
# Translating chunk: 金额
# Detected text: 最量
# Translating chunk: 最量
# Detected text: 金额
# Translating chunk: 金额
# Detected text: 最量
# Translating chunk: 最量
# Detected text: 金额
# Translating chunk: 金额
# Detected text: 最量
# Translating chunk: 最量
# Detected text: 金额
# Translating chunk: 金额
# Detected text: 数量
# Translating chunk: 数量
# Detected text: 金额
# Translating chunk: 金额
# Detected text: 北美
# Translating chunk: 北美
# Detected text: 6.50
# Translating chunk: 6.50
# Detected text: 1.04
# Translating chunk: 1.04
# Detected text: 3.90
# Translating chunk: 3.90
# Detected text: 2.14
# Translating chunk: 2.14
# Detected text: 6.07
# Translating chunk: 6.07
# Detected text: 2.38
# Translating chunk: 2.38
# Detected text: 7.03
# Translating chunk: 7.03
# Detected text: 3.26
# Translating chunk: 3.26
# Detected text: 13.24
# Translating chunk: 13.24
# Detected text: 1.08
# Translating chunk: 1.08
# Detected text: 2.8
# Translating chunk: 2.8
# Detected text: 1.60
# Translating chunk: 1.60
# Detected text: 2.85
# Translating chunk: 2.85
# Detected text: 1.81
# Translating chunk: 1.81
# Detected text: 3.50
# Translating chunk: 3.50
# Detected text: 2.09
# Translating chunk: 2.09
# Detected text: 4.71
# Translating chunk: 4.71
# Detected text: 7.41
# Translating chunk: 7.41
# Detected text: 1.60
# Translating chunk: 1.60
# Detected text: 香港
# Translating chunk: 香港
# Detected text: 6.10
# Translating chunk: 6.10
# Detected text: 1.37
# Translating chunk: 1.37
# Detected text: 1.93
# Translating chunk: 1.93
# Detected text: B.92
# Translating chunk: B.92
# Detected text: 2.00
# Translating chunk: 2.00
# Detected text: 10.63
# Translating chunk: 10.63
# Detected text: 3.34
# Translating chunk: 3.34
# Detected text: 11.92
# Translating chunk: 11.92
# Detected text: 4.12
# Translating chunk: 4.12
# Detected text: 0.98
# Translating chunk: 0.98
# Detected text: 0.74
# Translating chunk: 0.74
# Detected text: 1.00
# Translating chunk: 1.00
# Detected text: D.82
# Translating chunk: D.82
# Detected text: .01
# Translating chunk: .01
# Detected text: 2.95
# Translating chunk: 2.95
# Detected text: 1.51
# Translating chunk: 1.51
# Detected text: 东盟
# Translating chunk: 东盟
# Detected text: 2.35
# Translating chunk: 2.35
# Detected text: 1.70
# Translating chunk: 1.70
# Detected text: 台湾
# Translating chunk: 台湾
# Detected text: 中东
# Translating chunk: 中东
# Detected text: 拉美
# Translating chunk: 拉美
# Detected text: 1.43
# Translating chunk: 1.43
# Detected text: 大洋洲
# Translating chunk: 大洋洲
# Detected text: 出1北美：美国.加享大：共z国：
# Translating chunk: 出1北美：美国.加享大：共z国：
# Detected text: 欧盟：法国、意大利、荷兰、比利时、卢森量、德国、爱尔兰、丹麦、英国、希腊。
# Translating chunk: 欧盟：法国、意大利、荷兰、比利时、卢森量、德国、爱尔兰、丹麦、英国、希腊。
# Detected text: 句牙利、技克、斯备伐克、斯备文尼重、马耳他、塞浦路斯、保如利重、罗马
# Translating chunk: 句牙利、技克、斯备伐克、斯备文尼重、马耳他、塞浦路斯、保如利重、罗马
# Detected text: 省萄牙、西班牙.奥地利、芽兰、璃典、鼓兰、拉乾维重、立闯南、爱沙尼重。
# Translating chunk: 省萄牙、西班牙.奥地利、芽兰、璃典、鼓兰、拉乾维重、立闯南、爱沙尼重。
# Detected text: 东重：日本。韩国、朝鲜、蒙古：其4国：
# Translating chunk: 东重：日本。韩国、朝鲜、蒙古：其4国：
# Detected text: 东盟：印度尼西亚、新如坡。幸国、非律宾、马来西亚、文莱、插旬、越南、老树。
# Translating chunk: 东盟：印度尼西亚、新如坡。幸国、非律宾、马来西亚、文莱、插旬、越南、老树。
# Detected text: 束寨，共10国：
# Translating chunk: 束寨，共10国：
# Detected text: 中东：巴林、埃及、伊朗、伊控克、以色到、的旦、科感特、黎巴量、阿曼、卡塔乐。
# Translating chunk: 中东：巴林、埃及、伊朗、伊控克、以色到、的旦、科感特、黎巴量、阿曼、卡塔乐。
# Detected text: 沙特网检伯、叔利量、育拉伯联合首长国、也门、巴勒斯坦、阿尔及利重、利
# Translating chunk: 沙特网检伯、叔利量、育拉伯联合首长国、也门、巴勒斯坦、阿尔及利重、利
# Detected text: 比业。摩络哥、宾尼斯、苏丹、毛里塔尼亚、贵马里，共22国：
# Translating chunk: 比业。摩络哥、宾尼斯、苏丹、毛里塔尼亚、贵马里，共22国：
# Detected text: 东默：快罗斯联邦、白快罗斯、乌克兰、摩尔多瓦，共4国
# Translating chunk: 东默：快罗斯联邦、白快罗斯、乌克兰、摩尔多瓦，共4国
# Translation and text overlay completed successfully! Image saved at translated_image_paddleocr.jpg
